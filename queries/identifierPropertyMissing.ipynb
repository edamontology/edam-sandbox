# %% [markdown]
# **identifierPropertyMissing.ipynb**
#
# EDAM identifier concept is missing a mandatory or recommended annotation property
#
# **Documentation:** https://github.com/edamontology/edamverify/blob/master/docs/identifierPropertyMissing.md
#
# Set constants for script return values. Load EDAM_dev.owl from GitHub into an RDF graph.

# %%
import os
from rdflib import ConjunctiveGraph, Namespace
import json
from collections import OrderedDict

# Constants for script error reporting as per https://github.com/edamontology/edamverify.
NOERR = "NOERR"
INFO  = "INFO"
WARN  = "WARN"
ERROR = "ERROR"

#Load EDAM_dev.owl from GitHub into an RDF graph.
print("Loading graph ...", end="")
g = ConjunctiveGraph()
g.load(os.environ.get('EDAM_PATH', '../EDAM_dev.owl'), format='xml')
# g.load('https://raw.githubusercontent.com/edamontology/edamontology/master/EDAM_dev.owl', format='xml')
# g.load('EDAM_dev.owl', format='xml')
g.bind('edam', Namespace('http://edamontology.org#'))
print("done!")
# Out:
# Loading graph ...done!
# https://neuroml.org/neuromlv2|https://neuroml-db.org/ does not look like a valid URI, trying to serialize this will break.

# %% [markdown]
# Define SPARQL query to retrieve ID, term, and all properties that are mandatory or recommended for Format concepts. Run the query.
#
# **NB.1:** BASE is used to define the define the default namespace (for various elements below).
#
# **NB.2:** A concept is considered to be an identifier if it has a property ``<oboInOwl:inSubset>`` whose value contains the string ``identifiers``, e.g. ``<oboInOwl:inSubset rdf:resource="http://purl.obolibrary.org/obo/edam#identifiers"/>`` or ``<oboInOwl:inSubset>identifiers />``
#
# **NB.3:** Many of the checks should not apply to "placeholder" Identifier concepts (see https://edamontologydocs.readthedocs.io/en/latest/technical_details.html#concept-types).  The code could be improved to take account of this.

# %%
# Compile SPARQL query
query_term = """
BASE <http://edamontology.org/>
SELECT ?id ?term ?subsetpath ?documentation ?regex WHERE
{
# ?id rdfs:label ?term .
# ?id oboInOwl:inSubset ?subsetpath .
OPTIONAL {?id :documentation ?documentation .}
OPTIONAL {?id :regex ?regex .}
}
"""

# Run SPARQL query and collate results
err = NOERR
errfound = False
report = list()
results = g.query(query_term)

# %% [markdown]
# Analyse results of query.

# %%
# Error message building function
def report_append(err_new, msg):
    """
    Writes a report of an error and sets the error level appropriately.
    err: the error level to set
    msg: the message to write
    """
    global err
    global errfound
    global report
    if err_new > err:
        err = err_new
    errfound = True
    report.append(msg)

report.append('Recommended properties missing from these Identifier concepts:')

for r in results :
#    print(str(r['id']), str(r['term']), str(r['ext']), str(r['exact_syn']))
    id   = str(r['id'])
    term = str(r['term'])
    subsetpath  = str(r['subsetpath'])

    documentation = str(r['documentation'])
    regex = str(r['regex'])


    # Check for Format concepts
    if "identifiers" in subsetpath:
        if documentation == "None":
            report_append(INFO, "INFO Missing property (documentation) on ::: " + id +  ' (' + term + ')')
        if regex == "None":
            report_append(INFO, "INFO Missing property (regex) on ::: " + id +  ' (' + term + ')')

# %% [markdown]
# Write report and return approriate value.

# %%
# Write report
# Use ordered dictionary to get consistent listing of properties in the JSON output
report_dict = OrderedDict

if errfound:
    report_dict = {
        'test_name': 'identifierPropertyMissing',
        'status' : err,
        'reason' : report
    }
else:
    report_dict = {
        'test_name': 'identifierPropertyMissing',
        'status' : NOERR,
        'reason' : '-'
    }

report_json = json.dumps(report_dict, indent=4)
print(report_json)
# Out:
# {
#     "reason": [
#         "Recommended properties missing from these Identifier concepts:",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1115 (Sequence profile ID)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1115 (Sequence profile ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2388 (TAIR accession (At gene))",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2388 (TAIR accession (At gene))",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1900 (NCBI locus tag)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1900 (NCBI locus tag)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1045 (Species name)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1045 (Species name)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2391 (UTR accession)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2391 (UTR accession)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2610 (Ensembl ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1192 (Tool name (BLAST))",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1192 (Tool name (BLAST))",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2370 (ASTD ID (polya))",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2370 (ASTD ID (polya))",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2907 (Protein accession)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2907 (Protein accession)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_0989 (Protein identifier)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_0989 (Protein identifier)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2174 (FlyBase secondary identifier)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2174 (FlyBase secondary identifier)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2320 (Cell line name (assonant))",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2320 (Cell line name (assonant))",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2791 (Reference map name (SWISS-2DPAGE))",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2791 (Reference map name (SWISS-2DPAGE))",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1011 (EC number)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_3103 (ATC code)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_3103 (ATC code)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1191 (Tool name (signature))",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1191 (Tool name (signature))",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1150 (Disease ID)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1150 (Disease ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2298 (Gene ID (HGNC))",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2298 (Gene ID (HGNC))",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1072 (Structure alignment ID)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1072 (Structure alignment ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2578 (ArachnoServer ID)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2578 (ArachnoServer ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_0842 (Identifier)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_0842 (Identifier)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2916 (DDBJ accession)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2916 (DDBJ accession)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2383 (EGA accession)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2383 (EGA accession)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2114 (WormBase wormpep ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1807 (ORF name)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1807 (ORF name)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2254 (OBO file format name)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2254 (OBO file format name)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1182 (FMA concept ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1008 (Polypeptide chain ID)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1008 (Polypeptide chain ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_3568 (Gene Expression Atlas Experiment ID)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_3568 (Gene Expression Atlas Experiment ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1190 (Tool name)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1190 (Tool name)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2778 (CCAP strain number)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2778 (CCAP strain number)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1144 (ArrayExpress accession number)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2738 (Gene ID (Xenbase))",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2738 (Gene ID (Xenbase))",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2723 (Protein ID (DisProt))",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2723 (Protein ID (DisProt))",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2326 (DrugBank ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1059 (File name extension)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1059 (File name extension)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1112 (Sequence cluster ID)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1112 (Sequence cluster ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2129 (File format name)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2129 (File format name)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1147 (GEO accession number)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2118 (Person identifier)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2118 (Person identifier)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2643 (Gene ID (ZFIN))",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2770 (HIT ID)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2770 (HIT ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2651 (Disease ID (PharmGKB))",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2646 (Compound ID (ChEMBL))",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2098 (Job identifier)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2098 (Job identifier)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2295 (Gene ID)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2295 (Gene ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1117 (Prosite accession number)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2719 (dbProbe ID)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2719 (dbProbe ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2911 (Transcription factor accession)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2911 (Transcription factor accession)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1181 (UMLS concept ID)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1181 (UMLS concept ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2107 (Enzyme ID (BioCyc))",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2107 (Enzyme ID (BioCyc))",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2895 (Drug accession)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2895 (Drug accession)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_0997 (Chemical name (ChEBI))",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_0997 (Chemical name (ChEBI))",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2637 (cPath ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1000 (Chemical name (brand))",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1000 (Chemical name (brand))",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1106 (dbSNP ID)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1106 (dbSNP ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1757 (Atom name)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1757 (Atom name)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2789 (Protein ID (TopDB))",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2789 (Protein ID (TopDB))",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2793 (SISYPHUS ID)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2793 (SISYPHUS ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1908 (Locus ID (Tropgene))",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1908 (Locus ID (Tropgene))",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1070 (Structure ID)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1070 (Structure ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2769 (Transcript ID)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2769 (Transcript ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1903 (Locus ID (DictyBase))",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1903 (Locus ID (DictyBase))",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2670 (Pathway ID (DQCS))",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2538 (Mutation identifier)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2538 (Mutation identifier)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1118 (HMMER hidden Markov model ID)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1118 (HMMER hidden Markov model ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2294 (Sequence variation ID)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2294 (Sequence variation ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2803 (Clone ID (RefSeq))",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2803 (Clone ID (RefSeq))",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1895 (Locus ID (AGI))",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1044 (Kingdom name)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1044 (Kingdom name)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2595 (UTRdb taxon)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2595 (UTRdb taxon)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1155 (Pathway ID (reactome))",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2127 (Genetic code identifier)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2127 (Genetic code identifier)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2892 (Cell type name)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2892 (Cell type name)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_3266 (Sequence assembly ID)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_3266 (Sequence assembly ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2632 (SGD ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2784 (RNAVirusDB ID)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2784 (RNAVirusDB ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1036 (TIGR identifier)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1036 (TIGR identifier)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2800 (Orpha number)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2800 (Orpha number)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2628 (BioGRID interaction ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2727 (Promoter ID)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2727 (Promoter ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2373 (Spot ID)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2373 (Spot ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1089 (FlyBase ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1881 (Author ID)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1881 (Author ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1060 (File base name)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1060 (File base name)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2591 (Brite hierarchy ID)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2591 (Brite hierarchy ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1093 (Sequence accession)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1093 (Sequence accession)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1043 (CATH node ID)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1043 (CATH node ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2658 (Compound ID (ChemIDplus))",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2894 (Compound accession)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2894 (Compound accession)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1174 (ChEBI ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2636 (MatrixDB interaction ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1051 (Ontology name)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1051 (Ontology name)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2774 (Gene ID (JCVI))",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2774 (Gene ID (JCVI))",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2742 (AraC-XylS ID)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2742 (AraC-XylS ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2663 (Carbohydrate identifier)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2663 (Carbohydrate identifier)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2576 (Toxin identifier)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2576 (Toxin identifier)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2751 (GenomeReviews ID)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2751 (GenomeReviews ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2386 (EPD ID)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2386 (EPD ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2387 (TAIR accession)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2387 (TAIR accession)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2776 (ConsensusPathDB entity ID)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2776 (ConsensusPathDB entity ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2309 (Reaction ID (SABIO-RK))",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1075 (Protein family identifier)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1075 (Protein family identifier)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2766 (HAMAP ID)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2766 (HAMAP ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2700 (CATH identifier)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2700 (CATH identifier)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2615 (MINT ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2293 (Gramene secondary identifier)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2293 (Gramene secondary identifier)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2901 (Molecule accession)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2901 (Molecule accession)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2669 (ModelDB ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2112 (FlyBase primary identifier)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2112 (FlyBase primary identifier)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1025 (Gene identifier)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1025 (Gene identifier)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2654 (Target ID (TTD))",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2653 (Drug ID (TTD))",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1032 (Gene ID (DictyBase))",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1032 (Gene ID (DictyBase))",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1898 (Locus ID (CGD))",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1898 (Locus ID (CGD))",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_3025 (Ontology concept identifier)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_3025 (Ontology concept identifier)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2718 (Oligonucleotide ID)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2718 (Oligonucleotide ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2714 (CDD PSSM-ID)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2714 (CDD PSSM-ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1795 (Gene ID (EcoGene))",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1795 (Gene ID (EcoGene))",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1119 (JASPAR profile ID)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1119 (JASPAR profile ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2705 (GO concept ID (cellular component))",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1010 (Enzyme identifier)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1010 (Enzyme identifier)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2660 (BioNumbers ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1012 (Enzyme name)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1012 (Enzyme name)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_0998 (Chemical name (IUPAC))",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_0998 (Chemical name (IUPAC))",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2638 (PubChem bioassay ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2379 (Strain identifier)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2379 (Strain identifier)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_0995 (Nucleotide identifier)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_0995 (Nucleotide identifier)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2897 (Toxin accession)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2897 (Toxin accession)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1690 (Password)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1690 (Password)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_0977 (Tool identifier)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_0977 (Tool identifier)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1116 (ELM ID)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1116 (ELM ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2290 (EMBL accession)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2290 (EMBL accession)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1805 (Gene ID (WormBase))",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1079 (Electron microscopy model ID)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1079 (Electron microscopy model ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_3270 (Ensembl gene tree ID)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_3270 (Ensembl gene tree ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1040 (CATH domain ID)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1040 (CATH domain ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2253 (Data resource definition name)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2253 (Data resource definition name)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1794 (Gene ID (PlasmoDB))",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1794 (Gene ID (PlasmoDB))",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2614 (TCDB ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2630 (Mobile genetic element ID)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2630 (Mobile genetic element ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2650 (Pathway ID (PharmGKB))",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2642 (Gene ID (miRBase))",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2349 (Sequence cluster ID (UniRef50))",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2349 (Sequence cluster ID (UniRef50))",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2110 (Molecular property identifier)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2110 (Molecular property identifier)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2836 (DPVweb ID)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2836 (DPVweb ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2128 (Genetic code name)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2128 (Genetic code name)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2710 (CleanEx dataset code)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2710 (CleanEx dataset code)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2371 (ASTD ID (tss))",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2371 (ASTD ID (tss))",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1095 (EMBOSS Uniform Sequence Address)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1095 (EMBOSS Uniform Sequence Address)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1007 (Nucleotide code)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1007 (Nucleotide code)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1893 (Locus ID)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1893 (Locus ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1034 (Gene ID (SGD))",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2563 (Amino acid name (single letter))",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2563 (Amino acid name (single letter))",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1031 (Gene ID (CGD))",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1031 (Gene ID (CGD))",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2616 (DIP ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2790 (Gel ID)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2790 (Gel ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2346 (Sequence cluster ID (UniRef))",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2346 (Sequence cluster ID (UniRef))",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2154 (Sequence name)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2154 (Sequence name)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_0987 (Chromosome name)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_0987 (Chromosome name)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2385 (RefSeq accession (protein))",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2385 (RefSeq accession (protein))",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1050 (File name)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1050 (File name)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_0982 (Molecule identifier)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_0982 (Molecule identifier)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2662 (T3DB ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1882 (DragonDB author identifier)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1882 (DragonDB author identifier)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2344 (Pathway ID (NCI-Nature))",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1105 (dbEST accession)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1105 (dbEST accession)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2639 (PubChem ID)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2639 (PubChem ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2621 (TAIR accession (protein))",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2625 (LIPID MAPS ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1131 (Protein family name)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1131 (Protein family name)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2111 (Codon usage table ID)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2111 (Codon usage table ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1189 (Medline UI)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1189 (Medline UI)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2633 (Book ID)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2633 (Book ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_3238 (Cell type ontology ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1153 (OMIM ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2390 (UNITE accession)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2390 (UNITE accession)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2912 (Strain accession)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2912 (Strain accession)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1066 (Sequence alignment ID)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1066 (Sequence alignment ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2113 (WormBase identifier)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2113 (WormBase identifier)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2656 (NeuronDB ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2340 (Genome build identifier)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2340 (Genome build identifier)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1069 (Comparison matrix identifier)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1069 (Comparison matrix identifier)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1896 (Locus ID (ASPGD))",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1896 (Locus ID (ASPGD))",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2744 (Locus ID (PseudoCAP))",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2744 (Locus ID (PseudoCAP))",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1048 (Database ID)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1048 (Database ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2292 (GenBank accession)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2292 (GenBank accession)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1088 (Article ID)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1088 (Article ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1178 (HGNC concept ID)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1178 (HGNC concept ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1033 (Ensembl gene ID)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1033 (Ensembl gene ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1183 (EMAP concept ID)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1183 (EMAP concept ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1078 (Experiment annotation ID)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1078 (Experiment annotation ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2667 (MMDB ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2900 (Carbohydrate accession)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2900 (Carbohydrate accession)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2635 (Compound ID (3DMET))",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1891 (iHOP symbol)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1891 (iHOP symbol)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1140 (Superfamily hidden Markov model number)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1140 (Superfamily hidden Markov model number)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1804 (Gene ID (SGN))",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1804 (Gene ID (SGN))",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2641 (Reaction ID (MACie))",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2345 (Pathway ID (ConsensusPathDB))",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2345 (Pathway ID (ConsensusPathDB))",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_3273 (Sample ID)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_3273 (Sample ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1759 (PDB model number)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1759 (PDB model number)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2666 (CDD ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1194 (Tool name (EMBOSS))",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1194 (Tool name (EMBOSS))",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2380 (CABRI accession)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2380 (CABRI accession)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1173 (ChemSpider ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2755 (Transcription factor name)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2755 (Transcription factor name)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1172 (PubChem CID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1009 (Protein name)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1009 (Protein name)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1064 (Sequence set ID)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1064 (Sequence set ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2318 (Cell line name (truncated))",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2318 (Cell line name (truncated))",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1042 (SCOP sunid)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1042 (SCOP sunid)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2785 (Virus ID)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2785 (Virus ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1103 (EMBL/GenBank/DDBJ ID)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1103 (EMBL/GenBank/DDBJ ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2649 (PharmGKB ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1907 (Gene ID (KOME))",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1907 (Gene ID (KOME))",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2606 (RFAM name)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2606 (RFAM name)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1006 (Amino acid name)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1006 (Amino acid name)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1148 (GermOnline ID)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1148 (GermOnline ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2612 (Sequence cluster ID (CluSTr))",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_3275 (Phenotype name)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_3275 (Phenotype name)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2759 (Gene ID (VectorBase))",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2759 (Gene ID (VectorBase))",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_3265 (HGMD ID)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_3265 (HGMD ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2715 (Protein ID (CuticleDB))",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2715 (Protein ID (CuticleDB))",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1905 (Locus ID (MaizeGDB))",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1905 (Locus ID (MaizeGDB))",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2104 (BioCyc ID)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2104 (BioCyc ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_3667 (Disease identifier)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_3667 (Disease identifier)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1041 (SCOP concise classification string (sccs))",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1041 (SCOP concise classification string (sccs))",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_3035 (Structure identifier)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_3035 (Structure identifier)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2648 (Reaction kinetics ID (SABIO-RK))",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1162 (MIRIAM identifier)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2583 (GO concept ID (molecular function))",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2613 (KEGG Glycan ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1124 (TreeFam accession number)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1124 (TreeFam accession number)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_3264 (COSMIC ID)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_3264 (COSMIC ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2629 (Enzyme ID (MEROPS))",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2799 (Gene ID (MfunGD))",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2799 (Gene ID (MfunGD))",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2631 (ACLAME ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1802 (Gene ID (Gramene))",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1802 (Gene ID (Gramene))",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1758 (PDB residue name)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1758 (PDB residue name)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1159 (Pathway ID (PATIKA))",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1159 (Pathway ID (PATIKA))",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2626 (PeptideAtlas ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1692 (Person name)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1692 (Person name)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_0976 (Identifier (by type of data))",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_0976 (Identifier (by type of data))",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2316 (Cell line name)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2316 (Cell line name)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2131 (Operating system name)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2131 (Operating system name)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1005 (HET group name)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1005 (HET group name)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2384 (IPI protein ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2644 (Reaction ID (Rhea))",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1193 (Tool name (FASTA))",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1193 (Tool name (FASTA))",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2593 (BRENDA organism ID)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2593 (BRENDA organism ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1080 (Gene expression report ID)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1080 (Gene expression report ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2659 (Pathway ID (SMPDB))",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2347 (Sequence cluster ID (UniRef100))",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2347 (Sequence cluster ID (UniRef100))",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1114 (Sequence motif identifier)",
# ...
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2905 (Lipid accession)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2732 (Family name)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2732 (Family name)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2771 (HIX ID)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2771 (HIX ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1102 (Gramene primary identifier)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1102 (Gramene primary identifier)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2913 (Virus identifier)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2913 (Virus identifier)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2891 (Biological model accession)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2891 (Biological model accession)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2835 (Gene ID (VBASE2))",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2835 (Gene ID (VBASE2))",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2903 (Genome accession)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2903 (Genome accession)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2782 (SMART domain name)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2782 (SMART domain name)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1085 (Biological model ID)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1085 (Biological model ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1899 (Locus ID (CMR))",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1899 (Locus ID (CMR))",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_0990 (Compound name)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_0990 (Compound name)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2812 (Lipid identifier)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2812 (Lipid identifier)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2299 (Gene name)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2299 (Gene name)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2317 (Cell line name (exact))",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2317 (Cell line name (exact))",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2608 (Reaction ID (KEGG))",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1076 (Codon usage table name)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1076 (Codon usage table name)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1087 (Ontology concept ID)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1087 (Ontology concept ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2664 (GlycomeDB ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_0983 (Atom ID)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_0983 (Atom ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_3856 (RNA central ID)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_3856 (RNA central ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2704 (Clone ID (IMAGE))",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2704 (Clone ID (IMAGE))",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2617 (Signaling Gateway protein ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2133 (Logical operator)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2133 (Logical operator)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1875 (NCBI taxon)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1875 (NCBI taxon)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1873 (iHOP organism ID)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1873 (iHOP organism ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2565 (Amino acid name (full name))",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2565 (Amino acid name (full name))",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2761 (UTRSite ID)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2761 (UTRSite ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1188 (DOI)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1175 (BioPax concept ID)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1175 (BioPax concept ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2902 (Data resource definition accession)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2902 (Data resource definition accession)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2109 (Identifier (hybrid))",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2109 (Identifier (hybrid))",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1146 (EMDB ID)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1146 (EMDB ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1015 (Sequence feature ID)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1015 (Sequence feature ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_3759 (ProteomeXchange ID)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_3759 (ProteomeXchange ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2745 (Locus ID (UTR))",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2745 (Locus ID (UTR))",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2797 (Protein ID (LGICdb))",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2797 (Protein ID (LGICdb))",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1689 (Username)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1689 (Username)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2611 (ICD identifier)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1035 (Gene ID (GeneDB))",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1165 (MIRIAM data type primary name)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1165 (MIRIAM data type primary name)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1038 (Protein domain ID)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1038 (Protein domain ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1126 (Comparison matrix name)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1126 (Comparison matrix name)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1113 (Sequence cluster ID (COG))",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1113 (Sequence cluster ID (COG))",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2668 (iRefIndex ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2605 (Compound ID (KEGG))",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1901 (Locus ID (SGD))",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1901 (Locus ID (SGD))",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2786 (NCBI Genome Project ID)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2786 (NCBI Genome Project ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2285 (Gene ID (MIPS))",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2285 (Gene ID (MIPS))",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2342 (Pathway or network name)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2342 (Pathway or network name)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1897 (Locus ID (MGG))",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1897 (Locus ID (MGG))",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2220 (Sequence cluster ID (SYSTERS))",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2220 (Sequence cluster ID (SYSTERS))",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1195 (Tool name (EMBASSY package))",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1195 (Tool name (EMBASSY package))",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2757 (Pfam domain name)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2896 (Toxin name)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2896 (Toxin name)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_3104 (UNII)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_3104 (UNII)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1133 (InterPro accession)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2105 (Compound ID (BioCyc))",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2105 (Compound ID (BioCyc))",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2709 (CleanEx entry name)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2709 (CleanEx entry name)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_0994 (Amino acid identifier)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_0994 (Amino acid identifier)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2099 (Name)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2099 (Name)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2795 (ORF identifier)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2795 (ORF identifier)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2102 (KEGG organism code)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2102 (KEGG organism code)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_3022 (NCBI genetic code ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2741 (ABS ID)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2741 (ABS ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2665 (LipidBank ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2702 (Enzyme ID (CAZy))",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2702 (Enzyme ID (CAZy))",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2898 (Monosaccharide accession)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2898 (Monosaccharide accession)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1185 (MGED concept ID)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1185 (MGED concept ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1063 (Sequence identifier)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1063 (Sequence identifier)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1074 (Protein interaction ID)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1074 (Protein interaction ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1135 (Gene3D ID)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1135 (Gene3D ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_0988 (Peptide identifier)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_0988 (Peptide identifier)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2367 (ASTD ID)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2367 (ASTD ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1081 (Genotype and phenotype annotation ID)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1081 (Genotype and phenotype annotation ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2325 (REBASE enzyme number)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2325 (REBASE enzyme number)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2389 (UniSTS accession)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2389 (UniSTS accession)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2775 (Kinase name)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2775 (Kinase name)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_1167 (Taverna workflow ID)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_1167 (Taverna workflow ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2618 (Protein modification ID)",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2618 (Protein modification ID)",
#         "INFO Missing property (documentation) on ::: http://edamontology.org/data_2783 (Protein family ID (PANTHER))",
#         "INFO Missing property (regex) on ::: http://edamontology.org/data_2783 (Protein family ID (PANTHER))"
#     ],
#     "status": "NOERR",
#     "test_name": "identifierPropertyMissing"
# }
