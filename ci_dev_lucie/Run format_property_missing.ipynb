# %%
from rdflib import ConjunctiveGraph, Namespace
import json
import os


# Constants for script error reporting as per https://github.com/edamontology/edamverify.
NOERR = "NOERR"
INFO  = "INFO"
WARN  = "WARN"
ERROR = "ERROR"

#Load EDAM_dev.owl from GitHub into an RDF graph.
print("Loading graph ...", end="")
g = ConjunctiveGraph()
g.load(os.environ.get('EDAM_PATH', '../edamontology/EDAM_dev.owl'), format='xml')
#g.load('https://raw.githubusercontent.com/edamontology/edamontology/master/EDAM_dev.owl', format='xml')
# g.load('EDAM_dev.owl', format='xml')
g.bind('edam', Namespace('http://edamontology.org#'))
print("done!")
# Out:
# Loading graph ...done!

# %%
    query = "format_property_missing.rq"
    with open(query,'r') as f:
        query_term = f.read()
  
        errfound = False
        report = list()
        results = g.query(query_term)
        print(len(results))
        for r in results:
            print(f"{r['entity']} , '{r['label']}', is missing mandatory format property: {r['property']}  ")
    f.close()
# Out:
# 2022
# http://edamontology.org/format_1196 , 'SMILES', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_1196 , 'SMILES', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_1196 , 'SMILES', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_1197 , 'InChI', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_1197 , 'InChI', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_1197 , 'InChI', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_1197 , 'InChI', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_1198 , 'mf', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_1198 , 'mf', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_1198 , 'mf', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_1198 , 'mf', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_1199 , 'InChIKey', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_1199 , 'InChIKey', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_1199 , 'InChIKey', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_1199 , 'InChIKey', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_1200 , 'smarts', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_1200 , 'smarts', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_1200 , 'smarts', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_1200 , 'smarts', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_1206 , 'unambiguous pure', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_1206 , 'unambiguous pure', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_1206 , 'unambiguous pure', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_1206 , 'unambiguous pure', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_1207 , 'nucleotide', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_1207 , 'nucleotide', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_1207 , 'nucleotide', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_1207 , 'nucleotide', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_1208 , 'protein', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_1208 , 'protein', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_1208 , 'protein', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_1208 , 'protein', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_1209 , 'consensus', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_1209 , 'consensus', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_1209 , 'consensus', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_1209 , 'consensus', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_1210 , 'pure nucleotide', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_1210 , 'pure nucleotide', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_1210 , 'pure nucleotide', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_1210 , 'pure nucleotide', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_1211 , 'unambiguous pure nucleotide', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_1211 , 'unambiguous pure nucleotide', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_1211 , 'unambiguous pure nucleotide', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_1211 , 'unambiguous pure nucleotide', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_1212 , 'dna', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_1212 , 'dna', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_1212 , 'dna', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_1212 , 'dna', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_1213 , 'rna', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_1213 , 'rna', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_1213 , 'rna', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_1213 , 'rna', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_1214 , 'unambiguous pure dna', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_1214 , 'unambiguous pure dna', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_1214 , 'unambiguous pure dna', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_1214 , 'unambiguous pure dna', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_1215 , 'pure dna', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_1215 , 'pure dna', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_1215 , 'pure dna', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_1215 , 'pure dna', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_1216 , 'unambiguous pure rna sequence', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_1216 , 'unambiguous pure rna sequence', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_1216 , 'unambiguous pure rna sequence', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_1216 , 'unambiguous pure rna sequence', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_1217 , 'pure rna', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_1217 , 'pure rna', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_1217 , 'pure rna', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_1217 , 'pure rna', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_1218 , 'unambiguous pure protein', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_1218 , 'unambiguous pure protein', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_1218 , 'unambiguous pure protein', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_1218 , 'unambiguous pure protein', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_1219 , 'pure protein', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_1219 , 'pure protein', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_1219 , 'pure protein', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_1219 , 'pure protein', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_1248 , 'EMBL feature location', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_1248 , 'EMBL feature location', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_1248 , 'EMBL feature location', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_1248 , 'EMBL feature location', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_1295 , 'quicktandem', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_1295 , 'quicktandem', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_1295 , 'quicktandem', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_1295 , 'quicktandem', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_1296 , 'Sanger inverted repeats', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_1296 , 'Sanger inverted repeats', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_1296 , 'Sanger inverted repeats', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_1296 , 'Sanger inverted repeats', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_1297 , 'EMBOSS repeat', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_1297 , 'EMBOSS repeat', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_1297 , 'EMBOSS repeat', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_1297 , 'EMBOSS repeat', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_1316 , 'est2genome format', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_1316 , 'est2genome format', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_1316 , 'est2genome format', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_1316 , 'est2genome format', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_1318 , 'restrict format', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_1318 , 'restrict format', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_1318 , 'restrict format', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_1318 , 'restrict format', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_1319 , 'restover format', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_1319 , 'restover format', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_1319 , 'restover format', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_1319 , 'restover format', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_1320 , 'REBASE restriction sites', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_1320 , 'REBASE restriction sites', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_1320 , 'REBASE restriction sites', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_1320 , 'REBASE restriction sites', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_1332 , 'FASTA search results format', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_1332 , 'FASTA search results format', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_1332 , 'FASTA search results format', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_1332 , 'FASTA search results format', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_1333 , 'BLAST results', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_1333 , 'BLAST results', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_1333 , 'BLAST results', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_1333 , 'BLAST results', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_1334 , 'mspcrunch', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_1334 , 'mspcrunch', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_1334 , 'mspcrunch', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_1334 , 'mspcrunch', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_1335 , 'Smith-Waterman format', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_1335 , 'Smith-Waterman format', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_1335 , 'Smith-Waterman format', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_1335 , 'Smith-Waterman format', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_1336 , 'dhf', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_1336 , 'dhf', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_1336 , 'dhf', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_1336 , 'dhf', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_1337 , 'lhf', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_1337 , 'lhf', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_1337 , 'lhf', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_1337 , 'lhf', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_1341 , 'InterPro hits format', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_1341 , 'InterPro hits format', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_1341 , 'InterPro hits format', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_1341 , 'InterPro hits format', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_1342 , 'InterPro protein view report format', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_1342 , 'InterPro protein view report format', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_1342 , 'InterPro protein view report format', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_1342 , 'InterPro protein view report format', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_1343 , 'InterPro match table format', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_1343 , 'InterPro match table format', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_1343 , 'InterPro match table format', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_1343 , 'InterPro match table format', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_1349 , 'HMMER Dirichlet prior', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_1349 , 'HMMER Dirichlet prior', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_1349 , 'HMMER Dirichlet prior', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_1349 , 'HMMER Dirichlet prior', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_1350 , 'MEME Dirichlet prior', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_1350 , 'MEME Dirichlet prior', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_1350 , 'MEME Dirichlet prior', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_1350 , 'MEME Dirichlet prior', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_1351 , 'HMMER emission and transition', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_1351 , 'HMMER emission and transition', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_1351 , 'HMMER emission and transition', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_1351 , 'HMMER emission and transition', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_1356 , 'prosite-pattern', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_1356 , 'prosite-pattern', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_1356 , 'prosite-pattern', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_1356 , 'prosite-pattern', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_1357 , 'EMBOSS sequence pattern', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_1357 , 'EMBOSS sequence pattern', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_1357 , 'EMBOSS sequence pattern', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_1357 , 'EMBOSS sequence pattern', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_1360 , 'meme-motif', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_1360 , 'meme-motif', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_1360 , 'meme-motif', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_1360 , 'meme-motif', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_1366 , 'prosite-profile', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_1366 , 'prosite-profile', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_1366 , 'prosite-profile', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_1366 , 'prosite-profile', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_1367 , 'JASPAR format', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_1367 , 'JASPAR format', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_1367 , 'JASPAR format', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_1367 , 'JASPAR format', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_1369 , 'MEME background Markov model', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_1369 , 'MEME background Markov model', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_1369 , 'MEME background Markov model', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_1369 , 'MEME background Markov model', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_1370 , 'HMMER format', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_1370 , 'HMMER format', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_1370 , 'HMMER format', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_1370 , 'HMMER format', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_1391 , 'HMMER-aln', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_1391 , 'HMMER-aln', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_1391 , 'HMMER-aln', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_1391 , 'HMMER-aln', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_1392 , 'DIALIGN format', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_1392 , 'DIALIGN format', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_1392 , 'DIALIGN format', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_1392 , 'DIALIGN format', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_1393 , 'daf', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_1393 , 'daf', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_1393 , 'daf', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_1393 , 'daf', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_1419 , 'Sequence-MEME profile alignment', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_1419 , 'Sequence-MEME profile alignment', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_1419 , 'Sequence-MEME profile alignment', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_1419 , 'Sequence-MEME profile alignment', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_1421 , 'HMMER profile alignment (sequences versus HMMs)', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_1421 , 'HMMER profile alignment (sequences versus HMMs)', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_1421 , 'HMMER profile alignment (sequences versus HMMs)', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_1421 , 'HMMER profile alignment (sequences versus HMMs)', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_1422 , 'HMMER profile alignment (HMM versus sequences)', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_1422 , 'HMMER profile alignment (HMM versus sequences)', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_1422 , 'HMMER profile alignment (HMM versus sequences)', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_1422 , 'HMMER profile alignment (HMM versus sequences)', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_1423 , 'Phylip distance matrix', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_1423 , 'Phylip distance matrix', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_1423 , 'Phylip distance matrix', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_1423 , 'Phylip distance matrix', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_1424 , 'ClustalW dendrogram', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_1424 , 'ClustalW dendrogram', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_1424 , 'ClustalW dendrogram', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_1424 , 'ClustalW dendrogram', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_1425 , 'Phylip tree raw', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_1425 , 'Phylip tree raw', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_1425 , 'Phylip tree raw', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_1425 , 'Phylip tree raw', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_1430 , 'Phylip continuous quantitative characters', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_1430 , 'Phylip continuous quantitative characters', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_1430 , 'Phylip continuous quantitative characters', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_1430 , 'Phylip continuous quantitative characters', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_1432 , 'Phylip character frequencies format', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_1432 , 'Phylip character frequencies format', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_1432 , 'Phylip character frequencies format', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_1432 , 'Phylip character frequencies format', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_1433 , 'Phylip discrete states format', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_1433 , 'Phylip discrete states format', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_1433 , 'Phylip discrete states format', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_1433 , 'Phylip discrete states format', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_1434 , 'Phylip cliques format', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_1434 , 'Phylip cliques format', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_1434 , 'Phylip cliques format', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_1434 , 'Phylip cliques format', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_1435 , 'Phylip tree format', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_1435 , 'Phylip tree format', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_1435 , 'Phylip tree format', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_1435 , 'Phylip tree format', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_1436 , 'TreeBASE format', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_1436 , 'TreeBASE format', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_1436 , 'TreeBASE format', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_1436 , 'TreeBASE format', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_1437 , 'TreeFam format', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_1437 , 'TreeFam format', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_1437 , 'TreeFam format', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_1437 , 'TreeFam format', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_1445 , 'Phylip tree distance format', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_1445 , 'Phylip tree distance format', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_1445 , 'Phylip tree distance format', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_1445 , 'Phylip tree distance format', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_1454 , 'dssp', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_1454 , 'dssp', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_1454 , 'dssp', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_1454 , 'dssp', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_1455 , 'hssp', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_1455 , 'hssp', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_1455 , 'hssp', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_1455 , 'hssp', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_1457 , 'Dot-bracket format', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_1457 , 'Dot-bracket format', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_1457 , 'Dot-bracket format', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_1457 , 'Dot-bracket format', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_1458 , 'Vienna local RNA secondary structure format', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_1458 , 'Vienna local RNA secondary structure format', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_1458 , 'Vienna local RNA secondary structure format', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_1458 , 'Vienna local RNA secondary structure format', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_1475 , 'PDB database entry format', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_1475 , 'PDB database entry format', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_1475 , 'PDB database entry format', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_1476 , 'PDB', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_1476 , 'PDB', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_1476 , 'PDB', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_1476 , 'PDB', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_1477 , 'mmCIF', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_1477 , 'mmCIF', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_1477 , 'mmCIF', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_1477 , 'mmCIF', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_1478 , 'PDBML', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_1478 , 'PDBML', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_1478 , 'PDBML', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_1478 , 'PDBML', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_1504 , 'aaindex', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_1504 , 'aaindex', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_1504 , 'aaindex', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_1504 , 'aaindex', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_1551 , 'Pcons report format', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_1551 , 'Pcons report format', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_1551 , 'Pcons report format', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_1551 , 'Pcons report format', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_1552 , 'ProQ report format', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_1552 , 'ProQ report format', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_1552 , 'ProQ report format', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_1552 , 'ProQ report format', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_1582 , 'findkm', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_1582 , 'findkm', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_1582 , 'findkm', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_1582 , 'findkm', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_1627 , 'Primer3 primer', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_1627 , 'Primer3 primer', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_1627 , 'Primer3 primer', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_1627 , 'Primer3 primer', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_1628 , 'ABI', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_1628 , 'ABI', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_1628 , 'ABI', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_1628 , 'ABI', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_1629 , 'mira', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_1629 , 'mira', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_1629 , 'mira', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_1629 , 'mira', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_1630 , 'CAF', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_1630 , 'CAF', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_1631 , 'EXP', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_1631 , 'EXP', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_1631 , 'EXP', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_1632 , 'SCF', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_1632 , 'SCF', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_1632 , 'SCF', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_1633 , 'PHD', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_1633 , 'PHD', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_1633 , 'PHD', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_1637 , 'dat', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_1637 , 'dat', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_1637 , 'dat', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_1638 , 'cel', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_1638 , 'cel', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_1638 , 'cel', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_1639 , 'affymetrix', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_1639 , 'affymetrix', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_1639 , 'affymetrix', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_1639 , 'affymetrix', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_1641 , 'affymetrix-exp', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_1641 , 'affymetrix-exp', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_1641 , 'affymetrix-exp', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_1641 , 'affymetrix-exp', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_1644 , 'CHP', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_1665 , 'Taverna workflow format', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_1665 , 'Taverna workflow format', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_1665 , 'Taverna workflow format', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_1665 , 'Taverna workflow format', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_1705 , 'HET group dictionary entry format', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_1705 , 'HET group dictionary entry format', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_1705 , 'HET group dictionary entry format', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_1705 , 'HET group dictionary entry format', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_1734 , 'PubMed citation', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_1734 , 'PubMed citation', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_1734 , 'PubMed citation', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_1734 , 'PubMed citation', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_1735 , 'Medline Display Format', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_1735 , 'Medline Display Format', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_1735 , 'Medline Display Format', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_1735 , 'Medline Display Format', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_1736 , 'CiteXplore-core', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_1736 , 'CiteXplore-core', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_1736 , 'CiteXplore-core', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_1736 , 'CiteXplore-core', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_1737 , 'CiteXplore-all', is missing mandatory format property: http://edamontology.org/documentation
# ...
# http://edamontology.org/format_3884 , 'FF parameter format', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_3885 , 'BinPos', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_3885 , 'BinPos', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_3885 , 'BinPos', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_3885 , 'BinPos', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_3886 , 'RST', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_3886 , 'RST', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_3886 , 'RST', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_3887 , 'CHARMM rtf', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_3887 , 'CHARMM rtf', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_3887 , 'CHARMM rtf', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_3887 , 'CHARMM rtf', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_3888 , 'AMBER frcmod', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_3888 , 'AMBER frcmod', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_3888 , 'AMBER frcmod', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_3889 , 'AMBER off', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_3889 , 'AMBER off', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_3889 , 'AMBER off', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_3906 , 'NMReDATA', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_3906 , 'NMReDATA', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_3906 , 'NMReDATA', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_3906 , 'NMReDATA', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_3909 , 'BpForms', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_3909 , 'BpForms', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_3910 , 'trr', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_3910 , 'trr', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_3910 , 'trr', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_3951 , 'BcForms', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_3951 , 'BcForms', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_3956 , 'N-Quads', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_3956 , 'N-Quads', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_3969 , 'Vega', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_3970 , 'Vega-lite', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_3971 , 'NeuroML', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_3973 , 'Docker image', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_3973 , 'Docker image', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_3975 , 'GFA 1', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_3976 , 'GFA 2', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_3978 , 'CONTIG', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_3978 , 'CONTIG', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_3978 , 'CONTIG', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_3979 , 'WEGO', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_3979 , 'WEGO', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_3979 , 'WEGO', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_3980 , 'RPKM', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_3980 , 'RPKM', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_3980 , 'RPKM', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_3981 , 'TAR format', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_3981 , 'TAR format', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_3982 , 'CHAIN', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_3982 , 'CHAIN', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_3982 , 'CHAIN', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_3983 , 'NET', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_3983 , 'NET', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_3983 , 'NET', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_3984 , 'QMAP', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_3984 , 'QMAP', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_3984 , 'QMAP', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_3985 , 'gxformat2', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_3985 , 'gxformat2', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_3985 , 'gxformat2', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_3986 , 'WMV', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_3986 , 'WMV', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_3986 , 'WMV', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_3987 , 'ZIP format', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_3987 , 'ZIP format', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_3988 , 'LSM', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_3988 , 'LSM', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_3988 , 'LSM', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_3989 , 'GZIP format', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_3989 , 'GZIP format', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_3990 , 'AVI', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_3990 , 'AVI', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_3990 , 'AVI', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_3991 , 'TrackDB', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_3991 , 'TrackDB', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_3991 , 'TrackDB', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_3992 , 'CIGAR format', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_3992 , 'CIGAR format', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_3992 , 'CIGAR format', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_3993 , 'Stereolithography format', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_3993 , 'Stereolithography format', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_3993 , 'Stereolithography format', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_3994 , 'U3D', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_3994 , 'U3D', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_3994 , 'U3D', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_3995 , 'Texture file format', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_3995 , 'Texture file format', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_3995 , 'Texture file format', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_3996 , 'Python script', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_3996 , 'Python script', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_3996 , 'Python script', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_3997 , 'MPEG-4', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_3997 , 'MPEG-4', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_3997 , 'MPEG-4', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_3998 , 'Perl script', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_3998 , 'Perl script', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_3998 , 'Perl script', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_3999 , 'R script', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_3999 , 'R script', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_3999 , 'R script', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_4000 , 'R markdown', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_4000 , 'R markdown', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_4000 , 'R markdown', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_4002 , 'pickle', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_4002 , 'pickle', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_4003 , 'NumPy format', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_4003 , 'NumPy format', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_4004 , 'SimTools repertoire file format', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_4004 , 'SimTools repertoire file format', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_4005 , 'Configuration file format', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_4005 , 'Configuration file format', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_4006 , 'Zstandard format', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_4006 , 'Zstandard format', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_4007 , 'MATLAB script', is missing mandatory format property: http://edamontology.org/documentation
# http://edamontology.org/format_4007 , 'MATLAB script', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_4007 , 'MATLAB script', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_4015 , 'PEtab', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_4018 , 'gVCF', is missing mandatory format property: http://edamontology.org/example
# http://edamontology.org/format_4018 , 'gVCF', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_4023 , 'cml', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_4025 , 'BioSimulators format for the specifications of biosimulation tools', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/format_4026 , 'BioSimulators standard for command-line interfaces for biosimulation tools', is missing mandatory format property: http://edamontology.org/file_extension
# http://edamontology.org/format_4026 , 'BioSimulators standard for command-line interfaces for biosimulation tools', is missing mandatory format property: http://edamontology.org/is_format_of
