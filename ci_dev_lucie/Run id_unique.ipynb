# %%
from rdflib import ConjunctiveGraph, Namespace
import json
import os



# Constants for script error reporting as per https://github.com/edamontology/edamverify.
NOERR = "NOERR"
INFO  = "INFO"
WARN  = "WARN"
ERROR = "ERROR"

#Load EDAM_dev.owl from GitHub into an RDF graph.
print("Loading graph ...", end="")
g = ConjunctiveGraph()
g.load(os.environ.get('EDAM_PATH', '../edamontology/EDAM_dev.owl'), format='xml')
#g.load('https://raw.githubusercontent.com/edamontology/edamontology/master/EDAM_dev.owl', format='xml')
# g.load('EDAM_dev.owl', format='xml')
g.bind('edam', Namespace('http://edamontology.org#'))
print("done!")
# Out:
# Loading graph ...done!

# %%
    query = "id_unique.rq"
    with open(query,'r') as f:
        query_term = f.read()
        #print(query_terms)
        # Run SPARQL query and collate results
        errfound = False
        report = list()
        results = g.query(query_term)
        for r in results:
            #if int(r['count'])  != 1 :
            #    print(f"{r['entity']} ")
            print(f" {r['entity']} --- '{r['id']}''{r['count']}'")
# Out:
#  N8de84042bc494757aca98250edeac919 --- '''1'
#  Nf7bdb669c94e44c995e846239fad54c6 --- '''1'
#  http://edamontology.org/data_0005 --- '0005''1'
#  http://edamontology.org/data_0006 --- '0006''1'
#  http://edamontology.org/data_0007 --- '0007''1'
#  http://edamontology.org/data_0581 --- '0581''1'
#  http://edamontology.org/data_0582 --- '0582''1'
#  http://edamontology.org/data_0583 --- '0583''1'
#  http://edamontology.org/data_0831 --- '0831''1'
#  http://edamontology.org/data_0832 --- '0832''1'
#  http://edamontology.org/data_0835 --- '0835''1'
#  http://edamontology.org/data_0842 --- '0842''1'
#  http://edamontology.org/data_0843 --- '0843''1'
#  http://edamontology.org/data_0844 --- '0844''1'
#  http://edamontology.org/data_0845 --- '0845''1'
#  http://edamontology.org/data_0846 --- '0846''1'
#  http://edamontology.org/data_0847 --- '0847''1'
#  http://edamontology.org/data_0848 --- '0848''1'
#  http://edamontology.org/data_0849 --- '0849''1'
#  http://edamontology.org/data_0850 --- '0850''1'
#  http://edamontology.org/data_0851 --- '0851''1'
#  http://edamontology.org/data_0852 --- '0852''1'
#  http://edamontology.org/data_0853 --- '0853''1'
#  http://edamontology.org/data_0854 --- '0854''1'
#  http://edamontology.org/data_0855 --- '0855''1'
#  http://edamontology.org/data_0856 --- '0856''1'
#  http://edamontology.org/data_0857 --- '0857''1'
#  http://edamontology.org/data_0858 --- '0858''1'
#  http://edamontology.org/data_0859 --- '0859''1'
#  http://edamontology.org/data_0860 --- '0860''1'
#  http://edamontology.org/data_0861 --- '0861''1'
#  http://edamontology.org/data_0862 --- '0862''1'
#  http://edamontology.org/data_0863 --- '0863''1'
#  http://edamontology.org/data_0864 --- '0864''1'
#  http://edamontology.org/data_0865 --- '0865''1'
#  http://edamontology.org/data_0866 --- '0866''1'
#  http://edamontology.org/data_0867 --- '0867''1'
#  http://edamontology.org/data_0868 --- '0868''1'
#  http://edamontology.org/data_0869 --- '0869''1'
#  http://edamontology.org/data_0870 --- '0870''1'
#  http://edamontology.org/data_0871 --- '0871''1'
#  http://edamontology.org/data_0872 --- '0872''1'
#  http://edamontology.org/data_0874 --- '0874''1'
#  http://edamontology.org/data_0875 --- '0875''1'
#  http://edamontology.org/data_0876 --- '0876''1'
#  http://edamontology.org/data_0877 --- '0877''1'
#  http://edamontology.org/data_0878 --- '0878''1'
#  http://edamontology.org/data_0879 --- '0879''1'
#  http://edamontology.org/data_0880 --- '0880''1'
#  http://edamontology.org/data_0881 --- '0881''1'
#  http://edamontology.org/data_0882 --- '0882''1'
#  http://edamontology.org/data_0883 --- '0883''1'
#  http://edamontology.org/data_0884 --- '0884''1'
#  http://edamontology.org/data_0885 --- '0885''1'
#  http://edamontology.org/data_0886 --- '0886''1'
#  http://edamontology.org/data_0887 --- '0887''1'
#  http://edamontology.org/data_0888 --- '0888''1'
#  http://edamontology.org/data_0889 --- '0889''1'
#  http://edamontology.org/data_0890 --- '0890''1'
#  http://edamontology.org/data_0891 --- '0891''1'
#  http://edamontology.org/data_0892 --- '0892''1'
#  http://edamontology.org/data_0893 --- '0893''1'
#  http://edamontology.org/data_0894 --- '0894''1'
#  http://edamontology.org/data_0895 --- '0895''1'
#  http://edamontology.org/data_0896 --- '0896''1'
#  http://edamontology.org/data_0897 --- '0897''1'
#  http://edamontology.org/data_0899 --- '0899''1'
#  http://edamontology.org/data_0900 --- '0900''1'
#  http://edamontology.org/data_0901 --- '0901''1'
#  http://edamontology.org/data_0902 --- '0902''1'
#  http://edamontology.org/data_0903 --- '0903''1'
#  http://edamontology.org/data_0904 --- '0904''1'
#  http://edamontology.org/data_0905 --- '0905''1'
#  http://edamontology.org/data_0906 --- '0906''1'
#  http://edamontology.org/data_0907 --- '0907''1'
#  http://edamontology.org/data_0909 --- '0909''1'
#  http://edamontology.org/data_0910 --- '0910''1'
#  http://edamontology.org/data_0911 --- '0911''1'
#  http://edamontology.org/data_0912 --- '0912''1'
#  http://edamontology.org/data_0914 --- '0914''1'
#  http://edamontology.org/data_0916 --- '0916''1'
#  http://edamontology.org/data_0917 --- '0917''1'
#  http://edamontology.org/data_0918 --- '0918''1'
#  http://edamontology.org/data_0919 --- '0919''1'
#  http://edamontology.org/data_0920 --- '0920''1'
#  http://edamontology.org/data_0923 --- '0923''1'
#  http://edamontology.org/data_0924 --- '0924''1'
#  http://edamontology.org/data_0925 --- '0925''1'
#  http://edamontology.org/data_0926 --- '0926''1'
#  http://edamontology.org/data_0927 --- '0927''1'
#  http://edamontology.org/data_0928 --- '0928''1'
#  http://edamontology.org/data_0931 --- '0931''1'
#  http://edamontology.org/data_0932 --- '0932''1'
#  http://edamontology.org/data_0933 --- '0933''1'
#  http://edamontology.org/data_0934 --- '0934''1'
#  http://edamontology.org/data_0935 --- '0935''1'
#  http://edamontology.org/data_0936 --- '0936''1'
#  http://edamontology.org/data_0937 --- '0937''1'
#  http://edamontology.org/data_0938 --- '0938''1'
#  http://edamontology.org/data_0939 --- '0939''1'
#  http://edamontology.org/data_0940 --- '0940''1'
#  http://edamontology.org/data_0941 --- '0941''1'
#  http://edamontology.org/data_0942 --- '0942''1'
#  http://edamontology.org/data_0943 --- '0943''1'
#  http://edamontology.org/data_0944 --- '0944''1'
#  http://edamontology.org/data_0945 --- '0945''1'
#  http://edamontology.org/data_0946 --- '0946''1'
#  http://edamontology.org/data_0947 --- '0947''1'
#  http://edamontology.org/data_0948 --- '0948''1'
#  http://edamontology.org/data_0949 --- '0949''1'
#  http://edamontology.org/data_0950 --- '0950''1'
#  http://edamontology.org/data_0951 --- '0951''1'
#  http://edamontology.org/data_0952 --- '0952''1'
#  http://edamontology.org/data_0953 --- '0953''1'
#  http://edamontology.org/data_0954 --- '0954''1'
#  http://edamontology.org/data_0955 --- '0955''1'
#  http://edamontology.org/data_0956 --- '0956''1'
#  http://edamontology.org/data_0957 --- '0957''1'
#  http://edamontology.org/data_0958 --- '0958''1'
#  http://edamontology.org/data_0959 --- '0959''1'
#  http://edamontology.org/data_0960 --- '0960''1'
#  http://edamontology.org/data_0962 --- '0962''1'
#  http://edamontology.org/data_0963 --- '0963''1'
#  http://edamontology.org/data_0964 --- '0964''1'
#  http://edamontology.org/data_0966 --- '0966''1'
#  http://edamontology.org/data_0967 --- '0967''1'
#  http://edamontology.org/data_0968 --- '0968''1'
#  http://edamontology.org/data_0970 --- '0970''1'
#  http://edamontology.org/data_0971 --- '0971''1'
#  http://edamontology.org/data_0972 --- '0972''1'
#  http://edamontology.org/data_0974 --- '0974''1'
#  http://edamontology.org/data_0975 --- '0975''1'
#  http://edamontology.org/data_0976 --- '0976''1'
#  http://edamontology.org/data_0977 --- '0977''1'
#  http://edamontology.org/data_0978 --- '0978''1'
#  http://edamontology.org/data_0979 --- '0979''1'
#  http://edamontology.org/data_0980 --- '0980''1'
#  http://edamontology.org/data_0981 --- '0981''1'
#  http://edamontology.org/data_0982 --- '0982''1'
#  http://edamontology.org/data_0983 --- '0983''1'
#  http://edamontology.org/data_0984 --- '0984''1'
#  http://edamontology.org/data_0985 --- '0985''1'
#  http://edamontology.org/data_0986 --- '0986''1'
#  http://edamontology.org/data_0987 --- '0987''1'
#  http://edamontology.org/data_0988 --- '0988''1'
#  http://edamontology.org/data_0989 --- '0989''1'
#  http://edamontology.org/data_0990 --- '0990''1'
#  http://edamontology.org/data_0991 --- '0991''1'
#  http://edamontology.org/data_0992 --- '0992''1'
#  http://edamontology.org/data_0993 --- '0993''1'
#  http://edamontology.org/data_0994 --- '0994''1'
#  http://edamontology.org/data_0995 --- '0995''1'
#  http://edamontology.org/data_0996 --- '0996''1'
#  http://edamontology.org/data_0997 --- '0997''1'
#  http://edamontology.org/data_0998 --- '0998''1'
#  http://edamontology.org/data_0999 --- '0999''1'
#  http://edamontology.org/data_1000 --- '1000''1'
#  http://edamontology.org/data_1001 --- '1001''1'
#  http://edamontology.org/data_1002 --- '1002''1'
#  http://edamontology.org/data_1003 --- '1003''1'
#  http://edamontology.org/data_1004 --- '1004''1'
#  http://edamontology.org/data_1005 --- '1005''1'
#  http://edamontology.org/data_1006 --- '1006''1'
#  http://edamontology.org/data_1007 --- '1007''1'
#  http://edamontology.org/data_1008 --- '1008''1'
#  http://edamontology.org/data_1009 --- '1009''1'
#  http://edamontology.org/data_1010 --- '1010''1'
#  http://edamontology.org/data_1011 --- '1011''1'
#  http://edamontology.org/data_1012 --- '1012''1'
#  http://edamontology.org/data_1013 --- '1013''1'
#  http://edamontology.org/data_1014 --- '1014''1'
#  http://edamontology.org/data_1015 --- '1015''1'
#  http://edamontology.org/data_1016 --- '1016''1'
#  http://edamontology.org/data_1017 --- '1017''1'
#  http://edamontology.org/data_1018 --- '1018''1'
#  http://edamontology.org/data_1019 --- '1019''1'
#  http://edamontology.org/data_1020 --- '1020''1'
#  http://edamontology.org/data_1021 --- '1021''1'
#  http://edamontology.org/data_1022 --- '1022''1'
#  http://edamontology.org/data_1023 --- '1023''1'
#  http://edamontology.org/data_1024 --- '1024''1'
#  http://edamontology.org/data_1025 --- '1025''1'
#  http://edamontology.org/data_1026 --- '1026''1'
#  http://edamontology.org/data_1027 --- '1027''1'
#  http://edamontology.org/data_1028 --- '1028''1'
#  http://edamontology.org/data_1029 --- '1029''1'
#  http://edamontology.org/data_1030 --- '1030''1'
#  http://edamontology.org/data_1031 --- '1031''1'
#  http://edamontology.org/data_1032 --- '1032''1'
#  http://edamontology.org/data_1033 --- '1033''1'
#  http://edamontology.org/data_1034 --- '1034''1'
#  http://edamontology.org/data_1035 --- '1035''1'
#  http://edamontology.org/data_1036 --- '1036''1'
#  http://edamontology.org/data_1037 --- '1037''1'
#  http://edamontology.org/data_1038 --- '1038''1'
#  http://edamontology.org/data_1039 --- '1039''1'
#  http://edamontology.org/data_1040 --- '1040''1'
#  http://edamontology.org/data_1041 --- '1041''1'
#  http://edamontology.org/data_1042 --- '1042''1'
#  http://edamontology.org/data_1043 --- '1043''1'
#  http://edamontology.org/data_1044 --- '1044''1'
#  http://edamontology.org/data_1045 --- '1045''1'
#  http://edamontology.org/data_1046 --- '1046''1'
#  http://edamontology.org/data_1047 --- '1047''1'
#  http://edamontology.org/data_1048 --- '1048''1'
#  http://edamontology.org/data_1049 --- '1049''1'
#  http://edamontology.org/data_1050 --- '1050''1'
#  http://edamontology.org/data_1051 --- '1051''1'
#  http://edamontology.org/data_1052 --- '1052''1'
#  http://edamontology.org/data_1053 --- '1053''1'
#  http://edamontology.org/data_1055 --- '1055''1'
#  http://edamontology.org/data_1056 --- '1056''1'
#  http://edamontology.org/data_1057 --- '1057''1'
#  http://edamontology.org/data_1058 --- '1058''1'
#  http://edamontology.org/data_1059 --- '1059''1'
#  http://edamontology.org/data_1060 --- '1060''1'
#  http://edamontology.org/data_1061 --- '1061''1'
#  http://edamontology.org/data_1062 --- '1062''1'
#  http://edamontology.org/data_1063 --- '1063''1'
#  http://edamontology.org/data_1064 --- '1064''1'
#  http://edamontology.org/data_1065 --- '1065''1'
#  http://edamontology.org/data_1066 --- '1066''1'
#  http://edamontology.org/data_1067 --- '1067''1'
#  http://edamontology.org/data_1068 --- '1068''1'
#  http://edamontology.org/data_1069 --- '1069''1'
#  http://edamontology.org/data_1070 --- '1070''1'
#  http://edamontology.org/data_1071 --- '1071''1'
#  http://edamontology.org/data_1072 --- '1072''1'
#  http://edamontology.org/data_1073 --- '1073''1'
#  http://edamontology.org/data_1074 --- '1074''1'
#  http://edamontology.org/data_1075 --- '1075''1'
#  http://edamontology.org/data_1076 --- '1076''1'
#  http://edamontology.org/data_1077 --- '1077''1'
#  http://edamontology.org/data_1078 --- '1078''1'
#  http://edamontology.org/data_1079 --- '1079''1'
#  http://edamontology.org/data_1080 --- '1080''1'
#  http://edamontology.org/data_1081 --- '1081''1'
#  http://edamontology.org/data_1082 --- '1082''1'
#  http://edamontology.org/data_1083 --- '1083''1'
#  http://edamontology.org/data_1084 --- '1084''1'
#  http://edamontology.org/data_1085 --- '1085''1'
#  http://edamontology.org/data_1086 --- '1086''1'
#  http://edamontology.org/data_1087 --- '1087''1'
#  http://edamontology.org/data_1088 --- '1088''1'
#  http://edamontology.org/data_1089 --- '1089''1'
#  http://edamontology.org/data_1091 --- '1091''1'
#  http://edamontology.org/data_1092 --- '1092''1'
#  http://edamontology.org/data_1093 --- '1093''1'
#  http://edamontology.org/data_1094 --- '1094''1'
#  http://edamontology.org/data_1095 --- '1095''1'
#  http://edamontology.org/data_1096 --- '1096''1'
#  http://edamontology.org/data_1097 --- '1097''1'
#  http://edamontology.org/data_1098 --- '1098''1'
#  http://edamontology.org/data_1099 --- '1099''1'
#  http://edamontology.org/data_1100 --- '1100''1'
#  http://edamontology.org/data_1101 --- '1101''1'
#  http://edamontology.org/data_1102 --- '1102''1'
#  http://edamontology.org/data_1103 --- '1103''1'
#  http://edamontology.org/data_1104 --- '1104''1'
#  http://edamontology.org/data_1105 --- '1105''1'
#  http://edamontology.org/data_1106 --- '1106''1'
#  http://edamontology.org/data_1110 --- '1110''1'
#  http://edamontology.org/data_1111 --- '1111''1'
#  http://edamontology.org/data_1112 --- '1112''1'
#  http://edamontology.org/data_1113 --- '1113''1'
#  http://edamontology.org/data_1114 --- '1114''1'
#  http://edamontology.org/data_1115 --- '1115''1'
#  http://edamontology.org/data_1116 --- '1116''1'
#  http://edamontology.org/data_1117 --- '1117''1'
#  http://edamontology.org/data_1118 --- '1118''1'
#  http://edamontology.org/data_1119 --- '1119''1'
#  http://edamontology.org/data_1120 --- '1120''1'
#  http://edamontology.org/data_1121 --- '1121''1'
#  http://edamontology.org/data_1122 --- '1122''1'
#  http://edamontology.org/data_1123 --- '1123''1'
#  http://edamontology.org/data_1124 --- '1124''1'
#  http://edamontology.org/data_1125 --- '1125''1'
#  http://edamontology.org/data_1126 --- '1126''1'
#  http://edamontology.org/data_1127 --- '1127''1'
#  http://edamontology.org/data_1128 --- '1128''1'
#  http://edamontology.org/data_1129 --- '1129''1'
#  http://edamontology.org/data_1130 --- '1130''1'
#  http://edamontology.org/data_1131 --- '1131''1'
#  http://edamontology.org/data_1132 --- '1132''1'
#  http://edamontology.org/data_1133 --- '1133''1'
#  http://edamontology.org/data_1134 --- '1134''1'
#  http://edamontology.org/data_1135 --- '1135''1'
#  http://edamontology.org/data_1136 --- '1136''1'
#  http://edamontology.org/data_1137 --- '1137''1'
#  http://edamontology.org/data_1138 --- '1138''1'
#  http://edamontology.org/data_1139 --- '1139''1'
#  http://edamontology.org/data_1140 --- '1140''1'
#  http://edamontology.org/data_1141 --- '1141''1'
#  http://edamontology.org/data_1142 --- '1142''1'
#  http://edamontology.org/data_1143 --- '1143''1'
#  http://edamontology.org/data_1144 --- '1144''1'
#  http://edamontology.org/data_1145 --- '1145''1'
#  http://edamontology.org/data_1146 --- '1146''1'
#  http://edamontology.org/data_1147 --- '1147''1'
#  http://edamontology.org/data_1148 --- '1148''1'
#  http://edamontology.org/data_1149 --- '1149''1'
#  http://edamontology.org/data_1150 --- '1150''1'
#  http://edamontology.org/data_1151 --- '1151''1'
#  http://edamontology.org/data_1152 --- '1152''1'
#  http://edamontology.org/data_1153 --- '1153''1'
#  http://edamontology.org/data_1154 --- '1154''1'
#  http://edamontology.org/data_1155 --- '1155''1'
#  http://edamontology.org/data_1156 --- '1156''1'
#  http://edamontology.org/data_1157 --- '1157''1'
#  http://edamontology.org/data_1158 --- '1158''1'
#  http://edamontology.org/data_1159 --- '1159''1'
#  http://edamontology.org/data_1160 --- '1160''1'
#  http://edamontology.org/data_1161 --- '1161''1'
#  http://edamontology.org/data_1162 --- '1162''1'
#  http://edamontology.org/data_1163 --- '1163''1'
#  http://edamontology.org/data_1164 --- '1164''1'
#  http://edamontology.org/data_1165 --- '1165''1'
#  http://edamontology.org/data_1166 --- '1166''1'
#  http://edamontology.org/data_1167 --- '1167''1'
#  http://edamontology.org/data_1170 --- '1170''1'
#  http://edamontology.org/data_1171 --- '1171''1'
#  http://edamontology.org/data_1172 --- '1172''1'
#  http://edamontology.org/data_1173 --- '1173''1'
#  http://edamontology.org/data_1174 --- '1174''1'
#  http://edamontology.org/data_1175 --- '1175''1'
#  http://edamontology.org/data_1176 --- '1176''1'
#  http://edamontology.org/data_1177 --- '1177''1'
#  http://edamontology.org/data_1178 --- '1178''1'
#  http://edamontology.org/data_1179 --- '1179''1'
#  http://edamontology.org/data_1180 --- '1180''1'
#  http://edamontology.org/data_1181 --- '1181''1'
#  http://edamontology.org/data_1182 --- '1182''1'
#  http://edamontology.org/data_1183 --- '1183''1'
#  http://edamontology.org/data_1184 --- '1184''1'
#  http://edamontology.org/data_1185 --- '1185''1'
#  http://edamontology.org/data_1186 --- '1186''1'
#  http://edamontology.org/data_1187 --- '1187''1'
#  http://edamontology.org/data_1188 --- '1188''1'
#  http://edamontology.org/data_1189 --- '1189''1'
#  http://edamontology.org/data_1190 --- '1190''1'
#  http://edamontology.org/data_1191 --- '1191''1'
#  http://edamontology.org/data_1192 --- '1192''1'
#  http://edamontology.org/data_1193 --- '1193''1'
#  http://edamontology.org/data_1194 --- '1194''1'
#  http://edamontology.org/data_1195 --- '1195''1'
#  http://edamontology.org/data_1201 --- '1201''1'
#  http://edamontology.org/data_1202 --- '1202''1'
#  http://edamontology.org/data_1203 --- '1203''1'
#  http://edamontology.org/data_1204 --- '1204''1'
#  http://edamontology.org/data_1205 --- '1205''1'
#  http://edamontology.org/data_1233 --- '1233''1'
#  http://edamontology.org/data_1234 --- '1234''1'
#  http://edamontology.org/data_1235 --- '1235''1'
#  http://edamontology.org/data_1236 --- '1236''1'
#  http://edamontology.org/data_1237 --- '1237''1'
#  http://edamontology.org/data_1238 --- '1238''1'
#  http://edamontology.org/data_1239 --- '1239''1'
#  http://edamontology.org/data_1240 --- '1240''1'
#  http://edamontology.org/data_1241 --- '1241''1'
#  http://edamontology.org/data_1242 --- '1242''1'
#  http://edamontology.org/data_1243 --- '1243''1'
#  http://edamontology.org/data_1244 --- '1244''1'
#  http://edamontology.org/data_1245 --- '1245''1'
#  http://edamontology.org/data_1246 --- '1246''1'
#  http://edamontology.org/data_1249 --- '1249''1'
#  http://edamontology.org/data_1250 --- '1250''1'
#  http://edamontology.org/data_1251 --- '1251''1'
#  http://edamontology.org/data_1252 --- '1252''1'
#  http://edamontology.org/data_1253 --- '1253''1'
#  http://edamontology.org/data_1254 --- '1254''1'
#  http://edamontology.org/data_1255 --- '1255''1'
#  http://edamontology.org/data_1256 --- '1256''1'
#  http://edamontology.org/data_1257 --- '1257''1'
#  http://edamontology.org/data_1258 --- '1258''1'
#  http://edamontology.org/data_1259 --- '1259''1'
#  http://edamontology.org/data_1260 --- '1260''1'
#  http://edamontology.org/data_1261 --- '1261''1'
#  http://edamontology.org/data_1262 --- '1262''1'
#  http://edamontology.org/data_1263 --- '1263''1'
#  http://edamontology.org/data_1264 --- '1264''1'
#  http://edamontology.org/data_1265 --- '1265''1'
#  http://edamontology.org/data_1266 --- '1266''1'
#  http://edamontology.org/data_1267 --- '1267''1'
#  http://edamontology.org/data_1268 --- '1268''1'
#  http://edamontology.org/data_1269 --- '1269''1'
#  http://edamontology.org/data_1270 --- '1270''1'
#  http://edamontology.org/data_1274 --- '1274''1'
#  http://edamontology.org/data_1276 --- '1276''1'
#  http://edamontology.org/data_1277 --- '1277''1'
#  http://edamontology.org/data_1278 --- '1278''1'
#  http://edamontology.org/data_1279 --- '1279''1'
#  http://edamontology.org/data_1280 --- '1280''1'
#  http://edamontology.org/data_1281 --- '1281''1'
#  http://edamontology.org/data_1283 --- '1283''1'
#  http://edamontology.org/data_1284 --- '1284''1'
#  http://edamontology.org/data_1285 --- '1285''1'
#  http://edamontology.org/data_1286 --- '1286''1'
#  http://edamontology.org/data_1288 --- '1288''1'
#  http://edamontology.org/data_1289 --- '1289''1'
#  http://edamontology.org/data_1290 --- '1290''1'
#  http://edamontology.org/data_1291 --- '1291''1'
#  http://edamontology.org/data_1292 --- '1292''1'
#  http://edamontology.org/data_1293 --- '1293''1'
#  http://edamontology.org/data_1294 --- '1294''1'
#  http://edamontology.org/data_1298 --- '1298''1'
#  http://edamontology.org/data_1299 --- '1299''1'
#  http://edamontology.org/data_1300 --- '1300''1'
#  http://edamontology.org/data_1301 --- '1301''1'
#  http://edamontology.org/data_1303 --- '1303''1'
#  http://edamontology.org/data_1306 --- '1306''1'
#  http://edamontology.org/data_1309 --- '1309''1'
#  http://edamontology.org/data_1310 --- '1310''1'
#  http://edamontology.org/data_1313 --- '1313''1'
#  http://edamontology.org/data_1314 --- '1314''1'
#  http://edamontology.org/data_1315 --- '1315''1'
#  http://edamontology.org/data_1321 --- '1321''1'
#  http://edamontology.org/data_1322 --- '1322''1'
#  http://edamontology.org/data_1323 --- '1323''1'
#  http://edamontology.org/data_1324 --- '1324''1'
#  http://edamontology.org/data_1325 --- '1325''1'
#  http://edamontology.org/data_1326 --- '1326''1'
#  http://edamontology.org/data_1327 --- '1327''1'
#  http://edamontology.org/data_1328 --- '1328''1'
#  http://edamontology.org/data_1329 --- '1329''1'
#  http://edamontology.org/data_1330 --- '1330''1'
#  http://edamontology.org/data_1331 --- '1331''1'
#  http://edamontology.org/data_1338 --- '1338''1'
#  http://edamontology.org/data_1339 --- '1339''1'
#  http://edamontology.org/data_1340 --- '1340''1'
#  http://edamontology.org/data_1344 --- '1344''1'
#  http://edamontology.org/data_1345 --- '1345''1'
#  http://edamontology.org/data_1346 --- '1346''1'
#  http://edamontology.org/data_1347 --- '1347''1'
#  http://edamontology.org/data_1348 --- '1348''1'
#  http://edamontology.org/data_1352 --- '1352''1'
#  http://edamontology.org/data_1353 --- '1353''1'
#  http://edamontology.org/data_1354 --- '1354''1'
#  http://edamontology.org/data_1355 --- '1355''1'
#  http://edamontology.org/data_1358 --- '1358''1'
#  http://edamontology.org/data_1359 --- '1359''1'
#  http://edamontology.org/data_1361 --- '1361''1'
#  http://edamontology.org/data_1362 --- '1362''1'
#  http://edamontology.org/data_1363 --- '1363''1'
#  http://edamontology.org/data_1364 --- '1364''1'
#  http://edamontology.org/data_1365 --- '1365''1'
#  http://edamontology.org/data_1368 --- '1368''1'
#  http://edamontology.org/data_1371 --- '1371''1'
#  http://edamontology.org/data_1372 --- '1372''1'
#  http://edamontology.org/data_1373 --- '1373''1'
#  http://edamontology.org/data_1374 --- '1374''1'
#  http://edamontology.org/data_1375 --- '1375''1'
#  http://edamontology.org/data_1376 --- '1376''1'
#  http://edamontology.org/data_1377 --- '1377''1'
#  http://edamontology.org/data_1378 --- '1378''1'
#  http://edamontology.org/data_1379 --- '1379''1'
#  http://edamontology.org/data_1380 --- '1380''1'
#  http://edamontology.org/data_1381 --- '1381''1'
#  http://edamontology.org/data_1382 --- '1382''1'
#  http://edamontology.org/data_1383 --- '1383''1'
#  http://edamontology.org/data_1384 --- '1384''1'
#  http://edamontology.org/data_1385 --- '1385''1'
#  http://edamontology.org/data_1386 --- '1386''1'
#  http://edamontology.org/data_1387 --- '1387''1'
#  http://edamontology.org/data_1388 --- '1388''1'
#  http://edamontology.org/data_1389 --- '1389''1'
#  http://edamontology.org/data_1390 --- '1390''1'
#  http://edamontology.org/data_1394 --- '1394''1'
#  http://edamontology.org/data_1395 --- '1395''1'
#  http://edamontology.org/data_1396 --- '1396''1'
#  http://edamontology.org/data_1397 --- '1397''1'
#  http://edamontology.org/data_1398 --- '1398''1'
#  http://edamontology.org/data_1399 --- '1399''1'
#  http://edamontology.org/data_1400 --- '1400''1'
#  http://edamontology.org/data_1401 --- '1401''1'
#  http://edamontology.org/data_1402 --- '1402''1'
#  http://edamontology.org/data_1403 --- '1403''1'
#  http://edamontology.org/data_1404 --- '1404''1'
#  http://edamontology.org/data_1405 --- '1405''1'
#  http://edamontology.org/data_1406 --- '1406''1'
#  http://edamontology.org/data_1407 --- '1407''1'
#  http://edamontology.org/data_1408 --- '1408''1'
#  http://edamontology.org/data_1409 --- '1409''1'
#  http://edamontology.org/data_1410 --- '1410''1'
#  http://edamontology.org/data_1411 --- '1411''1'
#  http://edamontology.org/data_1412 --- '1412''1'
#  http://edamontology.org/data_1413 --- '1413''1'
#  http://edamontology.org/data_1414 --- '1414''1'
#  http://edamontology.org/data_1415 --- '1415''1'
#  http://edamontology.org/data_1416 --- '1416''1'
#  http://edamontology.org/data_1417 --- '1417''1'
#  http://edamontology.org/data_1418 --- '1418''1'
#  http://edamontology.org/data_1420 --- '1420''1'
#  http://edamontology.org/data_1426 --- '1426''1'
#  http://edamontology.org/data_1427 --- '1427''1'
#  http://edamontology.org/data_1428 --- '1428''1'
#  http://edamontology.org/data_1429 --- '1429''1'
#  http://edamontology.org/data_1438 --- '1438''1'
#  http://edamontology.org/data_1439 --- '1439''1'
#  http://edamontology.org/data_1440 --- '1440''1'
#  http://edamontology.org/data_1441 --- '1441''1'
#  http://edamontology.org/data_1442 --- '1442''1'
#  http://edamontology.org/data_1443 --- '1443''1'
#  http://edamontology.org/data_1444 --- '1444''1'
#  http://edamontology.org/data_1446 --- '1446''1'
#  http://edamontology.org/data_1447 --- '1447''1'
#  http://edamontology.org/data_1448 --- '1448''1'
#  http://edamontology.org/data_1449 --- '1449''1'
#  http://edamontology.org/data_1450 --- '1450''1'
#  http://edamontology.org/data_1451 --- '1451''1'
#  http://edamontology.org/data_1452 --- '1452''1'
#  http://edamontology.org/data_1453 --- '1453''1'
#  http://edamontology.org/data_1459 --- '1459''1'
#  http://edamontology.org/data_1460 --- '1460''1'
#  http://edamontology.org/data_1461 --- '1461''1'
#  http://edamontology.org/data_1462 --- '1462''1'
#  http://edamontology.org/data_1463 --- '1463''1'
#  http://edamontology.org/data_1464 --- '1464''1'
#  http://edamontology.org/data_1465 --- '1465''1'
#  http://edamontology.org/data_1466 --- '1466''1'
#  http://edamontology.org/data_1467 --- '1467''1'
#  http://edamontology.org/data_1468 --- '1468''1'
#  http://edamontology.org/data_1469 --- '1469''1'
#  http://edamontology.org/data_1470 --- '1470''1'
#  http://edamontology.org/data_1471 --- '1471''1'
#  http://edamontology.org/data_1472 --- '1472''1'
#  http://edamontology.org/data_1473 --- '1473''1'
#  http://edamontology.org/data_1474 --- '1474''1'
#  http://edamontology.org/data_1479 --- '1479''1'
#  http://edamontology.org/data_1480 --- '1480''1'
#  http://edamontology.org/data_1481 --- '1481''1'
#  http://edamontology.org/data_1482 --- '1482''1'
#  http://edamontology.org/data_1483 --- '1483''1'
#  http://edamontology.org/data_1484 --- '1484''1'
#  http://edamontology.org/data_1485 --- '1485''1'
#  http://edamontology.org/data_1486 --- '1486''1'
#  http://edamontology.org/data_1487 --- '1487''1'
#  http://edamontology.org/data_1488 --- '1488''1'
#  http://edamontology.org/data_1489 --- '1489''1'
#  http://edamontology.org/data_1490 --- '1490''1'
#  http://edamontology.org/data_1491 --- '1491''1'
#  http://edamontology.org/data_1492 --- '1492''1'
#  http://edamontology.org/data_1493 --- '1493''1'
#  http://edamontology.org/data_1494 --- '1494''1'
#  http://edamontology.org/data_1495 --- '1495''1'
#  http://edamontology.org/data_1496 --- '1496''1'
#  http://edamontology.org/data_1497 --- '1497''1'
#  http://edamontology.org/data_1498 --- '1498''1'
#  http://edamontology.org/data_1499 --- '1499''1'
#  http://edamontology.org/data_1501 --- '1501''1'
#  http://edamontology.org/data_1502 --- '1502''1'
#  http://edamontology.org/data_1503 --- '1503''1'
#  http://edamontology.org/data_1505 --- '1505''1'
#  http://edamontology.org/data_1506 --- '1506''1'
#  http://edamontology.org/data_1507 --- '1507''1'
#  http://edamontology.org/data_1508 --- '1508''1'
#  http://edamontology.org/data_1509 --- '1509''1'
#  http://edamontology.org/data_1517 --- '1517''1'
#  http://edamontology.org/data_1519 --- '1519''1'
#  http://edamontology.org/data_1520 --- '1520''1'
#  http://edamontology.org/data_1521 --- '1521''1'
#  http://edamontology.org/data_1522 --- '1522''1'
#  http://edamontology.org/data_1523 --- '1523''1'
#  http://edamontology.org/data_1524 --- '1524''1'
#  http://edamontology.org/data_1525 --- '1525''1'
#  http://edamontology.org/data_1526 --- '1526''1'
#  http://edamontology.org/data_1527 --- '1527''1'
#  http://edamontology.org/data_1528 --- '1528''1'
#  http://edamontology.org/data_1529 --- '1529''1'
#  http://edamontology.org/data_1530 --- '1530''1'
#  http://edamontology.org/data_1531 --- '1531''1'
#  http://edamontology.org/data_1532 --- '1532''1'
#  http://edamontology.org/data_1533 --- '1533''1'
#  http://edamontology.org/data_1534 --- '1534''1'
#  http://edamontology.org/data_1536 --- '1536''1'
#  http://edamontology.org/data_1537 --- '1537''1'
#  http://edamontology.org/data_1539 --- '1539''1'
#  http://edamontology.org/data_1540 --- '1540''1'
#  http://edamontology.org/data_1541 --- '1541''1'
#  http://edamontology.org/data_1542 --- '1542''1'
#  http://edamontology.org/data_1543 --- '1543''1'
#  http://edamontology.org/data_1544 --- '1544''1'
#  http://edamontology.org/data_1545 --- '1545''1'
#  http://edamontology.org/data_1546 --- '1546''1'
#  http://edamontology.org/data_1547 --- '1547''1'
#  http://edamontology.org/data_1548 --- '1548''1'
#  http://edamontology.org/data_1549 --- '1549''1'
#  http://edamontology.org/data_1550 --- '1550''1'
#  http://edamontology.org/data_1553 --- '1553''1'
#  http://edamontology.org/data_1554 --- '1554''1'
#  http://edamontology.org/data_1555 --- '1555''1'
#  http://edamontology.org/data_1556 --- '1556''1'
#  http://edamontology.org/data_1557 --- '1557''1'
#  http://edamontology.org/data_1558 --- '1558''1'
#  http://edamontology.org/data_1559 --- '1559''1'
#  http://edamontology.org/data_1560 --- '1560''1'
#  http://edamontology.org/data_1561 --- '1561''1'
#  http://edamontology.org/data_1564 --- '1564''1'
#  http://edamontology.org/data_1565 --- '1565''1'
#  http://edamontology.org/data_1566 --- '1566''1'
#  http://edamontology.org/data_1567 --- '1567''1'
#  http://edamontology.org/data_1583 --- '1583''1'
#  http://edamontology.org/data_1584 --- '1584''1'
#  http://edamontology.org/data_1585 --- '1585''1'
#  http://edamontology.org/data_1586 --- '1586''1'
#  http://edamontology.org/data_1587 --- '1587''1'
#  http://edamontology.org/data_1588 --- '1588''1'
#  http://edamontology.org/data_1589 --- '1589''1'
#  http://edamontology.org/data_1590 --- '1590''1'
#  http://edamontology.org/data_1591 --- '1591''1'
#  http://edamontology.org/data_1592 --- '1592''1'
#  http://edamontology.org/data_1593 --- '1593''1'
#  http://edamontology.org/data_1594 --- '1594''1'
#  http://edamontology.org/data_1595 --- '1595''1'
#  http://edamontology.org/data_1596 --- '1596''1'
#  http://edamontology.org/data_1597 --- '1597''1'
#  http://edamontology.org/data_1598 --- '1598''1'
#  http://edamontology.org/data_1599 --- '1599''1'
#  http://edamontology.org/data_1600 --- '1600''1'
#  http://edamontology.org/data_1601 --- '1601''1'
#  http://edamontology.org/data_1602 --- '1602''1'
#  http://edamontology.org/data_1621 --- '1621''1'
#  http://edamontology.org/data_1622 --- '1622''1'
#  http://edamontology.org/data_1634 --- '1634''1'
#  http://edamontology.org/data_1636 --- '1636''1'
#  http://edamontology.org/data_1642 --- '1642''1'
#  http://edamontology.org/data_1643 --- '1643''1'
#  http://edamontology.org/data_1646 --- '1646''1'
#  http://edamontology.org/data_1656 --- '1656''1'
#  http://edamontology.org/data_1657 --- '1657''1'
#  http://edamontology.org/data_1658 --- '1658''1'
#  http://edamontology.org/data_1659 --- '1659''1'
#  http://edamontology.org/data_1660 --- '1660''1'
#  http://edamontology.org/data_1661 --- '1661''1'
#  http://edamontology.org/data_1662 --- '1662''1'
#  http://edamontology.org/data_1663 --- '1663''1'
#  http://edamontology.org/data_1664 --- '1664''1'
#  http://edamontology.org/data_1667 --- '1667''1'
#  http://edamontology.org/data_1668 --- '1668''1'
#  http://edamontology.org/data_1669 --- '1669''1'
#  http://edamontology.org/data_1670 --- '1670''1'
#  http://edamontology.org/data_1671 --- '1671''1'
#  http://edamontology.org/data_1672 --- '1672''1'
#  http://edamontology.org/data_1673 --- '1673''1'
#  http://edamontology.org/data_1674 --- '1674''1'
#  http://edamontology.org/data_1675 --- '1675''1'
#  http://edamontology.org/data_1676 --- '1676''1'
#  http://edamontology.org/data_1677 --- '1677''1'
#  http://edamontology.org/data_1678 --- '1678''1'
#  http://edamontology.org/data_1679 --- '1679''1'
#  http://edamontology.org/data_1680 --- '1680''1'
#  http://edamontology.org/data_1681 --- '1681''1'
#  http://edamontology.org/data_1682 --- '1682''1'
#  http://edamontology.org/data_1683 --- '1683''1'
#  http://edamontology.org/data_1684 --- '1684''1'
#  http://edamontology.org/data_1685 --- '1685''1'
#  http://edamontology.org/data_1686 --- '1686''1'
#  http://edamontology.org/data_1687 --- '1687''1'
#  http://edamontology.org/data_1688 --- '1688''1'
#  http://edamontology.org/data_1689 --- '1689''1'
#  http://edamontology.org/data_1690 --- '1690''1'
#  http://edamontology.org/data_1691 --- '1691''1'
#  http://edamontology.org/data_1692 --- '1692''1'
#  http://edamontology.org/data_1693 --- '1693''1'
#  http://edamontology.org/data_1694 --- '1694''1'
#  http://edamontology.org/data_1695 --- '1695''1'
#  http://edamontology.org/data_1696 --- '1696''1'
#  http://edamontology.org/data_1707 --- '1707''1'
#  http://edamontology.org/data_1708 --- '1708''1'
#  http://edamontology.org/data_1709 --- '1709''1'
#  http://edamontology.org/data_1710 --- '1710''1'
#  http://edamontology.org/data_1711 --- '1711''1'
#  http://edamontology.org/data_1712 --- '1712''1'
#  http://edamontology.org/data_1713 --- '1713''1'
#  http://edamontology.org/data_1714 --- '1714''1'
#  http://edamontology.org/data_1715 --- '1715''1'
#  http://edamontology.org/data_1716 --- '1716''1'
#  http://edamontology.org/data_1717 --- '1717''1'
#  http://edamontology.org/data_1718 --- '1718''1'
#  http://edamontology.org/data_1719 --- '1719''1'
#  http://edamontology.org/data_1720 --- '1720''1'
#  http://edamontology.org/data_1721 --- '1721''1'
#  http://edamontology.org/data_1722 --- '1722''1'
#  http://edamontology.org/data_1723 --- '1723''1'
#  http://edamontology.org/data_1724 --- '1724''1'
#  http://edamontology.org/data_1725 --- '1725''1'
#  http://edamontology.org/data_1726 --- '1726''1'
#  http://edamontology.org/data_1727 --- '1727''1'
#  http://edamontology.org/data_1728 --- '1728''1'
#  http://edamontology.org/data_1729 --- '1729''1'
#  http://edamontology.org/data_1730 --- '1730''1'
#  http://edamontology.org/data_1731 --- '1731''1'
#  http://edamontology.org/data_1732 --- '1732''1'
#  http://edamontology.org/data_1733 --- '1733''1'
#  http://edamontology.org/data_1738 --- '1738''1'
#  http://edamontology.org/data_1742 --- '1742''1'
#  http://edamontology.org/data_1743 --- '1743''1'
#  http://edamontology.org/data_1744 --- '1744''1'
#  http://edamontology.org/data_1745 --- '1745''1'
#  http://edamontology.org/data_1746 --- '1746''1'
#  http://edamontology.org/data_1748 --- '1748''1'
#  http://edamontology.org/data_1755 --- '1755''1'
#  http://edamontology.org/data_1756 --- '1756''1'
#  http://edamontology.org/data_1757 --- '1757''1'
#  http://edamontology.org/data_1758 --- '1758''1'
#  http://edamontology.org/data_1759 --- '1759''1'
#  http://edamontology.org/data_1762 --- '1762''1'
#  http://edamontology.org/data_1764 --- '1764''1'
#  http://edamontology.org/data_1765 --- '1765''1'
#  http://edamontology.org/data_1766 --- '1766''1'
#  http://edamontology.org/data_1767 --- '1767''1'
#  http://edamontology.org/data_1771 --- '1771''1'
#  http://edamontology.org/data_1772 --- '1772''1'
#  http://edamontology.org/data_1776 --- '1776''1'
#  http://edamontology.org/data_1783 --- '1783''1'
#  http://edamontology.org/data_1784 --- '1784''1'
#  http://edamontology.org/data_1785 --- '1785''1'
#  http://edamontology.org/data_1786 --- '1786''1'
#  http://edamontology.org/data_1787 --- '1787''1'
#  http://edamontology.org/data_1788 --- '1788''1'
#  http://edamontology.org/data_1789 --- '1789''1'
#  http://edamontology.org/data_1790 --- '1790''1'
#  http://edamontology.org/data_1791 --- '1791''1'
#  http://edamontology.org/data_1792 --- '1792''1'
#  http://edamontology.org/data_1793 --- '1793''1'
#  http://edamontology.org/data_1794 --- '1794''1'
#  http://edamontology.org/data_1795 --- '1795''1'
#  http://edamontology.org/data_1796 --- '1796''1'
#  http://edamontology.org/data_1797 --- '1797''1'
#  http://edamontology.org/data_1798 --- '1798''1'
#  http://edamontology.org/data_1799 --- '1799''1'
#  http://edamontology.org/data_1800 --- '1800''1'
#  http://edamontology.org/data_1801 --- '1801''1'
#  http://edamontology.org/data_1802 --- '1802''1'
#  http://edamontology.org/data_1803 --- '1803''1'
#  http://edamontology.org/data_1804 --- '1804''1'
#  http://edamontology.org/data_1805 --- '1805''1'
#  http://edamontology.org/data_1806 --- '1806''1'
#  http://edamontology.org/data_1807 --- '1807''1'
#  http://edamontology.org/data_1852 --- '1852''1'
#  http://edamontology.org/data_1853 --- '1853''1'
#  http://edamontology.org/data_1855 --- '1855''1'
#  http://edamontology.org/data_1856 --- '1856''1'
#  http://edamontology.org/data_1857 --- '1857''1'
#  http://edamontology.org/data_1858 --- '1858''1'
#  http://edamontology.org/data_1859 --- '1859''1'
#  http://edamontology.org/data_1860 --- '1860''1'
#  http://edamontology.org/data_1863 --- '1863''1'
#  http://edamontology.org/data_1864 --- '1864''1'
#  http://edamontology.org/data_1865 --- '1865''1'
#  http://edamontology.org/data_1866 --- '1866''1'
#  http://edamontology.org/data_1867 --- '1867''1'
#  http://edamontology.org/data_1868 --- '1868''1'
#  http://edamontology.org/data_1869 --- '1869''1'
#  http://edamontology.org/data_1870 --- '1870''1'
#  http://edamontology.org/data_1872 --- '1872''1'
#  http://edamontology.org/data_1873 --- '1873''1'
#  http://edamontology.org/data_1874 --- '1874''1'
#  http://edamontology.org/data_1875 --- '1875''1'
#  http://edamontology.org/data_1877 --- '1877''1'
#  http://edamontology.org/data_1878 --- '1878''1'
#  http://edamontology.org/data_1879 --- '1879''1'
#  http://edamontology.org/data_1880 --- '1880''1'
#  http://edamontology.org/data_1881 --- '1881''1'
#  http://edamontology.org/data_1882 --- '1882''1'
#  http://edamontology.org/data_1883 --- '1883''1'
#  http://edamontology.org/data_1884 --- '1884''1'
#  http://edamontology.org/data_1885 --- '1885''1'
#  http://edamontology.org/data_1886 --- '1886''1'
#  http://edamontology.org/data_1887 --- '1887''1'
#  http://edamontology.org/data_1888 --- '1888''1'
#  http://edamontology.org/data_1889 --- '1889''1'
#  http://edamontology.org/data_1890 --- '1890''1'
#  http://edamontology.org/data_1891 --- '1891''1'
#  http://edamontology.org/data_1892 --- '1892''1'
#  http://edamontology.org/data_1893 --- '1893''1'
#  http://edamontology.org/data_1895 --- '1895''1'
#  http://edamontology.org/data_1896 --- '1896''1'
#  http://edamontology.org/data_1897 --- '1897''1'
#  http://edamontology.org/data_1898 --- '1898''1'
#  http://edamontology.org/data_1899 --- '1899''1'
#  http://edamontology.org/data_1900 --- '1900''1'
#  http://edamontology.org/data_1901 --- '1901''1'
#  http://edamontology.org/data_1902 --- '1902''1'
#  http://edamontology.org/data_1903 --- '1903''1'
#  http://edamontology.org/data_1904 --- '1904''1'
#  http://edamontology.org/data_1905 --- '1905''1'
#  http://edamontology.org/data_1906 --- '1906''1'
#  http://edamontology.org/data_1907 --- '1907''1'
#  http://edamontology.org/data_1908 --- '1908''1'
#  http://edamontology.org/data_1916 --- '1916''1'
#  http://edamontology.org/data_1917 --- '1917''1'
#  http://edamontology.org/data_2007 --- '2007''1'
#  http://edamontology.org/data_2009 --- '2009''1'
#  http://edamontology.org/data_2012 --- '2012''1'
#  http://edamontology.org/data_2016 --- '2016''1'
#  http://edamontology.org/data_2018 --- '2018''1'
#  http://edamontology.org/data_2019 --- '2019''1'
#  http://edamontology.org/data_2022 --- '2022''1'
#  http://edamontology.org/data_2023 --- '2023''1'
#  http://edamontology.org/data_2024 --- '2024''1'
#  http://edamontology.org/data_2025 --- '2025''1'
#  http://edamontology.org/data_2026 --- '2026''1'
#  http://edamontology.org/data_2028 --- '2028''1'
#  http://edamontology.org/data_2041 --- '2041''1'
#  http://edamontology.org/data_2042 --- '2042''1'
#  http://edamontology.org/data_2043 --- '2043''1'
#  http://edamontology.org/data_2044 --- '2044''1'
#  http://edamontology.org/data_2046 --- '2046''1'
#  http://edamontology.org/data_2047 --- '2047''1'
#  http://edamontology.org/data_2048 --- '2048''1'
#  http://edamontology.org/data_2050 --- '2050''1'
#  http://edamontology.org/data_2053 --- '2053''1'
#  http://edamontology.org/data_2070 --- '2070''1'
#  http://edamontology.org/data_2071 --- '2071''1'
#  http://edamontology.org/data_2079 --- '2079''1'
#  http://edamontology.org/data_2080 --- '2080''1'
#  http://edamontology.org/data_2081 --- '2081''1'
#  http://edamontology.org/data_2082 --- '2082''1'
#  http://edamontology.org/data_2083 --- '2083''1'
#  http://edamontology.org/data_2084 --- '2084''1'
#  http://edamontology.org/data_2085 --- '2085''1'
#  http://edamontology.org/data_2086 --- '2086''1'
#  http://edamontology.org/data_2087 --- '2087''1'
#  http://edamontology.org/data_2088 --- '2088''1'
#  http://edamontology.org/data_2090 --- '2090''1'
#  http://edamontology.org/data_2091 --- '2091''1'
#  http://edamontology.org/data_2092 --- '2092''1'
#  http://edamontology.org/data_2093 --- '2093''1'
#  http://edamontology.org/data_2098 --- '2098''1'
#  http://edamontology.org/data_2099 --- '2099''1'
#  http://edamontology.org/data_2100 --- '2100''1'
#  http://edamontology.org/data_2101 --- '2101''1'
#  http://edamontology.org/data_2102 --- '2102''1'
#  http://edamontology.org/data_2103 --- '2103''1'
#  http://edamontology.org/data_2104 --- '2104''1'
#  http://edamontology.org/data_2105 --- '2105''1'
#  http://edamontology.org/data_2106 --- '2106''1'
#  http://edamontology.org/data_2107 --- '2107''1'
#  http://edamontology.org/data_2108 --- '2108''1'
#  http://edamontology.org/data_2109 --- '2109''1'
#  http://edamontology.org/data_2110 --- '2110''1'
#  http://edamontology.org/data_2111 --- '2111''1'
#  http://edamontology.org/data_2112 --- '2112''1'
#  http://edamontology.org/data_2113 --- '2113''1'
#  http://edamontology.org/data_2114 --- '2114''1'
#  http://edamontology.org/data_2116 --- '2116''1'
#  http://edamontology.org/data_2117 --- '2117''1'
#  http://edamontology.org/data_2118 --- '2118''1'
#  http://edamontology.org/data_2119 --- '2119''1'
#  http://edamontology.org/data_2126 --- '2126''1'
#  http://edamontology.org/data_2127 --- '2127''1'
#  http://edamontology.org/data_2128 --- '2128''1'
#  http://edamontology.org/data_2129 --- '2129''1'
#  http://edamontology.org/data_2130 --- '2130''1'
#  http://edamontology.org/data_2131 --- '2131''1'
#  http://edamontology.org/data_2132 --- '2132''1'
#  http://edamontology.org/data_2133 --- '2133''1'
#  http://edamontology.org/data_2134 --- '2134''1'
#  http://edamontology.org/data_2135 --- '2135''1'
#  http://edamontology.org/data_2136 --- '2136''1'
#  http://edamontology.org/data_2137 --- '2137''1'
#  http://edamontology.org/data_2139 --- '2139''1'
#  http://edamontology.org/data_2140 --- '2140''1'
#  http://edamontology.org/data_2141 --- '2141''1'
#  http://edamontology.org/data_2142 --- '2142''1'
#  http://edamontology.org/data_2143 --- '2143''1'
#  http://edamontology.org/data_2145 --- '2145''1'
#  http://edamontology.org/data_2146 --- '2146''1'
#  http://edamontology.org/data_2147 --- '2147''1'
#  http://edamontology.org/data_2149 --- '2149''1'
#  http://edamontology.org/data_2150 --- '2150''1'
#  http://edamontology.org/data_2151 --- '2151''1'
#  http://edamontology.org/data_2152 --- '2152''1'
#  http://edamontology.org/data_2154 --- '2154''1'
#  http://edamontology.org/data_2156 --- '2156''1'
#  http://edamontology.org/data_2157 --- '2157''1'
#  http://edamontology.org/data_2160 --- '2160''1'
#  http://edamontology.org/data_2161 --- '2161''1'
#  http://edamontology.org/data_2162 --- '2162''1'
#  http://edamontology.org/data_2163 --- '2163''1'
#  http://edamontology.org/data_2164 --- '2164''1'
#  http://edamontology.org/data_2165 --- '2165''1'
#  http://edamontology.org/data_2166 --- '2166''1'
#  http://edamontology.org/data_2167 --- '2167''1'
#  http://edamontology.org/data_2168 --- '2168''1'
#  http://edamontology.org/data_2169 --- '2169''1'
#  http://edamontology.org/data_2173 --- '2173''1'
#  http://edamontology.org/data_2174 --- '2174''1'
#  http://edamontology.org/data_2176 --- '2176''1'
#  http://edamontology.org/data_2177 --- '2177''1'
#  http://edamontology.org/data_2178 --- '2178''1'
#  http://edamontology.org/data_2179 --- '2179''1'
#  http://edamontology.org/data_2180 --- '2180''1'
#  http://edamontology.org/data_2190 --- '2190''1'
#  http://edamontology.org/data_2191 --- '2191''1'
#  http://edamontology.org/data_2192 --- '2192''1'
#  http://edamontology.org/data_2193 --- '2193''1'
#  http://edamontology.org/data_2198 --- '2198''1'
#  http://edamontology.org/data_2201 --- '2201''1'
#  http://edamontology.org/data_2208 --- '2208''1'
#  http://edamontology.org/data_2209 --- '2209''1'
#  http://edamontology.org/data_2212 --- '2212''1'
#  http://edamontology.org/data_2213 --- '2213''1'
#  http://edamontology.org/data_2214 --- '2214''1'
#  http://edamontology.org/data_2215 --- '2215''1'
#  http://edamontology.org/data_2216 --- '2216''1'
#  http://edamontology.org/data_2217 --- '2217''1'
#  http://edamontology.org/data_2218 --- '2218''1'
#  http://edamontology.org/data_2219 --- '2219''1'
#  http://edamontology.org/data_2220 --- '2220''1'
#  http://edamontology.org/data_2223 --- '2223''1'
#  http://edamontology.org/data_2235 --- '2235''1'
#  http://edamontology.org/data_2236 --- '2236''1'
#  http://edamontology.org/data_2240 --- '2240''1'
#  http://edamontology.org/data_2242 --- '2242''1'
#  http://edamontology.org/data_2245 --- '2245''1'
#  http://edamontology.org/data_2247 --- '2247''1'
#  http://edamontology.org/data_2248 --- '2248''1'
#  http://edamontology.org/data_2249 --- '2249''1'
#  http://edamontology.org/data_2250 --- '2250''1'
#  http://edamontology.org/data_2251 --- '2251''1'
#  http://edamontology.org/data_2252 --- '2252''1'
#  http://edamontology.org/data_2253 --- '2253''1'
#  http://edamontology.org/data_2254 --- '2254''1'
#  http://edamontology.org/data_2285 --- '2285''1'
#  http://edamontology.org/data_2288 --- '2288''1'
#  http://edamontology.org/data_2289 --- '2289''1'
#  http://edamontology.org/data_2290 --- '2290''1'
#  http://edamontology.org/data_2291 --- '2291''1'
#  http://edamontology.org/data_2292 --- '2292''1'
#  http://edamontology.org/data_2293 --- '2293''1'
#  http://edamontology.org/data_2294 --- '2294''1'
#  http://edamontology.org/data_2295 --- '2295''1'
#  http://edamontology.org/data_2296 --- '2296''1'
#  http://edamontology.org/data_2297 --- '2297''1'
#  http://edamontology.org/data_2298 --- '2298''1'
#  http://edamontology.org/data_2299 --- '2299''1'
#  http://edamontology.org/data_2300 --- '2300''1'
#  http://edamontology.org/data_2301 --- '2301''1'
#  http://edamontology.org/data_2302 --- '2302''1'
#  http://edamontology.org/data_2307 --- '2307''1'
#  http://edamontology.org/data_2308 --- '2308''1'
#  http://edamontology.org/data_2309 --- '2309''1'
#  http://edamontology.org/data_2313 --- '2313''1'
#  http://edamontology.org/data_2314 --- '2314''1'
#  http://edamontology.org/data_2315 --- '2315''1'
#  http://edamontology.org/data_2316 --- '2316''1'
#  http://edamontology.org/data_2317 --- '2317''1'
#  http://edamontology.org/data_2318 --- '2318''1'
#  http://edamontology.org/data_2319 --- '2319''1'
#  http://edamontology.org/data_2320 --- '2320''1'
#  http://edamontology.org/data_2321 --- '2321''1'
#  http://edamontology.org/data_2325 --- '2325''1'
#  http://edamontology.org/data_2326 --- '2326''1'
#  http://edamontology.org/data_2327 --- '2327''1'
#  http://edamontology.org/data_2335 --- '2335''1'
#  http://edamontology.org/data_2336 --- '2336''1'
#  http://edamontology.org/data_2337 --- '2337''1'
#  http://edamontology.org/data_2338 --- '2338''1'
#  http://edamontology.org/data_2339 --- '2339''1'
#  http://edamontology.org/data_2340 --- '2340''1'
#  http://edamontology.org/data_2342 --- '2342''1'
#  http://edamontology.org/data_2343 --- '2343''1'
#  http://edamontology.org/data_2344 --- '2344''1'
#  http://edamontology.org/data_2345 --- '2345''1'
#  http://edamontology.org/data_2346 --- '2346''1'
#  http://edamontology.org/data_2347 --- '2347''1'
#  http://edamontology.org/data_2348 --- '2348''1'
#  http://edamontology.org/data_2349 --- '2349''1'
#  http://edamontology.org/data_2353 --- '2353''1'
#  http://edamontology.org/data_2354 --- '2354''1'
#  http://edamontology.org/data_2355 --- '2355''1'
#  http://edamontology.org/data_2356 --- '2356''1'
#  http://edamontology.org/data_2357 --- '2357''1'
#  http://edamontology.org/data_2358 --- '2358''1'
#  http://edamontology.org/data_2359 --- '2359''1'
#  http://edamontology.org/data_2360 --- '2360''1'
#  http://edamontology.org/data_2362 --- '2362''1'
#  http://edamontology.org/data_2363 --- '2363''1'
# ...
#  http://edamontology.org/topic_0779 --- '0779''1'
#  http://edamontology.org/topic_0780 --- '0780''1'
#  http://edamontology.org/topic_0781 --- '0781''1'
#  http://edamontology.org/topic_0782 --- '0782''1'
#  http://edamontology.org/topic_0783 --- '0783''1'
#  http://edamontology.org/topic_0786 --- '0786''1'
#  http://edamontology.org/topic_0787 --- '0787''1'
#  http://edamontology.org/topic_0796 --- '0796''1'
#  http://edamontology.org/topic_0797 --- '0797''1'
#  http://edamontology.org/topic_0798 --- '0798''1'
#  http://edamontology.org/topic_0803 --- '0803''1'
#  http://edamontology.org/topic_0804 --- '0804''1'
#  http://edamontology.org/topic_0820 --- '0820''1'
#  http://edamontology.org/topic_0821 --- '0821''1'
#  http://edamontology.org/topic_0922 --- '0922''1'
#  http://edamontology.org/topic_1302 --- '1302''1'
#  http://edamontology.org/topic_1304 --- '1304''1'
#  http://edamontology.org/topic_1305 --- '1305''1'
#  http://edamontology.org/topic_1307 --- '1307''1'
#  http://edamontology.org/topic_1308 --- '1308''1'
#  http://edamontology.org/topic_1311 --- '1311''1'
#  http://edamontology.org/topic_1312 --- '1312''1'
#  http://edamontology.org/topic_1317 --- '1317''1'
#  http://edamontology.org/topic_1456 --- '1456''1'
#  http://edamontology.org/topic_1770 --- '1770''1'
#  http://edamontology.org/topic_1775 --- '1775''1'
#  http://edamontology.org/topic_1811 --- '1811''1'
#  http://edamontology.org/topic_2225 --- '2225''1'
#  http://edamontology.org/topic_2226 --- '2226''1'
#  http://edamontology.org/topic_2229 --- '2229''1'
#  http://edamontology.org/topic_2230 --- '2230''1'
#  http://edamontology.org/topic_2232 --- '2232''1'
#  http://edamontology.org/topic_2257 --- '2257''1'
#  http://edamontology.org/topic_2258 --- '2258''1'
#  http://edamontology.org/topic_2259 --- '2259''1'
#  http://edamontology.org/topic_2269 --- '2269''1'
#  http://edamontology.org/topic_2271 --- '2271''1'
#  http://edamontology.org/topic_2275 --- '2275''1'
#  http://edamontology.org/topic_2276 --- '2276''1'
#  http://edamontology.org/topic_2277 --- '2277''1'
#  http://edamontology.org/topic_2278 --- '2278''1'
#  http://edamontology.org/topic_2280 --- '2280''1'
#  http://edamontology.org/topic_2397 --- '2397''1'
#  http://edamontology.org/topic_2399 --- '2399''1'
#  http://edamontology.org/topic_2533 --- '2533''1'
#  http://edamontology.org/topic_2640 --- '2640''1'
#  http://edamontology.org/topic_2661 --- '2661''1'
#  http://edamontology.org/topic_2754 --- '2754''1'
#  http://edamontology.org/topic_2807 --- '2807''1'
#  http://edamontology.org/topic_2809 --- '2809''1'
#  http://edamontology.org/topic_2811 --- '2811''1'
#  http://edamontology.org/topic_2813 --- '2813''1'
#  http://edamontology.org/topic_2814 --- '2814''1'
#  http://edamontology.org/topic_2815 --- '2815''1'
#  http://edamontology.org/topic_2816 --- '2816''1'
#  http://edamontology.org/topic_2817 --- '2817''1'
#  http://edamontology.org/topic_2818 --- '2818''1'
#  http://edamontology.org/topic_2819 --- '2819''1'
#  http://edamontology.org/topic_2820 --- '2820''1'
#  http://edamontology.org/topic_2821 --- '2821''1'
#  http://edamontology.org/topic_2826 --- '2826''1'
#  http://edamontology.org/topic_2828 --- '2828''1'
#  http://edamontology.org/topic_2829 --- '2829''1'
#  http://edamontology.org/topic_2830 --- '2830''1'
#  http://edamontology.org/topic_2839 --- '2839''1'
#  http://edamontology.org/topic_2840 --- '2840''1'
#  http://edamontology.org/topic_2842 --- '2842''1'
#  http://edamontology.org/topic_2846 --- '2846''1'
#  http://edamontology.org/topic_2847 --- '2847''1'
#  http://edamontology.org/topic_2867 --- '2867''1'
#  http://edamontology.org/topic_2868 --- '2868''1'
#  http://edamontology.org/topic_2869 --- '2869''1'
#  http://edamontology.org/topic_2885 --- '2885''1'
#  http://edamontology.org/topic_2953 --- '2953''1'
#  http://edamontology.org/topic_3032 --- '3032''1'
#  http://edamontology.org/topic_3038 --- '3038''1'
#  http://edamontology.org/topic_3039 --- '3039''1'
#  http://edamontology.org/topic_3041 --- '3041''1'
#  http://edamontology.org/topic_3042 --- '3042''1'
#  http://edamontology.org/topic_3043 --- '3043''1'
#  http://edamontology.org/topic_3044 --- '3044''1'
#  http://edamontology.org/topic_3047 --- '3047''1'
#  http://edamontology.org/topic_3048 --- '3048''1'
#  http://edamontology.org/topic_3050 --- '3050''1'
#  http://edamontology.org/topic_3052 --- '3052''1'
#  http://edamontology.org/topic_3053 --- '3053''1'
#  http://edamontology.org/topic_3055 --- '3055''1'
#  http://edamontology.org/topic_3056 --- '3056''1'
#  http://edamontology.org/topic_3060 --- '3060''1'
#  http://edamontology.org/topic_3061 --- '3061''1'
#  http://edamontology.org/topic_3062 --- '3062''1'
#  http://edamontology.org/topic_3063 --- '3063''1'
#  http://edamontology.org/topic_3064 --- '3064''1'
#  http://edamontology.org/topic_3065 --- '3065''1'
#  http://edamontology.org/topic_3067 --- '3067''1'
#  http://edamontology.org/topic_3068 --- '3068''1'
#  http://edamontology.org/topic_3070 --- '3070''1'
#  http://edamontology.org/topic_3071 --- '3071''1'
#  http://edamontology.org/topic_3072 --- '3072''1'
#  http://edamontology.org/topic_3073 --- '3073''1'
#  http://edamontology.org/topic_3074 --- '3074''1'
#  http://edamontology.org/topic_3075 --- '3075''1'
#  http://edamontology.org/topic_3077 --- '3077''1'
#  http://edamontology.org/topic_3078 --- '3078''1'
#  http://edamontology.org/topic_3118 --- '3118''1'
#  http://edamontology.org/topic_3120 --- '3120''1'
#  http://edamontology.org/topic_3123 --- '3123''1'
#  http://edamontology.org/topic_3125 --- '3125''1'
#  http://edamontology.org/topic_3126 --- '3126''1'
#  http://edamontology.org/topic_3127 --- '3127''1'
#  http://edamontology.org/topic_3135 --- '3135''1'
#  http://edamontology.org/topic_3139 --- '3139''1'
#  http://edamontology.org/topic_3168 --- '3168''1'
#  http://edamontology.org/topic_3169 --- '3169''1'
#  http://edamontology.org/topic_3170 --- '3170''1'
#  http://edamontology.org/topic_3171 --- '3171''1'
#  http://edamontology.org/topic_3172 --- '3172''1'
#  http://edamontology.org/topic_3173 --- '3173''1'
#  http://edamontology.org/topic_3174 --- '3174''1'
#  http://edamontology.org/topic_3175 --- '3175''1'
#  http://edamontology.org/topic_3176 --- '3176''1'
#  http://edamontology.org/topic_3177 --- '3177''1'
#  http://edamontology.org/topic_3178 --- '3178''1'
#  http://edamontology.org/topic_3179 --- '3179''1'
#  http://edamontology.org/topic_3263 --- '3263''1'
#  http://edamontology.org/topic_3277 --- '3277''1'
#  http://edamontology.org/topic_3292 --- '3292''1'
#  http://edamontology.org/topic_3293 --- '3293''1'
#  http://edamontology.org/topic_3295 --- '3295''1'
#  http://edamontology.org/topic_3297 --- '3297''1'
#  http://edamontology.org/topic_3298 --- '3298''1'
#  http://edamontology.org/topic_3299 --- '3299''1'
#  http://edamontology.org/topic_3300 --- '3300''1'
#  http://edamontology.org/topic_3301 --- '3301''1'
#  http://edamontology.org/topic_3302 --- '3302''1'
#  http://edamontology.org/topic_3303 --- '3303''1'
#  http://edamontology.org/topic_3304 --- '3304''1'
#  http://edamontology.org/topic_3305 --- '3305''1'
#  http://edamontology.org/topic_3306 --- '3306''1'
#  http://edamontology.org/topic_3307 --- '3307''1'
#  http://edamontology.org/topic_3308 --- '3308''1'
#  http://edamontology.org/topic_3314 --- '3314''1'
#  http://edamontology.org/topic_3315 --- '3315''1'
#  http://edamontology.org/topic_3316 --- '3316''1'
#  http://edamontology.org/topic_3318 --- '3318''1'
#  http://edamontology.org/topic_3320 --- '3320''1'
#  http://edamontology.org/topic_3321 --- '3321''1'
#  http://edamontology.org/topic_3322 --- '3322''1'
#  http://edamontology.org/topic_3323 --- '3323''1'
#  http://edamontology.org/topic_3324 --- '3324''1'
#  http://edamontology.org/topic_3325 --- '3325''1'
#  http://edamontology.org/topic_3332 --- '3332''1'
#  http://edamontology.org/topic_3334 --- '3334''1'
#  http://edamontology.org/topic_3335 --- '3335''1'
#  http://edamontology.org/topic_3336 --- '3336''1'
#  http://edamontology.org/topic_3337 --- '3337''1'
#  http://edamontology.org/topic_3338 --- '3338''1'
#  http://edamontology.org/topic_3339 --- '3339''1'
#  http://edamontology.org/topic_3340 --- '3340''1'
#  http://edamontology.org/topic_3341 --- '3341''1'
#  http://edamontology.org/topic_3342 --- '3342''1'
#  http://edamontology.org/topic_3343 --- '3343''1'
#  http://edamontology.org/topic_3344 --- '3344''1'
#  http://edamontology.org/topic_3345 --- '3345''1'
#  http://edamontology.org/topic_3346 --- '3346''1'
#  http://edamontology.org/topic_3360 --- '3360''1'
#  http://edamontology.org/topic_3361 --- '3361''1'
#  http://edamontology.org/topic_3365 --- '3365''1'
#  http://edamontology.org/topic_3366 --- '3366''1'
#  http://edamontology.org/topic_3368 --- '3368''1'
#  http://edamontology.org/topic_3369 --- '3369''1'
#  http://edamontology.org/topic_3370 --- '3370''1'
#  http://edamontology.org/topic_3371 --- '3371''1'
#  http://edamontology.org/topic_3372 --- '3372''1'
#  http://edamontology.org/topic_3373 --- '3373''1'
#  http://edamontology.org/topic_3374 --- '3374''1'
#  http://edamontology.org/topic_3375 --- '3375''1'
#  http://edamontology.org/topic_3376 --- '3376''1'
#  http://edamontology.org/topic_3377 --- '3377''1'
#  http://edamontology.org/topic_3378 --- '3378''1'
#  http://edamontology.org/topic_3379 --- '3379''1'
#  http://edamontology.org/topic_3382 --- '3382''1'
#  http://edamontology.org/topic_3383 --- '3383''1'
#  http://edamontology.org/topic_3384 --- '3384''1'
#  http://edamontology.org/topic_3385 --- '3385''1'
#  http://edamontology.org/topic_3386 --- '3386''1'
#  http://edamontology.org/topic_3387 --- '3387''1'
#  http://edamontology.org/topic_3388 --- '3388''1'
#  http://edamontology.org/topic_3390 --- '3390''1'
#  http://edamontology.org/topic_3391 --- '3391''1'
#  http://edamontology.org/topic_3393 --- '3393''1'
#  http://edamontology.org/topic_3394 --- '3394''1'
#  http://edamontology.org/topic_3395 --- '3395''1'
#  http://edamontology.org/topic_3396 --- '3396''1'
#  http://edamontology.org/topic_3397 --- '3397''1'
#  http://edamontology.org/topic_3398 --- '3398''1'
#  http://edamontology.org/topic_3399 --- '3399''1'
#  http://edamontology.org/topic_3400 --- '3400''1'
#  http://edamontology.org/topic_3401 --- '3401''1'
#  http://edamontology.org/topic_3402 --- '3402''1'
#  http://edamontology.org/topic_3403 --- '3403''1'
#  http://edamontology.org/topic_3404 --- '3404''1'
#  http://edamontology.org/topic_3405 --- '3405''1'
#  http://edamontology.org/topic_3406 --- '3406''1'
#  http://edamontology.org/topic_3407 --- '3407''1'
#  http://edamontology.org/topic_3408 --- '3408''1'
#  http://edamontology.org/topic_3409 --- '3409''1'
#  http://edamontology.org/topic_3410 --- '3410''1'
#  http://edamontology.org/topic_3411 --- '3411''1'
#  http://edamontology.org/topic_3412 --- '3412''1'
#  http://edamontology.org/topic_3413 --- '3413''1'
#  http://edamontology.org/topic_3414 --- '3414''1'
#  http://edamontology.org/topic_3415 --- '3415''1'
#  http://edamontology.org/topic_3416 --- '3416''1'
#  http://edamontology.org/topic_3417 --- '3417''1'
#  http://edamontology.org/topic_3418 --- '3418''1'
#  http://edamontology.org/topic_3419 --- '3419''1'
#  http://edamontology.org/topic_3420 --- '3420''1'
#  http://edamontology.org/topic_3421 --- '3421''1'
#  http://edamontology.org/topic_3422 --- '3422''1'
#  http://edamontology.org/topic_3423 --- '3423''1'
#  http://edamontology.org/topic_3444 --- '3444''1'
#  http://edamontology.org/topic_3448 --- '3448''1'
#  http://edamontology.org/topic_3452 --- '3452''1'
#  http://edamontology.org/topic_3473 --- '3473''1'
#  http://edamontology.org/topic_3474 --- '3474''1'
#  http://edamontology.org/topic_3489 --- '3489''1'
#  http://edamontology.org/topic_3500 --- '3500''1'
#  http://edamontology.org/topic_3510 --- '3510''1'
#  http://edamontology.org/topic_3511 --- '3511''1'
#  http://edamontology.org/topic_3512 --- '3512''1'
#  http://edamontology.org/topic_3514 --- '3514''1'
#  http://edamontology.org/topic_3515 --- '3515''1'
#  http://edamontology.org/topic_3516 --- '3516''1'
#  http://edamontology.org/topic_3517 --- '3517''1'
#  http://edamontology.org/topic_3518 --- '3518''1'
#  http://edamontology.org/topic_3519 --- '3519''1'
#  http://edamontology.org/topic_3520 --- '3520''1'
#  http://edamontology.org/topic_3521 --- '3521''1'
#  http://edamontology.org/topic_3522 --- '3522''1'
#  http://edamontology.org/topic_3523 --- '3523''1'
#  http://edamontology.org/topic_3524 --- '3524''1'
#  http://edamontology.org/topic_3525 --- '3525''1'
#  http://edamontology.org/topic_3526 --- '3526''1'
#  http://edamontology.org/topic_3527 --- '3527''1'
#  http://edamontology.org/topic_3528 --- '3528''1'
#  http://edamontology.org/topic_3529 --- '3529''1'
#  http://edamontology.org/topic_3530 --- '3530''1'
#  http://edamontology.org/topic_3531 --- '3531''1'
#  http://edamontology.org/topic_3533 --- '3533''1'
#  http://edamontology.org/topic_3534 --- '3534''1'
#  http://edamontology.org/topic_3535 --- '3535''1'
#  http://edamontology.org/topic_3536 --- '3536''1'
#  http://edamontology.org/topic_3537 --- '3537''1'
#  http://edamontology.org/topic_3538 --- '3538''1'
#  http://edamontology.org/topic_3539 --- '3539''1'
#  http://edamontology.org/topic_3540 --- '3540''1'
#  http://edamontology.org/topic_3541 --- '3541''1'
#  http://edamontology.org/topic_3542 --- '3542''1'
#  http://edamontology.org/topic_3543 --- '3543''1'
#  http://edamontology.org/topic_3544 --- '3544''1'
#  http://edamontology.org/topic_3569 --- '3569''1'
#  http://edamontology.org/topic_3570 --- '3570''1'
#  http://edamontology.org/topic_3571 --- '3571''1'
#  http://edamontology.org/topic_3572 --- '3572''1'
#  http://edamontology.org/topic_3573 --- '3573''1'
#  http://edamontology.org/topic_3574 --- '3574''1'
#  http://edamontology.org/topic_3575 --- '3575''1'
#  http://edamontology.org/topic_3576 --- '3576''1'
#  http://edamontology.org/topic_3577 --- '3577''1'
#  http://edamontology.org/topic_3656 --- '3656''1'
#  http://edamontology.org/topic_3673 --- '3673''1'
#  http://edamontology.org/topic_3674 --- '3674''1'
#  http://edamontology.org/topic_3676 --- '3676''1'
#  http://edamontology.org/topic_3678 --- '3678''1'
#  http://edamontology.org/topic_3679 --- '3679''1'
#  http://edamontology.org/topic_3697 --- '3697''1'
#  http://edamontology.org/topic_3794 --- '3794''1'
#  http://edamontology.org/topic_3796 --- '3796''1'
#  http://edamontology.org/topic_3810 --- '3810''1'
#  http://edamontology.org/topic_3837 --- '3837''1'
#  http://edamontology.org/topic_3855 --- '3855''1'
#  http://edamontology.org/topic_3892 --- '3892''1'
#  http://edamontology.org/topic_3895 --- '3895''1'
#  http://edamontology.org/topic_3912 --- '3912''1'
#  http://edamontology.org/topic_3922 --- '3922''1'
#  http://edamontology.org/topic_3930 --- '3930''1'
#  http://edamontology.org/topic_3931 --- '3931''1'
#  http://edamontology.org/topic_3934 --- '3934''1'
#  http://edamontology.org/topic_3939 --- '3939''1'
#  http://edamontology.org/topic_3940 --- '3940''1'
#  http://edamontology.org/topic_3941 --- '3941''1'
#  http://edamontology.org/topic_3943 --- '3943''1'
#  http://edamontology.org/topic_3944 --- '3944''1'
#  http://edamontology.org/topic_3945 --- '3945''1'
#  http://edamontology.org/topic_3948 --- '3948''1'
#  http://edamontology.org/topic_3954 --- '3954''1'
#  http://edamontology.org/topic_3955 --- '3955''1'
#  http://edamontology.org/topic_3957 --- '3957''1'
#  http://edamontology.org/topic_3958 --- '3958''1'
#  http://edamontology.org/topic_3959 --- '3959''1'
#  http://edamontology.org/topic_3966 --- '3966''1'
#  http://edamontology.org/topic_3967 --- '3967''1'
#  http://edamontology.org/topic_3974 --- '3974''1'
#  http://edamontology.org/topic_4010 --- '4010''1'
#  http://edamontology.org/topic_4011 --- '4011''1'
#  http://edamontology.org/topic_4012 --- '4012''1'
#  http://edamontology.org/topic_4013 --- '4013''1'
#  http://edamontology.org/topic_4014 --- '4014''1'
#  http://edamontology.org/topic_4016 --- '4016''1'
#  http://edamontology.org/topic_4017 --- '4017''1'
#  http://edamontology.org/topic_4019 --- '4019''1'
#  http://edamontology.org/topic_4020 --- '4020''1'
#  http://edamontology.org/topic_4021 --- '4021''1'
#  http://edamontology.org/topic_4027 --- '4027''1'
#  http://edamontology.org/topic_4028 --- '4028''1'
#  http://edamontology.org/topic_4033 --- '4033''1'
#  http://www.geneontology.org/formats/oboInOwl#ObsoleteClass --- '''1'
#  http://www.w3.org/2002/07/owl#DeprecatedClass --- '''1'
