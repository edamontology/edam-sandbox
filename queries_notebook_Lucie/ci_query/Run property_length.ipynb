# %%
from rdflib import ConjunctiveGraph, Namespace
import json
import os


# Constants for script error reporting as per https://github.com/edamontology/edamverify.
NOERR = "NOERR"
INFO  = "INFO"
WARN  = "WARN"
ERROR = "ERROR"

#Load EDAM_dev.owl from GitHub into an RDF graph.
print("Loading graph ...", end="")
g = ConjunctiveGraph()
g.load(os.environ.get('EDAM_PATH', '../edamontology/EDAM_dev.owl'), format='xml')
#g.load('https://raw.githubusercontent.com/edamontology/edamontology/master/EDAM_dev.owl', format='xml')
# g.load('EDAM_dev.owl', format='xml')
g.bind('edam', Namespace('http://edamontology.org#'))
print("done!")
# Out:
# Loading graph ...done!

# %%
query = "property_length.rq"
with open(query,'r') as f:
    query_term = f.read()

    errfound = False
    report = list()
    results = g.query(query_term)
    print(len(results))
    for r in results:
        print(f"{r['entity']} , '{r['label']}',  {r['property']}  ")
        #print(f"{r['entity']} , '{r['label']}', is missing mandatory property: {r['property_subs_edam']}  ")
        #print(f"{r['entity']}  {r['p']} '{r['v']}' ")

f.close()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Input In [27], in <module>
#       6 report = list()
#       7 results = g.query(query_term)
# ----> 8 print(len(results))
#       9 for r in results:
#      10     print(f"{r['entity']} , '{r['label']}',  {r['property']}  ")
#
# File ~/.local/lib/python3.9/site-packages/rdflib/query.py:272, in Result.__len__(self)
#     270     return 1
#     271 elif self.type == "SELECT":
# --> 272     return len(self.bindings)
#     273 else:
#     274     return len(self.graph)
#
# File ~/.local/lib/python3.9/site-packages/rdflib/query.py:178, in Result._get_bindings(self)
#     176 def _get_bindings(self):
#     177     if self._genbindings:
# --> 178         self._bindings += list(self._genbindings)
#     179         self._genbindings = None
#     181     return self._bindings
#
# File ~/.local/lib/python3.9/site-packages/rdflib/plugins/sparql/evaluate.py:498, in evalDistinct(ctx, part)
#     497 def evalDistinct(ctx, part):
# --> 498     res = evalPart(ctx, part.p)
#     500     done = set()
#     501     for x in res:
#
# File ~/.local/lib/python3.9/site-packages/rdflib/plugins/sparql/evaluate.py:269, in evalPart(ctx, part)
#     266     return evalMinus(ctx, part)
#     268 elif part.name == "Project":
# --> 269     return evalProject(ctx, part)
#     270 elif part.name == "Slice":
#     271     return evalSlice(ctx, part)
#
# File ~/.local/lib/python3.9/site-packages/rdflib/plugins/sparql/evaluate.py:508, in evalProject(ctx, project)
#     507 def evalProject(ctx, project):
# --> 508     res = evalPart(ctx, project.p)
#     510     return (row.project(project.PV) for row in res)
#
# File ~/.local/lib/python3.9/site-packages/rdflib/plugins/sparql/evaluate.py:278, in evalPart(ctx, part)
#     275     return evalReduced(ctx, part)
#     277 elif part.name == "OrderBy":
# --> 278     return evalOrderBy(ctx, part)
#     279 elif part.name == "Group":
#     280     return evalGroup(ctx, part)
#
# File ~/.local/lib/python3.9/site-packages/rdflib/plugins/sparql/evaluate.py:442, in evalOrderBy(ctx, part)
#     439 for e in reversed(part.expr):
#     441     reverse = bool(e.order and e.order == "DESC")
# --> 442     res = sorted(
#     443         res, key=lambda x: _val(value(x, e.expr, variables=True)), reverse=reverse
#     444     )
#     446 return res
#
# File ~/.local/lib/python3.9/site-packages/rdflib/plugins/sparql/evaluate.py:173, in evalFilter(ctx, part)
#     170 def evalFilter(ctx, part):
#     171     # TODO: Deal with dict returned from evalPart!
#     172     for c in evalPart(ctx, part.p):
# --> 173         if _ebv(
#     174             part.expr,
#     175             c.forget(ctx, _except=part._vars) if not part.no_isolated_scope else c,
#     176         ):
#     177             yield c
#
# File ~/.local/lib/python3.9/site-packages/rdflib/plugins/sparql/evalutils.py:48, in _ebv(expr, ctx)
#      46 if isinstance(expr, Expr):
#      47     try:
# ---> 48         return EBV(expr.eval(ctx))
#      49     except SPARQLError:
#      50         return False  # filter error == False
#
# File ~/.local/lib/python3.9/site-packages/rdflib/plugins/sparql/parserutils.py:194, in Expr.eval(self, ctx)
#     192 try:
#     193     self.ctx = ctx
# --> 194     return self._evalfn(ctx)
#     195 except SPARQLError as e:
#     196     return e
#
# File ~/.local/lib/python3.9/site-packages/rdflib/plugins/sparql/operators.py:580, in Builtin_EXISTS(e, ctx)
#     577 exists = e.name == "Builtin_EXISTS"
#     579 ctx = ctx.ctx.thaw(ctx)  # hmm
# --> 580 for x in evalPart(ctx, e.graph):
#     581     return Literal(exists)
#     582 return Literal(not exists)
#
# File ~/.local/lib/python3.9/site-packages/rdflib/plugins/sparql/evaluate.py:173, in evalFilter(ctx, part)
#     170 def evalFilter(ctx, part):
#     171     # TODO: Deal with dict returned from evalPart!
#     172     for c in evalPart(ctx, part.p):
# --> 173         if _ebv(
#     174             part.expr,
#     175             c.forget(ctx, _except=part._vars) if not part.no_isolated_scope else c,
#     176         ):
#     177             yield c
#
# File ~/.local/lib/python3.9/site-packages/rdflib/plugins/sparql/evalutils.py:48, in _ebv(expr, ctx)
#      46 if isinstance(expr, Expr):
#      47     try:
# ---> 48         return EBV(expr.eval(ctx))
#      49     except SPARQLError:
#      50         return False  # filter error == False
#
# File ~/.local/lib/python3.9/site-packages/rdflib/plugins/sparql/parserutils.py:194, in Expr.eval(self, ctx)
#     192 try:
#     193     self.ctx = ctx
# --> 194     return self._evalfn(ctx)
#     195 except SPARQLError as e:
#     196     return e
#
# File ~/.local/lib/python3.9/site-packages/rdflib/plugins/sparql/operators.py:216, in Builtin_REGEX(expr, ctx)
#     213     flagMap = dict([("i", re.IGNORECASE), ("s", re.DOTALL), ("m", re.MULTILINE)])
#     214     cFlag = reduce(pyop.or_, [flagMap.get(f, 0) for f in flags])
# --> 216 return Literal(bool(re.search(str(pattern), text, cFlag)))
#
# File /usr/lib/python3.9/re.py:201, in search(pattern, string, flags)
#     198 def search(pattern, string, flags=0):
#     199     """Scan through string looking for a match to the pattern, returning
#     200     a Match object, or None if no match was found."""
# --> 201     return _compile(pattern, flags).search(string)
#
# File /usr/lib/python3.9/re.py:304, in _compile(pattern, flags)
#     302 if not sre_compile.isstring(pattern):
#     303     raise TypeError("first argument must be string or compiled pattern")
# --> 304 p = sre_compile.compile(pattern, flags)
#     305 if not (flags & DEBUG):
#     306     if len(_cache) >= _MAXCACHE:
#     307         # Drop the oldest item
#
# File /usr/lib/python3.9/sre_compile.py:764, in compile(p, flags)
#     762 if isstring(p):
#     763     pattern = p
# --> 764     p = sre_parse.parse(p, flags)
#     765 else:
#     766     pattern = None
#
# File /usr/lib/python3.9/sre_parse.py:948, in parse(str, flags, state)
#     945 state.str = str
#     947 try:
# --> 948     p = _parse_sub(source, state, flags & SRE_FLAG_VERBOSE, 0)
#     949 except Verbose:
#     950     # the VERBOSE flag was switched on inside the pattern.  to be
#     951     # on the safe side, we'll parse the whole thing again...
#     952     state = State()
#
# File /usr/lib/python3.9/sre_parse.py:443, in _parse_sub(source, state, verbose, nested)
#     441 start = source.tell()
#     442 while True:
# --> 443     itemsappend(_parse(source, state, verbose, nested + 1,
#     444                        not nested and not items))
#     445     if not sourcematch("|"):
#     446         break
#
# File /usr/lib/python3.9/sre_parse.py:525, in _parse(source, state, verbose, nested, first)
#     522         continue
#     524 if this[0] == "\\":
# --> 525     code = _escape(source, this, state)
#     526     subpatternappend(code)
#     528 elif this not in SPECIAL_CHARS:
#
# File /usr/lib/python3.9/sre_parse.py:426, in _escape(source, escape, state)
#     424     if len(escape) == 2:
#     425         if c in ASCIILETTERS:
# --> 426             raise source.error("bad escape %s" % escape, len(escape))
#     427         return LITERAL, ord(escape[1])
#     428 except ValueError:
#
# error: bad escape \c at position 0
