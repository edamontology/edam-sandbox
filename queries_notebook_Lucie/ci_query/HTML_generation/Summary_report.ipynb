# %%
import unittest
import logging, sys
import glob
import json
import os
from jinja2 import Template

import nbformat

from IPython.display import display, Markdown

# %%
with open('tests.conf','r') as f:
    lines = f.read().splitlines()

for l in lines :
    print (l)

f.close()
# Out:
# Summary_report_super_class_refers_to_self.html
# Summary_report_object_relation_obsolete.html
# Summary_report_deprecated_replacement_obsolete.html

# %%
summary = []
for l in lines:
    with open(l,'r') as f:
        sum_html = f.read()
        summary.append(sum_html)
f.close()
print(summary)
# Out:
# ['\n\n                <tr>    \n                \n                                                         <!--TO CHANGE-->\n\n                    <td>Super class refers to self</td>\n                    <td>No error found</td>\n                    <td></td>                \n                \n                \n                </tr>\n', '\n\n                <tr>\n                \n                                                            <!--TO CHANGE-->\n\n                    <td>Object relation obsolete</td>\n                    <td>2 errors found</td>\n                    <td>   \n                    <a href="Report_object_relation_obsolete.html"> link_here </a> \n                    </td>                \n                \n                </tr>\n', '\n\n                <tr>\n                \n                                                            <!--TO CHANGE-->\n\n                    <td>Deprecated replacement obsolete</td>\n                    <td>5 errors found</td>\n  
# ...

# %%
###
### template syntax : https://jinja.palletsprojects.com/en/3.0.x/templates/ 
###
html_template = """
<!DOCTYPE html>
<html>
<head>
    <title>EDAM ontology development dashboard</title>
    <meta charset="utf-8">
    <meta name="viewport" content="width=device-width, initial-scale=1">
    <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/5.15.4/css/all.min.css"/>
    <link rel="stylesheet" type="text/css" href="css/bulma.min.css" />
    <link rel="stylesheet" type="text/css" href="css/app.css" />
</head>

<body>
<div class="columns">

    <div class="column is-one-quarter">
        <section class="section"> 
                                                            <!--TO CHANGE-->
                                                             
            <h1>CI report EDAM Ontology</h1>     
        </section>
    </div>
    <div class="column is-full ">
        <section class="section">
                                                             <!--TO CHANGE-->
                                                             
            <text> Description : Summary of all errors raised by CI tests.</text>   
        <br></br>
        </section>
    </div>

    <div class="column">
        <section class="section">
        
            <table class="table">
              <thead>
                <tr>
                  <th>Test name</th>
                  <th>Errors</th>
                  <th>Link</th>
                </tr>
              </thead>
              
              <tbody>
              
               {%for test in summary %}
                   {{test}}
               {%endfor%}
                    

              </table>
        </section>
    </div>
    

</div>
</body>
</html>
"""

template = Template(html_template)

html_code = template.render(
    summary=summary
)

###
### write to output file :
#                                                      TO CHANGE!!!!
###
with open('Summary_report.html', 'w') as f:
    f.write(html_code)

###
### Display HTML
###
print(html_code)
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <title>EDAM ontology development dashboard</title>
#     <meta charset="utf-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1">
#     <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/5.15.4/css/all.min.css"/>
#     <link rel="stylesheet" type="text/css" href="css/bulma.min.css" />
#     <link rel="stylesheet" type="text/css" href="css/app.css" />
# </head>
#
# <body>
# <div class="columns">
#
#     <div class="column is-one-quarter">
#         <section class="section">
#                                                             <!--TO CHANGE-->
#
#             <h1>CI report EDAM Ontology</h1>
#         </section>
#     </div>
#     <div class="column is-full ">
#         <section class="section">
#                                                              <!--TO CHANGE-->
#
#             <text> Description : Summary of all errors raised by CI tests.</text>
#         <br></br>
# ...
