# %%
from rdflib import ConjunctiveGraph, Namespace
import json
import os


# Constants for script error reporting as per https://github.com/edamontology/edamverify.
NOERR = "NOERR"
INFO  = "INFO"
WARN  = "WARN"
ERROR = "ERROR"

#Load EDAM_dev.owl from GitHub into an RDF graph.
print("Loading graph ...", end="")
g = ConjunctiveGraph()
g.load(os.environ.get('EDAM_PATH', '../edamontology/EDAM_dev.owl'), format='xml')
#g.load('https://raw.githubusercontent.com/edamontology/edamontology/master/EDAM_dev.owl', format='xml')
# g.load('EDAM_dev.owl', format='xml')
g.bind('edam', Namespace('http://edamontology.org#'))
print("done!")
# Out:
# Loading graph ...done!

# %%
    query = "identifier_property_missing.rq"
    with open(query,'r') as f:
        query_term = f.read()
  
        errfound = False
        report = list()
        results = g.query(query_term)
        print(len(results))
        for r in results:
            print(f"{r['entity']} , '{r['label']}', is missing mandatory identifier property : {r['property']} ")
    f.close()
# Out:
# 193
# http://edamontology.org/data_1002 , 'CAS number', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_1003 , 'Chemical registry number (Beilstein)', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_1004 , 'Chemical registry number (Gmelin)', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_1027 , 'Gene ID (NCBI)', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_1031 , 'Gene ID (CGD)', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_1032 , 'Gene ID (DictyBase)', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_1033 , 'Ensembl gene ID', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_1036 , 'TIGR identifier', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_1039 , 'SCOP domain identifier', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_1040 , 'CATH domain ID', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_1041 , 'SCOP concise classification string (sccs)', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_1042 , 'SCOP sunid', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_1043 , 'CATH node ID', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_1066 , 'Sequence alignment ID', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_1100 , 'PIR identifier', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_1102 , 'Gramene primary identifier', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_1103 , 'EMBL/GenBank/DDBJ ID', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_1104 , 'Sequence cluster ID (UniGene)', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_1105 , 'dbEST accession', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_1106 , 'dbSNP ID', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_1113 , 'Sequence cluster ID (COG)', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_1118 , 'HMMER hidden Markov model ID', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_1119 , 'JASPAR profile ID', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_1123 , 'TreeBASE study accession number', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_1124 , 'TreeFam accession number', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_1128 , 'AAindex ID', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_1129 , 'BIND accession number', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_1134 , 'InterPro secondary accession', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_1135 , 'Gene3D ID', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_1140 , 'Superfamily hidden Markov model number', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_1141 , 'TIGRFam ID', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_1143 , 'TRANSFAC accession number', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_1146 , 'EMDB ID', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_1148 , 'GermOnline ID', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_1149 , 'EMAGE ID', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_1151 , 'HGVbase ID', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_1154 , 'KEGG object identifier', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_1157 , 'Pathway ID (BioCyc)', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_1158 , 'Pathway ID (INOH)', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_1159 , 'Pathway ID (PATIKA)', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_1160 , 'Pathway ID (CPDB)', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_1164 , 'MIRIAM URI', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_1167 , 'Taverna workflow ID', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_1175 , 'BioPax concept ID', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_1177 , 'MeSH concept ID', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_1178 , 'HGNC concept ID', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_1180 , 'Plant Ontology concept ID', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_1181 , 'UMLS concept ID', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_1183 , 'EMAP concept ID', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_1184 , 'ChEBI concept ID', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_1185 , 'MGED concept ID', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_1186 , 'myGrid concept ID', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_1189 , 'Medline UI', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_1794 , 'Gene ID (PlasmoDB)', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_1795 , 'Gene ID (EcoGene)', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_1796 , 'Gene ID (FlyBase)', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_1802 , 'Gene ID (Gramene)', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_1803 , 'Gene ID (Virginia microbial)', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_1804 , 'Gene ID (SGN)', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_1873 , 'iHOP organism ID', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_1885 , 'Gene ID (GeneFarm)', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_1886 , 'Blattner number', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_1891 , 'iHOP symbol', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_1896 , 'Locus ID (ASPGD)', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_1897 , 'Locus ID (MGG)', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_1898 , 'Locus ID (CGD)', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_1899 , 'Locus ID (CMR)', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_1900 , 'NCBI locus tag', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_1901 , 'Locus ID (SGD)', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_1902 , 'Locus ID (MMP)', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_1903 , 'Locus ID (DictyBase)', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_1904 , 'Locus ID (EntrezGene)', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_1905 , 'Locus ID (MaizeGDB)', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_1907 , 'Gene ID (KOME)', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_1908 , 'Locus ID (Tropgene)', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2102 , 'KEGG organism code', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2104 , 'BioCyc ID', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2105 , 'Compound ID (BioCyc)', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2106 , 'Reaction ID (BioCyc)', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2107 , 'Enzyme ID (BioCyc)', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2112 , 'FlyBase primary identifier', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2174 , 'FlyBase secondary identifier', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2209 , 'Mutation ID', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2220 , 'Sequence cluster ID (SYSTERS)', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2285 , 'Gene ID (MIPS)', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2290 , 'EMBL accession', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2292 , 'GenBank accession', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2293 , 'Gramene secondary identifier', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2297 , 'Gene ID (ECK)', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2298 , 'Gene ID (HGNC)', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2302 , 'STRING ID', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2314 , 'GI number', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2315 , 'NCBI version', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2325 , 'REBASE enzyme number', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2327 , 'GI number (protein)', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2345 , 'Pathway ID (ConsensusPathDB)', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2346 , 'Sequence cluster ID (UniRef)', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2347 , 'Sequence cluster ID (UniRef100)', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2348 , 'Sequence cluster ID (UniRef90)', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2349 , 'Sequence cluster ID (UniRef50)', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2356 , 'RFAM accession', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2367 , 'ASTD ID', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2368 , 'ASTD ID (exon)', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2369 , 'ASTD ID (intron)', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2370 , 'ASTD ID (polya)', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2371 , 'ASTD ID (tss)', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2374 , 'Spot serial number', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2375 , 'Spot ID (HSC-2DPAGE)', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2380 , 'CABRI accession', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2383 , 'EGA accession', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2385 , 'RefSeq accession (protein)', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2386 , 'EPD ID', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2387 , 'TAIR accession', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2388 , 'TAIR accession (At gene)', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2389 , 'UniSTS accession', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2390 , 'UNITE accession', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2391 , 'UTR accession', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2393 , 'mFLJ/mKIAA number', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2398 , 'Ensembl protein ID', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2578 , 'ArachnoServer ID', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2580 , 'BindingDB Monomer ID', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2588 , 'BlotBase blot ID', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2591 , 'Brite hierarchy ID', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2593 , 'BRENDA organism ID', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2639 , 'PubChem ID', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2700 , 'CATH identifier', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2701 , 'CATH node ID (family)', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2702 , 'Enzyme ID (CAZy)', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2704 , 'Clone ID (IMAGE)', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2709 , 'CleanEx entry name', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2713 , 'Protein ID (CORUM)', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2714 , 'CDD PSSM-ID', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2715 , 'Protein ID (CuticleDB)', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2716 , 'DBD ID', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2719 , 'dbProbe ID', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2721 , 'DiProDB ID', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2723 , 'Protein ID (DisProt)', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2725 , 'Ensembl transcript ID', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2729 , 'COGEME EST ID', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2730 , 'COGEME unisequence ID', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2731 , 'Protein family ID (GeneFarm)', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2736 , 'Sequence feature ID (SwissRegulon)', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2737 , 'FIG ID', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2738 , 'Gene ID (Xenbase)', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2739 , 'Gene ID (Genolist)', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2741 , 'ABS ID', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2742 , 'AraC-XylS ID', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2744 , 'Locus ID (PseudoCAP)', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2745 , 'Locus ID (UTR)', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2746 , 'MonosaccharideDB ID', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2751 , 'GenomeReviews ID', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2756 , 'TCID', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2759 , 'Gene ID (VectorBase)', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2766 , 'HAMAP ID', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2770 , 'HIT ID', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2771 , 'HIX ID', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2772 , 'HPA antibody id', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2773 , 'IMGT/HLA ID', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2774 , 'Gene ID (JCVI)', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2776 , 'ConsensusPathDB entity ID', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2778 , 'CCAP strain number', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2780 , 'Stock number (TAIR)', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2781 , 'REDIdb ID', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2783 , 'Protein family ID (PANTHER)', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2784 , 'RNAVirusDB ID', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2786 , 'NCBI Genome Project ID', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2787 , 'NCBI genome accession', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2789 , 'Protein ID (TopDB)', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2792 , 'Protein ID (PeroxiBase)', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2793 , 'SISYPHUS ID', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2794 , 'ORF ID', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2796 , 'Linucs ID', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2797 , 'Protein ID (LGICdb)', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2798 , 'MaizeDB ID', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2799 , 'Gene ID (MfunGD)', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2800 , 'Orpha number', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2802 , 'Protein ID (EcID)', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2803 , 'Clone ID (RefSeq)', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2804 , 'Protein ID (ConoServer)', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2805 , 'GeneSNP ID', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2835 , 'Gene ID (VBASE2)', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2836 , 'DPVweb ID', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2915 , 'Gramene identifier', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_2916 , 'DDBJ accession', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_3029 , 'Protein ID (EMBL/GenBank/DDBJ)', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_3103 , 'ATC code', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_3264 , 'COSMIC ID', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_3265 , 'HGMD ID', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_3270 , 'Ensembl gene tree ID', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_3274 , 'MGI accession', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_3757 , 'Unimod ID', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_3769 , 'BRENDA ontology concept ID', is missing mandatory identifier property : http://edamontology.org/regex
# http://edamontology.org/data_3856 , 'RNA central ID', is missing mandatory identifier property : http://edamontology.org/regex
