# %%
from rdflib import ConjunctiveGraph, Namespace
import json
import os


# Constants for script error reporting as per https://github.com/edamontology/edamverify.

#Load EDAM_dev.owl from GitHub into an RDF graph.
print("Loading graph ...", end="")
g = ConjunctiveGraph()
g.load(os.environ.get('EDAM_PATH', '../edamontology/EDAM_dev.owl'), format='xml')
#g.load('https://raw.githubusercontent.com/edamontology/edamontology/master/EDAM_dev.owl', format='xml')
# g.load('EDAM_dev.owl', format='xml')
g.bind('edam', Namespace('http://edamontology.org#'))
print("done!")
# Out:
# Loading graph ...done!

# %%
q = """
PREFIX obo: <http://purl.obolibrary.org/obo/>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX oboInOwl: <http://www.geneontology.org/formats/oboInOwl#>
PREFIX edam:<http://edamontology.org/>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>

SELECT DISTINCT ?entity ?property ?value ?label WHERE {
    # ?entity a owl:Class .
    # ?entity oboInOwl:hasDefinition ?value .    
        FILTER REGEX (?value, "^(.{0,25})$").
    # ?entity rdfs:label ?label.

}
ORDER BY ?entity

"""

# %%
results = g.query(q)
print(f"{len(results)} ")
for r in results:
    #print(f"{r['entity']} , defintion less than 25 char , {r['label']}\n                                                                  {r['value']}")
    print(f"{r['entity']} , defintion less than 25 char , {r['value']}")
# Out:
# 86
# http://edamontology.org/data_0844 , defintion less than 25 char , Mass of a molecule.
# http://edamontology.org/data_0845 , defintion less than 25 char , Net charge of a molecule.
# http://edamontology.org/data_0987 , defintion less than 25 char , Name of a chromosome.
# http://edamontology.org/data_0989 , defintion less than 25 char , Identifier of a protein.
# http://edamontology.org/data_0993 , defintion less than 25 char , Identifier of a drug.
# http://edamontology.org/data_1009 , defintion less than 25 char , Name of a protein.
# http://edamontology.org/data_1012 , defintion less than 25 char , Name of an enzyme.
# http://edamontology.org/data_1049 , defintion less than 25 char , The name of a directory.
# http://edamontology.org/data_1060 , defintion less than 25 char , The base name of a file.
# http://edamontology.org/data_1131 , defintion less than 25 char , Name of a protein family.
# ...

# %%
q = """
PREFIX obo: <http://purl.obolibrary.org/obo/>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX oboInOwl: <http://www.geneontology.org/formats/oboInOwl#>
PREFIX edam:<http://edamontology.org/>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>

SELECT DISTINCT ?entity ?property ?value ?label WHERE {
    # ?entity a owl:Class .
    # ?entity oboInOwl:hasDefinition ?value .    
        FILTER REGEX (?value, "^(.{0,25})$").
    # ?entity rdfs:label ?label.
    FILTER (?label = ?value)

}
ORDER BY ?entity

"""

# %%
results = g.query(q)
print(f"{len(results)} ")
for r in results:
    print(f"{r['entity']} , defintion less than 25 char , {r['label']}\n                                                                  {r['value']}")
# Out:
# 1
# http://edamontology.org/topic_0771 , defintion less than 25 char , Theoretical biology
#                                                                   Theoretical biology

# %%
q = """
PREFIX obo: <http://purl.obolibrary.org/obo/>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX oboInOwl: <http://www.geneontology.org/formats/oboInOwl#>
PREFIX edam:<http://edamontology.org/>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>

SELECT DISTINCT ?entity ?property ?value2 ?label WHERE {
    # ?entity a owl:Class .
    # ?entity oboInOwl:hasDefinition ?value .    
        FILTER REGEX (?value, "^(.{0,25})$").
    # ?entity rdfs:label ?label.
    BIND ( REPLACE (?value, ".$", "") AS ?value2 )
    #FILTER (?label = ?value2)

}
ORDER BY ?entity

"""

# %%
results = g.query(q)
print(f"{len(results)} ")
for r in results:
    print(f"{r['entity']} , defintion less than 25 char , {r['label']}\n                                                                  {r['value2']}")
# Out:
# 86
# http://edamontology.org/data_0844 , defintion less than 25 char , Molecular mass
#                                                                   Mass of a molecule
# http://edamontology.org/data_0845 , defintion less than 25 char , Molecular charge
#                                                                   Net charge of a molecule
# http://edamontology.org/data_0987 , defintion less than 25 char , Chromosome name
#                                                                   Name of a chromosome
# http://edamontology.org/data_0989 , defintion less than 25 char , Protein identifier
#                                                                   Identifier of a protein
# http://edamontology.org/data_0993 , defintion less than 25 char , Drug identifier
#                                                                   Identifier of a drug
# http://edamontology.org/data_1009 , defintion less than 25 char , Protein name
# ...

# %%
q = """
PREFIX obo: <http://purl.obolibrary.org/obo/>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX oboInOwl: <http://www.geneontology.org/formats/oboInOwl#>
PREFIX edam:<http://edamontology.org/>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>

SELECT DISTINCT ?entity ?property ?value2 ?label WHERE {
    # ?entity a owl:Class .
    # ?entity oboInOwl:hasDefinition ?value .    
        FILTER REGEX (?value, "^(.{0,25})$").
    # ?entity rdfs:label ?label.
    BIND ( REPLACE (?value, ".$", "") AS ?value2 )
    FILTER (?label = ?value2)

}
ORDER BY ?entity

"""

# %%
results = g.query(q)
print(f"{len(results)} ")
for r in results:
    print(f"{r['entity']} , defintion less than 25 char , {r['label']}\n                                                                  {r['value2']}")
# Out:
# 9
# http://edamontology.org/data_1680 , defintion less than 25 char , STRIDE log file
#                                                                   STRIDE log file
# http://edamontology.org/data_1681 , defintion less than 25 char , NACCESS log file
#                                                                   NACCESS log file
# http://edamontology.org/format_2330 , defintion less than 25 char , Textual format
#                                                                   Textual format
# http://edamontology.org/format_2333 , defintion less than 25 char , Binary format
#                                                                   Binary format
# http://edamontology.org/topic_0753 , defintion less than 25 char , Metabolic pathways
#                                                                   Metabolic pathways
# http://edamontology.org/topic_0754 , defintion less than 25 char , Signaling pathways
# ...
