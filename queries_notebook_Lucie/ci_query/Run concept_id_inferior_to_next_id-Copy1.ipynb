# %%
from rdflib import ConjunctiveGraph, Namespace
import json
import os


# Constants for script error reporting as per https://github.com/edamontology/edamverify.
NOERR = "NOERR"
INFO  = "INFO"
WARN  = "WARN"
ERROR = "ERROR"

#Load EDAM_dev.owl from GitHub into an RDF graph.
print("Loading graph ...", end="")
g = ConjunctiveGraph()
g.parse(os.environ.get('EDAM_PATH', '../edamontology/EDAM_dev.owl'), format='xml')
#g.load('https://raw.githubusercontent.com/edamontology/edamontology/master/EDAM_dev.owl', format='xml')
# g.load('EDAM_dev.owl', format='xml')
g.bind('edam', Namespace('http://edamontology.org#'))
print("done!")
# Out:
# Loading graph ...done!

# %%
    query = "concept_id_inferior_to_next_id-Copy1.rq"
    with open(query,'r') as f:
        query_term = f.read()
  
        errfound = False
        report = list()
        results = g.query(query_term)
        print(len(results))
        ids=[]
        for r in results:
            print(r)
            ids.append(int(r['id']))
            next_id = int(r['value'])

        
        max_ids = max(ids)
        if next_id != (max_ids+1) : 
            print(max_ids+1,next_id)
            print('error next id diff than max +1')
        
    f.close()
# Out:
# 3492
# (rdflib.term.URIRef('http://edamontology.org/data_0005'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Resource type'), rdflib.term.Literal('0005'))
# (rdflib.term.URIRef('http://edamontology.org/data_0006'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Data'), rdflib.term.Literal('0006'))
# (rdflib.term.URIRef('http://edamontology.org/data_0007'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Tool'), rdflib.term.Literal('0007'))
# (rdflib.term.URIRef('http://edamontology.org/data_0581'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Database'), rdflib.term.Literal('0581'))
# (rdflib.term.URIRef('http://edamontology.org/data_0582'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Ontology'), rdflib.term.Literal('0582'))
# (rdflib.term.URIRef('http://edamontology.org/data_0583'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Directory metadata'), rdflib.term.Literal('0583'))
# (rdflib.term.URIRef('http://edamontology.org/data_0831'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('MeSH vocabulary'), rdflib.term.Literal('0831'))
# (rdflib.term.URIRef('http://edamontology.org/data_0832'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('HGNC vocabulary'), rdflib.term.Literal('0832'))
# (rdflib.term.URIRef('http://edamontology.org/data_0835'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('UMLS vocabulary'), rdflib.term.Literal('0835'))
# (rdflib.term.URIRef('http://edamontology.org/data_0842'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Identifier'), rdflib.term.Literal('0842'))
# (rdflib.term.URIRef('http://edamontology.org/data_0843'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Database entry'), rdflib.term.Literal('0843'))
# (rdflib.term.URIRef('http://edamontology.org/data_0844'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Molecular mass'), rdflib.term.Literal('0844'))
# (rdflib.term.URIRef('http://edamontology.org/data_0845'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Molecular charge'), rdflib.term.Literal('0845'))
# (rdflib.term.URIRef('http://edamontology.org/data_0846'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Chemical formula'), rdflib.term.Literal('0846'))
# (rdflib.term.URIRef('http://edamontology.org/data_0847'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('QSAR descriptor'), rdflib.term.Literal('0847'))
# (rdflib.term.URIRef('http://edamontology.org/data_0848'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Raw sequence'), rdflib.term.Literal('0848'))
# (rdflib.term.URIRef('http://edamontology.org/data_0849'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Sequence record'), rdflib.term.Literal('0849'))
# (rdflib.term.URIRef('http://edamontology.org/data_0850'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Sequence set'), rdflib.term.Literal('0850'))
# (rdflib.term.URIRef('http://edamontology.org/data_0851'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Sequence mask character'), rdflib.term.Literal('0851'))
# (rdflib.term.URIRef('http://edamontology.org/data_0852'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Sequence mask type'), rdflib.term.Literal('0852'))
# (rdflib.term.URIRef('http://edamontology.org/data_0853'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('DNA sense specification'), rdflib.term.Literal('0853'))
# (rdflib.term.URIRef('http://edamontology.org/data_0854'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Sequence length specification'), rdflib.term.Literal('0854'))
# (rdflib.term.URIRef('http://edamontology.org/data_0855'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Sequence metadata'), rdflib.term.Literal('0855'))
# (rdflib.term.URIRef('http://edamontology.org/data_0856'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Sequence feature source'), rdflib.term.Literal('0856'))
# (rdflib.term.URIRef('http://edamontology.org/data_0857'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Sequence search results'), rdflib.term.Literal('0857'))
# (rdflib.term.URIRef('http://edamontology.org/data_0858'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Sequence signature matches'), rdflib.term.Literal('0858'))
# (rdflib.term.URIRef('http://edamontology.org/data_0859'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Sequence signature model'), rdflib.term.Literal('0859'))
# (rdflib.term.URIRef('http://edamontology.org/data_0860'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Sequence signature data'), rdflib.term.Literal('0860'))
# (rdflib.term.URIRef('http://edamontology.org/data_0861'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Sequence alignment (words)'), rdflib.term.Literal('0861'))
# (rdflib.term.URIRef('http://edamontology.org/data_0862'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Dotplot'), rdflib.term.Literal('0862'))
# (rdflib.term.URIRef('http://edamontology.org/data_0863'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Sequence alignment'), rdflib.term.Literal('0863'))
# (rdflib.term.URIRef('http://edamontology.org/data_0864'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Sequence alignment parameter'), rdflib.term.Literal('0864'))
# (rdflib.term.URIRef('http://edamontology.org/data_0865'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Sequence similarity score'), rdflib.term.Literal('0865'))
# (rdflib.term.URIRef('http://edamontology.org/data_0866'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Sequence alignment metadata'), rdflib.term.Literal('0866'))
# (rdflib.term.URIRef('http://edamontology.org/data_0867'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Sequence alignment report'), rdflib.term.Literal('0867'))
# (rdflib.term.URIRef('http://edamontology.org/data_0868'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Profile-profile alignment'), rdflib.term.Literal('0868'))
# (rdflib.term.URIRef('http://edamontology.org/data_0869'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Sequence-profile alignment'), rdflib.term.Literal('0869'))
# (rdflib.term.URIRef('http://edamontology.org/data_0870'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Sequence distance matrix'), rdflib.term.Literal('0870'))
# (rdflib.term.URIRef('http://edamontology.org/data_0871'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Phylogenetic character data'), rdflib.term.Literal('0871'))
# (rdflib.term.URIRef('http://edamontology.org/data_0872'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Phylogenetic tree'), rdflib.term.Literal('0872'))
# (rdflib.term.URIRef('http://edamontology.org/data_0874'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Comparison matrix'), rdflib.term.Literal('0874'))
# (rdflib.term.URIRef('http://edamontology.org/data_0875'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Protein topology'), rdflib.term.Literal('0875'))
# (rdflib.term.URIRef('http://edamontology.org/data_0876'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Protein features report (secondary structure)'), rdflib.term.Literal('0876'))
# (rdflib.term.URIRef('http://edamontology.org/data_0877'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Protein features report (super-secondary)'), rdflib.term.Literal('0877'))
# (rdflib.term.URIRef('http://edamontology.org/data_0878'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Protein secondary structure alignment'), rdflib.term.Literal('0878'))
# (rdflib.term.URIRef('http://edamontology.org/data_0879'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Secondary structure alignment metadata (protein)'), rdflib.term.Literal('0879'))
# (rdflib.term.URIRef('http://edamontology.org/data_0880'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('RNA secondary structure'), rdflib.term.Literal('0880'))
# (rdflib.term.URIRef('http://edamontology.org/data_0881'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('RNA secondary structure alignment'), rdflib.term.Literal('0881'))
# (rdflib.term.URIRef('http://edamontology.org/data_0882'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Secondary structure alignment metadata (RNA)'), rdflib.term.Literal('0882'))
# (rdflib.term.URIRef('http://edamontology.org/data_0883'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Structure'), rdflib.term.Literal('0883'))
# (rdflib.term.URIRef('http://edamontology.org/data_0884'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Tertiary structure record'), rdflib.term.Literal('0884'))
# (rdflib.term.URIRef('http://edamontology.org/data_0885'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Structure database search results'), rdflib.term.Literal('0885'))
# (rdflib.term.URIRef('http://edamontology.org/data_0886'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Structure alignment'), rdflib.term.Literal('0886'))
# (rdflib.term.URIRef('http://edamontology.org/data_0887'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Structure alignment report'), rdflib.term.Literal('0887'))
# (rdflib.term.URIRef('http://edamontology.org/data_0888'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Structure similarity score'), rdflib.term.Literal('0888'))
# (rdflib.term.URIRef('http://edamontology.org/data_0889'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Structural profile'), rdflib.term.Literal('0889'))
# (rdflib.term.URIRef('http://edamontology.org/data_0890'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Structural (3D) profile alignment'), rdflib.term.Literal('0890'))
# (rdflib.term.URIRef('http://edamontology.org/data_0891'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Sequence-3D profile alignment'), rdflib.term.Literal('0891'))
# (rdflib.term.URIRef('http://edamontology.org/data_0892'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Protein sequence-structure scoring matrix'), rdflib.term.Literal('0892'))
# (rdflib.term.URIRef('http://edamontology.org/data_0893'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Sequence-structure alignment'), rdflib.term.Literal('0893'))
# (rdflib.term.URIRef('http://edamontology.org/data_0894'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Amino acid annotation'), rdflib.term.Literal('0894'))
# (rdflib.term.URIRef('http://edamontology.org/data_0895'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Peptide annotation'), rdflib.term.Literal('0895'))
# (rdflib.term.URIRef('http://edamontology.org/data_0896'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Protein report'), rdflib.term.Literal('0896'))
# (rdflib.term.URIRef('http://edamontology.org/data_0897'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Protein property'), rdflib.term.Literal('0897'))
# (rdflib.term.URIRef('http://edamontology.org/data_0899'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Protein structural motifs and surfaces'), rdflib.term.Literal('0899'))
# (rdflib.term.URIRef('http://edamontology.org/data_0900'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Protein domain classification'), rdflib.term.Literal('0900'))
# (rdflib.term.URIRef('http://edamontology.org/data_0901'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Protein features report (domains)'), rdflib.term.Literal('0901'))
# (rdflib.term.URIRef('http://edamontology.org/data_0902'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Protein architecture report'), rdflib.term.Literal('0902'))
# (rdflib.term.URIRef('http://edamontology.org/data_0903'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Protein folding report'), rdflib.term.Literal('0903'))
# (rdflib.term.URIRef('http://edamontology.org/data_0904'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Protein features (mutation)'), rdflib.term.Literal('0904'))
# (rdflib.term.URIRef('http://edamontology.org/data_0905'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Protein interaction raw data'), rdflib.term.Literal('0905'))
# (rdflib.term.URIRef('http://edamontology.org/data_0906'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Protein interaction data'), rdflib.term.Literal('0906'))
# (rdflib.term.URIRef('http://edamontology.org/data_0907'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Protein family report'), rdflib.term.Literal('0907'))
# (rdflib.term.URIRef('http://edamontology.org/data_0909'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Vmax'), rdflib.term.Literal('0909'))
# (rdflib.term.URIRef('http://edamontology.org/data_0910'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Km'), rdflib.term.Literal('0910'))
# (rdflib.term.URIRef('http://edamontology.org/data_0911'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Nucleotide base annotation'), rdflib.term.Literal('0911'))
# (rdflib.term.URIRef('http://edamontology.org/data_0912'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Nucleic acid property'), rdflib.term.Literal('0912'))
# (rdflib.term.URIRef('http://edamontology.org/data_0914'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Codon usage data'), rdflib.term.Literal('0914'))
# (rdflib.term.URIRef('http://edamontology.org/data_0916'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Gene report'), rdflib.term.Literal('0916'))
# (rdflib.term.URIRef('http://edamontology.org/data_0917'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Gene classification'), rdflib.term.Literal('0917'))
# (rdflib.term.URIRef('http://edamontology.org/data_0918'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('DNA variation'), rdflib.term.Literal('0918'))
# (rdflib.term.URIRef('http://edamontology.org/data_0919'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Chromosome report'), rdflib.term.Literal('0919'))
# (rdflib.term.URIRef('http://edamontology.org/data_0920'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Genotype/phenotype report'), rdflib.term.Literal('0920'))
# (rdflib.term.URIRef('http://edamontology.org/data_0923'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('PCR experiment report'), rdflib.term.Literal('0923'))
# (rdflib.term.URIRef('http://edamontology.org/data_0924'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Sequence trace'), rdflib.term.Literal('0924'))
# (rdflib.term.URIRef('http://edamontology.org/data_0925'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Sequence assembly'), rdflib.term.Literal('0925'))
# (rdflib.term.URIRef('http://edamontology.org/data_0926'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('RH scores'), rdflib.term.Literal('0926'))
# (rdflib.term.URIRef('http://edamontology.org/data_0927'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Genetic linkage report'), rdflib.term.Literal('0927'))
# (rdflib.term.URIRef('http://edamontology.org/data_0928'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Gene expression profile'), rdflib.term.Literal('0928'))
# (rdflib.term.URIRef('http://edamontology.org/data_0931'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Microarray experiment report'), rdflib.term.Literal('0931'))
# (rdflib.term.URIRef('http://edamontology.org/data_0932'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Oligonucleotide probe data'), rdflib.term.Literal('0932'))
# (rdflib.term.URIRef('http://edamontology.org/data_0933'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('SAGE experimental data'), rdflib.term.Literal('0933'))
# (rdflib.term.URIRef('http://edamontology.org/data_0934'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('MPSS experimental data'), rdflib.term.Literal('0934'))
# (rdflib.term.URIRef('http://edamontology.org/data_0935'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('SBS experimental data'), rdflib.term.Literal('0935'))
# (rdflib.term.URIRef('http://edamontology.org/data_0936'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Sequence tag profile (with gene assignment)'), rdflib.term.Literal('0936'))
# (rdflib.term.URIRef('http://edamontology.org/data_0937'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Electron density map'), rdflib.term.Literal('0937'))
# (rdflib.term.URIRef('http://edamontology.org/data_0938'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Raw NMR data'), rdflib.term.Literal('0938'))
# (rdflib.term.URIRef('http://edamontology.org/data_0939'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('CD spectra'), rdflib.term.Literal('0939'))
# (rdflib.term.URIRef('http://edamontology.org/data_0940'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Volume map'), rdflib.term.Literal('0940'))
# (rdflib.term.URIRef('http://edamontology.org/data_0941'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Electron microscopy model'), rdflib.term.Literal('0941'))
# (rdflib.term.URIRef('http://edamontology.org/data_0942'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('2D PAGE image'), rdflib.term.Literal('0942'))
# (rdflib.term.URIRef('http://edamontology.org/data_0943'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Mass spectrum'), rdflib.term.Literal('0943'))
# (rdflib.term.URIRef('http://edamontology.org/data_0944'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Peptide mass fingerprint'), rdflib.term.Literal('0944'))
# (rdflib.term.URIRef('http://edamontology.org/data_0945'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Peptide identification'), rdflib.term.Literal('0945'))
# (rdflib.term.URIRef('http://edamontology.org/data_0946'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Pathway or network annotation'), rdflib.term.Literal('0946'))
# (rdflib.term.URIRef('http://edamontology.org/data_0947'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Biological pathway map'), rdflib.term.Literal('0947'))
# (rdflib.term.URIRef('http://edamontology.org/data_0948'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Data resource definition'), rdflib.term.Literal('0948'))
# (rdflib.term.URIRef('http://edamontology.org/data_0949'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Workflow metadata'), rdflib.term.Literal('0949'))
# (rdflib.term.URIRef('http://edamontology.org/data_0950'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Mathematical model'), rdflib.term.Literal('0950'))
# (rdflib.term.URIRef('http://edamontology.org/data_0951'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Statistical estimate score'), rdflib.term.Literal('0951'))
# (rdflib.term.URIRef('http://edamontology.org/data_0952'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('EMBOSS database resource definition'), rdflib.term.Literal('0952'))
# (rdflib.term.URIRef('http://edamontology.org/data_0953'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Version information'), rdflib.term.Literal('0953'))
# (rdflib.term.URIRef('http://edamontology.org/data_0954'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Database cross-mapping'), rdflib.term.Literal('0954'))
# (rdflib.term.URIRef('http://edamontology.org/data_0955'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Data index'), rdflib.term.Literal('0955'))
# (rdflib.term.URIRef('http://edamontology.org/data_0956'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Data index report'), rdflib.term.Literal('0956'))
# (rdflib.term.URIRef('http://edamontology.org/data_0957'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Database metadata'), rdflib.term.Literal('0957'))
# (rdflib.term.URIRef('http://edamontology.org/data_0958'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Tool metadata'), rdflib.term.Literal('0958'))
# (rdflib.term.URIRef('http://edamontology.org/data_0959'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Job metadata'), rdflib.term.Literal('0959'))
# (rdflib.term.URIRef('http://edamontology.org/data_0960'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('User metadata'), rdflib.term.Literal('0960'))
# (rdflib.term.URIRef('http://edamontology.org/data_0962'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Small molecule report'), rdflib.term.Literal('0962'))
# (rdflib.term.URIRef('http://edamontology.org/data_0963'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Cell line report'), rdflib.term.Literal('0963'))
# (rdflib.term.URIRef('http://edamontology.org/data_0964'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Scent annotation'), rdflib.term.Literal('0964'))
# (rdflib.term.URIRef('http://edamontology.org/data_0966'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Ontology term'), rdflib.term.Literal('0966'))
# (rdflib.term.URIRef('http://edamontology.org/data_0967'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Ontology concept data'), rdflib.term.Literal('0967'))
# (rdflib.term.URIRef('http://edamontology.org/data_0968'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Keyword'), rdflib.term.Literal('0968'))
# (rdflib.term.URIRef('http://edamontology.org/data_0970'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Citation'), rdflib.term.Literal('0970'))
# (rdflib.term.URIRef('http://edamontology.org/data_0971'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Article'), rdflib.term.Literal('0971'))
# (rdflib.term.URIRef('http://edamontology.org/data_0972'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Text mining report'), rdflib.term.Literal('0972'))
# (rdflib.term.URIRef('http://edamontology.org/data_0974'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Entity identifier'), rdflib.term.Literal('0974'))
# (rdflib.term.URIRef('http://edamontology.org/data_0975'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Data resource identifier'), rdflib.term.Literal('0975'))
# (rdflib.term.URIRef('http://edamontology.org/data_0976'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Identifier (by type of data)'), rdflib.term.Literal('0976'))
# (rdflib.term.URIRef('http://edamontology.org/data_0977'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Tool identifier'), rdflib.term.Literal('0977'))
# (rdflib.term.URIRef('http://edamontology.org/data_0978'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Discrete entity identifier'), rdflib.term.Literal('0978'))
# (rdflib.term.URIRef('http://edamontology.org/data_0979'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Entity feature identifier'), rdflib.term.Literal('0979'))
# (rdflib.term.URIRef('http://edamontology.org/data_0980'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Entity collection identifier'), rdflib.term.Literal('0980'))
# (rdflib.term.URIRef('http://edamontology.org/data_0981'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Phenomenon identifier'), rdflib.term.Literal('0981'))
# (rdflib.term.URIRef('http://edamontology.org/data_0982'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Molecule identifier'), rdflib.term.Literal('0982'))
# (rdflib.term.URIRef('http://edamontology.org/data_0983'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Atom ID'), rdflib.term.Literal('0983'))
# (rdflib.term.URIRef('http://edamontology.org/data_0984'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Molecule name'), rdflib.term.Literal('0984'))
# (rdflib.term.URIRef('http://edamontology.org/data_0985'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Molecule type'), rdflib.term.Literal('0985'))
# (rdflib.term.URIRef('http://edamontology.org/data_0986'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Chemical identifier'), rdflib.term.Literal('0986'))
# (rdflib.term.URIRef('http://edamontology.org/data_0987'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Chromosome name'), rdflib.term.Literal('0987'))
# (rdflib.term.URIRef('http://edamontology.org/data_0988'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Peptide identifier'), rdflib.term.Literal('0988'))
# (rdflib.term.URIRef('http://edamontology.org/data_0989'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Protein identifier'), rdflib.term.Literal('0989'))
# (rdflib.term.URIRef('http://edamontology.org/data_0990'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Compound name'), rdflib.term.Literal('0990'))
# (rdflib.term.URIRef('http://edamontology.org/data_0991'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Chemical registry number'), rdflib.term.Literal('0991'))
# (rdflib.term.URIRef('http://edamontology.org/data_0992'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Ligand identifier'), rdflib.term.Literal('0992'))
# (rdflib.term.URIRef('http://edamontology.org/data_0993'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Drug identifier'), rdflib.term.Literal('0993'))
# (rdflib.term.URIRef('http://edamontology.org/data_0994'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Amino acid identifier'), rdflib.term.Literal('0994'))
# (rdflib.term.URIRef('http://edamontology.org/data_0995'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Nucleotide identifier'), rdflib.term.Literal('0995'))
# (rdflib.term.URIRef('http://edamontology.org/data_0996'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Monosaccharide identifier'), rdflib.term.Literal('0996'))
# (rdflib.term.URIRef('http://edamontology.org/data_0997'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Chemical name (ChEBI)'), rdflib.term.Literal('0997'))
# (rdflib.term.URIRef('http://edamontology.org/data_0998'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Chemical name (IUPAC)'), rdflib.term.Literal('0998'))
# (rdflib.term.URIRef('http://edamontology.org/data_0999'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Chemical name (INN)'), rdflib.term.Literal('0999'))
# (rdflib.term.URIRef('http://edamontology.org/data_1000'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Chemical name (brand)'), rdflib.term.Literal('1000'))
# (rdflib.term.URIRef('http://edamontology.org/data_1001'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Chemical name (synonymous)'), rdflib.term.Literal('1001'))
# (rdflib.term.URIRef('http://edamontology.org/data_1002'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('CAS number'), rdflib.term.Literal('1002'))
# (rdflib.term.URIRef('http://edamontology.org/data_1003'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Chemical registry number (Beilstein)'), rdflib.term.Literal('1003'))
# (rdflib.term.URIRef('http://edamontology.org/data_1004'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Chemical registry number (Gmelin)'), rdflib.term.Literal('1004'))
# (rdflib.term.URIRef('http://edamontology.org/data_1005'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('HET group name'), rdflib.term.Literal('1005'))
# (rdflib.term.URIRef('http://edamontology.org/data_1006'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Amino acid name'), rdflib.term.Literal('1006'))
# (rdflib.term.URIRef('http://edamontology.org/data_1007'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Nucleotide code'), rdflib.term.Literal('1007'))
# (rdflib.term.URIRef('http://edamontology.org/data_1008'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Polypeptide chain ID'), rdflib.term.Literal('1008'))
# (rdflib.term.URIRef('http://edamontology.org/data_1009'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Protein name'), rdflib.term.Literal('1009'))
# (rdflib.term.URIRef('http://edamontology.org/data_1010'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Enzyme identifier'), rdflib.term.Literal('1010'))
# (rdflib.term.URIRef('http://edamontology.org/data_1011'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('EC number'), rdflib.term.Literal('1011'))
# (rdflib.term.URIRef('http://edamontology.org/data_1012'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Enzyme name'), rdflib.term.Literal('1012'))
# (rdflib.term.URIRef('http://edamontology.org/data_1013'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Restriction enzyme name'), rdflib.term.Literal('1013'))
# (rdflib.term.URIRef('http://edamontology.org/data_1014'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Sequence position specification'), rdflib.term.Literal('1014'))
# (rdflib.term.URIRef('http://edamontology.org/data_1015'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Sequence feature ID'), rdflib.term.Literal('1015'))
# (rdflib.term.URIRef('http://edamontology.org/data_1016'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Sequence position'), rdflib.term.Literal('1016'))
# (rdflib.term.URIRef('http://edamontology.org/data_1017'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Sequence range'), rdflib.term.Literal('1017'))
# (rdflib.term.URIRef('http://edamontology.org/data_1018'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Nucleic acid feature identifier'), rdflib.term.Literal('1018'))
# (rdflib.term.URIRef('http://edamontology.org/data_1019'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Protein feature identifier'), rdflib.term.Literal('1019'))
# (rdflib.term.URIRef('http://edamontology.org/data_1020'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Sequence feature key'), rdflib.term.Literal('1020'))
# (rdflib.term.URIRef('http://edamontology.org/data_1021'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Sequence feature qualifier'), rdflib.term.Literal('1021'))
# (rdflib.term.URIRef('http://edamontology.org/data_1022'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Sequence feature label'), rdflib.term.Literal('1022'))
# (rdflib.term.URIRef('http://edamontology.org/data_1023'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('EMBOSS Uniform Feature Object'), rdflib.term.Literal('1023'))
# (rdflib.term.URIRef('http://edamontology.org/data_1024'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Codon name'), rdflib.term.Literal('1024'))
# (rdflib.term.URIRef('http://edamontology.org/data_1025'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Gene identifier'), rdflib.term.Literal('1025'))
# (rdflib.term.URIRef('http://edamontology.org/data_1026'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Gene symbol'), rdflib.term.Literal('1026'))
# (rdflib.term.URIRef('http://edamontology.org/data_1027'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Gene ID (NCBI)'), rdflib.term.Literal('1027'))
# (rdflib.term.URIRef('http://edamontology.org/data_1028'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Gene identifier (NCBI RefSeq)'), rdflib.term.Literal('1028'))
# (rdflib.term.URIRef('http://edamontology.org/data_1029'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Gene identifier (NCBI UniGene)'), rdflib.term.Literal('1029'))
# (rdflib.term.URIRef('http://edamontology.org/data_1030'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Gene identifier (Entrez)'), rdflib.term.Literal('1030'))
# (rdflib.term.URIRef('http://edamontology.org/data_1031'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Gene ID (CGD)'), rdflib.term.Literal('1031'))
# (rdflib.term.URIRef('http://edamontology.org/data_1032'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Gene ID (DictyBase)'), rdflib.term.Literal('1032'))
# (rdflib.term.URIRef('http://edamontology.org/data_1033'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Ensembl gene ID'), rdflib.term.Literal('1033'))
# (rdflib.term.URIRef('http://edamontology.org/data_1034'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Gene ID (SGD)'), rdflib.term.Literal('1034'))
# (rdflib.term.URIRef('http://edamontology.org/data_1035'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Gene ID (GeneDB)'), rdflib.term.Literal('1035'))
# (rdflib.term.URIRef('http://edamontology.org/data_1036'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('TIGR identifier'), rdflib.term.Literal('1036'))
# (rdflib.term.URIRef('http://edamontology.org/data_1037'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('TAIR accession (gene)'), rdflib.term.Literal('1037'))
# (rdflib.term.URIRef('http://edamontology.org/data_1038'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Protein domain ID'), rdflib.term.Literal('1038'))
# (rdflib.term.URIRef('http://edamontology.org/data_1039'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('SCOP domain identifier'), rdflib.term.Literal('1039'))
# (rdflib.term.URIRef('http://edamontology.org/data_1040'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('CATH domain ID'), rdflib.term.Literal('1040'))
# (rdflib.term.URIRef('http://edamontology.org/data_1041'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('SCOP concise classification string (sccs)'), rdflib.term.Literal('1041'))
# (rdflib.term.URIRef('http://edamontology.org/data_1042'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('SCOP sunid'), rdflib.term.Literal('1042'))
# (rdflib.term.URIRef('http://edamontology.org/data_1043'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('CATH node ID'), rdflib.term.Literal('1043'))
# (rdflib.term.URIRef('http://edamontology.org/data_1044'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Kingdom name'), rdflib.term.Literal('1044'))
# (rdflib.term.URIRef('http://edamontology.org/data_1045'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Species name'), rdflib.term.Literal('1045'))
# (rdflib.term.URIRef('http://edamontology.org/data_1046'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Strain name'), rdflib.term.Literal('1046'))
# (rdflib.term.URIRef('http://edamontology.org/data_1047'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('URI'), rdflib.term.Literal('1047'))
# (rdflib.term.URIRef('http://edamontology.org/data_1048'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Database ID'), rdflib.term.Literal('1048'))
# (rdflib.term.URIRef('http://edamontology.org/data_1049'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Directory name'), rdflib.term.Literal('1049'))
# (rdflib.term.URIRef('http://edamontology.org/data_1050'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('File name'), rdflib.term.Literal('1050'))
# (rdflib.term.URIRef('http://edamontology.org/data_1051'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Ontology name'), rdflib.term.Literal('1051'))
# (rdflib.term.URIRef('http://edamontology.org/data_1052'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('URL'), rdflib.term.Literal('1052'))
# (rdflib.term.URIRef('http://edamontology.org/data_1053'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('URN'), rdflib.term.Literal('1053'))
# (rdflib.term.URIRef('http://edamontology.org/data_1055'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('LSID'), rdflib.term.Literal('1055'))
# (rdflib.term.URIRef('http://edamontology.org/data_1056'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Database name'), rdflib.term.Literal('1056'))
# (rdflib.term.URIRef('http://edamontology.org/data_1057'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Sequence database name'), rdflib.term.Literal('1057'))
# (rdflib.term.URIRef('http://edamontology.org/data_1058'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Enumerated file name'), rdflib.term.Literal('1058'))
# (rdflib.term.URIRef('http://edamontology.org/data_1059'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('File name extension'), rdflib.term.Literal('1059'))
# (rdflib.term.URIRef('http://edamontology.org/data_1060'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('File base name'), rdflib.term.Literal('1060'))
# (rdflib.term.URIRef('http://edamontology.org/data_1061'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('QSAR descriptor name'), rdflib.term.Literal('1061'))
# (rdflib.term.URIRef('http://edamontology.org/data_1062'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Database entry identifier'), rdflib.term.Literal('1062'))
# (rdflib.term.URIRef('http://edamontology.org/data_1063'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Sequence identifier'), rdflib.term.Literal('1063'))
# (rdflib.term.URIRef('http://edamontology.org/data_1064'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Sequence set ID'), rdflib.term.Literal('1064'))
# (rdflib.term.URIRef('http://edamontology.org/data_1065'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Sequence signature identifier'), rdflib.term.Literal('1065'))
# (rdflib.term.URIRef('http://edamontology.org/data_1066'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Sequence alignment ID'), rdflib.term.Literal('1066'))
# (rdflib.term.URIRef('http://edamontology.org/data_1067'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Phylogenetic distance matrix identifier'), rdflib.term.Literal('1067'))
# (rdflib.term.URIRef('http://edamontology.org/data_1068'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Phylogenetic tree ID'), rdflib.term.Literal('1068'))
# ...
# (rdflib.term.URIRef('http://edamontology.org/topic_3528'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Disease pathways'), rdflib.term.Literal('3528'))
# (rdflib.term.URIRef('http://edamontology.org/topic_3529'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Environmental information processing pathways'), rdflib.term.Literal('3529'))
# (rdflib.term.URIRef('http://edamontology.org/topic_3530'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Genetic information processing pathways'), rdflib.term.Literal('3530'))
# (rdflib.term.URIRef('http://edamontology.org/topic_3531'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Protein super-secondary structure'), rdflib.term.Literal('3531'))
# (rdflib.term.URIRef('http://edamontology.org/topic_3533'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Protein active sites'), rdflib.term.Literal('3533'))
# (rdflib.term.URIRef('http://edamontology.org/topic_3534'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Protein binding sites'), rdflib.term.Literal('3534'))
# (rdflib.term.URIRef('http://edamontology.org/topic_3535'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Protein-nucleic acid binding sites'), rdflib.term.Literal('3535'))
# (rdflib.term.URIRef('http://edamontology.org/topic_3536'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Protein cleavage sites'), rdflib.term.Literal('3536'))
# (rdflib.term.URIRef('http://edamontology.org/topic_3537'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Protein chemical modifications'), rdflib.term.Literal('3537'))
# (rdflib.term.URIRef('http://edamontology.org/topic_3538'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Protein disordered structure'), rdflib.term.Literal('3538'))
# (rdflib.term.URIRef('http://edamontology.org/topic_3539'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Protein domains'), rdflib.term.Literal('3539'))
# (rdflib.term.URIRef('http://edamontology.org/topic_3540'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Protein key folding sites'), rdflib.term.Literal('3540'))
# (rdflib.term.URIRef('http://edamontology.org/topic_3541'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Protein post-translational modifications'), rdflib.term.Literal('3541'))
# (rdflib.term.URIRef('http://edamontology.org/topic_3542'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Protein secondary structure'), rdflib.term.Literal('3542'))
# (rdflib.term.URIRef('http://edamontology.org/topic_3543'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Protein sequence repeats'), rdflib.term.Literal('3543'))
# (rdflib.term.URIRef('http://edamontology.org/topic_3544'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Protein signal peptides'), rdflib.term.Literal('3544'))
# (rdflib.term.URIRef('http://edamontology.org/topic_3569'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Applied mathematics'), rdflib.term.Literal('3569'))
# (rdflib.term.URIRef('http://edamontology.org/topic_3570'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Pure mathematics'), rdflib.term.Literal('3570'))
# (rdflib.term.URIRef('http://edamontology.org/topic_3571'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Data governance'), rdflib.term.Literal('3571'))
# (rdflib.term.URIRef('http://edamontology.org/topic_3572'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Data quality management'), rdflib.term.Literal('3572'))
# (rdflib.term.URIRef('http://edamontology.org/topic_3573'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Freshwater biology'), rdflib.term.Literal('3573'))
# (rdflib.term.URIRef('http://edamontology.org/topic_3574'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Human genetics'), rdflib.term.Literal('3574'))
# (rdflib.term.URIRef('http://edamontology.org/topic_3575'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Tropical medicine'), rdflib.term.Literal('3575'))
# (rdflib.term.URIRef('http://edamontology.org/topic_3576'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Medical biotechnology'), rdflib.term.Literal('3576'))
# (rdflib.term.URIRef('http://edamontology.org/topic_3577'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Personalised medicine'), rdflib.term.Literal('3577'))
# (rdflib.term.URIRef('http://edamontology.org/topic_3656'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Immunoprecipitation experiment'), rdflib.term.Literal('3656'))
# (rdflib.term.URIRef('http://edamontology.org/topic_3673'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Whole genome sequencing'), rdflib.term.Literal('3673'))
# (rdflib.term.URIRef('http://edamontology.org/topic_3674'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Methylated DNA immunoprecipitation'), rdflib.term.Literal('3674'))
# (rdflib.term.URIRef('http://edamontology.org/topic_3676'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Exome sequencing'), rdflib.term.Literal('3676'))
# (rdflib.term.URIRef('http://edamontology.org/topic_3678'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Experimental design and studies'), rdflib.term.Literal('3678'))
# (rdflib.term.URIRef('http://edamontology.org/topic_3679'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Animal study'), rdflib.term.Literal('3679'))
# (rdflib.term.URIRef('http://edamontology.org/topic_3697'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Microbial ecology'), rdflib.term.Literal('3697'))
# (rdflib.term.URIRef('http://edamontology.org/topic_3794'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('RNA immunoprecipitation'), rdflib.term.Literal('3794'))
# (rdflib.term.URIRef('http://edamontology.org/topic_3796'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Population genomics'), rdflib.term.Literal('3796'))
# (rdflib.term.URIRef('http://edamontology.org/topic_3810'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Agricultural science'), rdflib.term.Literal('3810'))
# (rdflib.term.URIRef('http://edamontology.org/topic_3837'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Metagenomic sequencing'), rdflib.term.Literal('3837'))
# (rdflib.term.URIRef('http://edamontology.org/topic_3855'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Environmental sciences'), rdflib.term.Literal('3855'))
# (rdflib.term.URIRef('http://edamontology.org/topic_3892'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Biomolecular simulation'), rdflib.term.Literal('3892'))
# (rdflib.term.URIRef('http://edamontology.org/topic_3895'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Synthetic biology'), rdflib.term.Literal('3895'))
# (rdflib.term.URIRef('http://edamontology.org/topic_3912'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Genetic engineering'), rdflib.term.Literal('3912'))
# (rdflib.term.URIRef('http://edamontology.org/topic_3922'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Proteogenomics'), rdflib.term.Literal('3922'))
# (rdflib.term.URIRef('http://edamontology.org/topic_3930'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Immunogenetics'), rdflib.term.Literal('3930'))
# (rdflib.term.URIRef('http://edamontology.org/topic_3931'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Chemometrics'), rdflib.term.Literal('3931'))
# (rdflib.term.URIRef('http://edamontology.org/topic_3934'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Cytometry'), rdflib.term.Literal('3934'))
# (rdflib.term.URIRef('http://edamontology.org/topic_3939'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Metabolic engineering'), rdflib.term.Literal('3939'))
# (rdflib.term.URIRef('http://edamontology.org/topic_3940'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Chromosome conformation capture'), rdflib.term.Literal('3940'))
# (rdflib.term.URIRef('http://edamontology.org/topic_3941'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Metatranscriptomics'), rdflib.term.Literal('3941'))
# (rdflib.term.URIRef('http://edamontology.org/topic_3943'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Paleogenomics'), rdflib.term.Literal('3943'))
# (rdflib.term.URIRef('http://edamontology.org/topic_3944'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Cladistics'), rdflib.term.Literal('3944'))
# (rdflib.term.URIRef('http://edamontology.org/topic_3945'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Molecular evolution'), rdflib.term.Literal('3945'))
# (rdflib.term.URIRef('http://edamontology.org/topic_3948'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Immunoinformatics'), rdflib.term.Literal('3948'))
# (rdflib.term.URIRef('http://edamontology.org/topic_3954'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Echography'), rdflib.term.Literal('3954'))
# (rdflib.term.URIRef('http://edamontology.org/topic_3955'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Fluxomics'), rdflib.term.Literal('3955'))
# (rdflib.term.URIRef('http://edamontology.org/topic_3957'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Protein interaction experiment'), rdflib.term.Literal('3957'))
# (rdflib.term.URIRef('http://edamontology.org/topic_3958'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Copy number variation'), rdflib.term.Literal('3958'))
# (rdflib.term.URIRef('http://edamontology.org/topic_3959'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Cytogenetics'), rdflib.term.Literal('3959'))
# (rdflib.term.URIRef('http://edamontology.org/topic_3966'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Vaccinology'), rdflib.term.Literal('3966'))
# (rdflib.term.URIRef('http://edamontology.org/topic_3967'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Immunomics'), rdflib.term.Literal('3967'))
# (rdflib.term.URIRef('http://edamontology.org/topic_3974'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Epistasis'), rdflib.term.Literal('3974'))
# (rdflib.term.URIRef('http://edamontology.org/topic_4010'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Open science'), rdflib.term.Literal('4010'))
# (rdflib.term.URIRef('http://edamontology.org/topic_4011'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Data rescue'), rdflib.term.Literal('4011'))
# (rdflib.term.URIRef('http://edamontology.org/topic_4012'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('FAIR data'), rdflib.term.Literal('4012'))
# (rdflib.term.URIRef('http://edamontology.org/topic_4013'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Antimicrobial Resistance'), rdflib.term.Literal('4013'))
# (rdflib.term.URIRef('http://edamontology.org/topic_4014'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Electroencephalography'), rdflib.term.Literal('4014'))
# (rdflib.term.URIRef('http://edamontology.org/topic_4016'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Electrocardiography'), rdflib.term.Literal('4016'))
# (rdflib.term.URIRef('http://edamontology.org/topic_4017'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Cryogenic electron microscopy'), rdflib.term.Literal('4017'))
# (rdflib.term.URIRef('http://edamontology.org/topic_4019'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Biosciences'), rdflib.term.Literal('4019'))
# (rdflib.term.URIRef('http://edamontology.org/topic_4020'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Carbon cycle'), rdflib.term.Literal('4020'))
# (rdflib.term.URIRef('http://edamontology.org/topic_4021'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Multiomics'), rdflib.term.Literal('4021'))
# (rdflib.term.URIRef('http://edamontology.org/OUPS_4027'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Ribosome Profiling'), rdflib.term.Literal('4027'))
# (rdflib.term.URIRef('http://edamontology.org/topic_4028'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Single-Cell Sequencing'), rdflib.term.Literal('4028'))
# (rdflib.term.URIRef('http://edamontology.org/topic_4028'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Acoustics'), rdflib.term.Literal('4028'))
# (rdflib.term.URIRef('http://edamontology.org/topic_4033'), rdflib.term.URIRef('http://edamontology.org/next_id'), rdflib.term.Literal('4015'), rdflib.term.Literal('Microfluidics'), rdflib.term.Literal('4033'))
# 4034 4015
# error next id diff than max +1
