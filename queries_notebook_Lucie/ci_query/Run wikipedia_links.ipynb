# %%
from rdflib import ConjunctiveGraph, Namespace
import json
import os


# Constants for script error reporting as per https://github.com/edamontology/edamverify.
NOERR = "NOERR"
INFO  = "INFO"
WARN  = "WARN"
ERROR = "ERROR"

#Load EDAM_dev.owl from GitHub into an RDF graph.
print("Loading graph ...", end="")
g = ConjunctiveGraph()
g.load(os.environ.get('EDAM_PATH', '../edamontology/EDAM_dev.owl'), format='xml')
#g.load('https://raw.githubusercontent.com/edamontology/edamontology/master/EDAM_dev.owl', format='xml')
# g.load('EDAM_dev.owl', format='xml')
g.bind('edam', Namespace('http://edamontology.org#'))
print("done!")
# Out:
# Loading graph ...done!

# %%
    query = "check_wikipedia_link-Copy1.rq"
    with open(query,'r') as f:
        query_term = f.read()
  
        errfound = False
        report = list()
        results = g.query(query_term)
        print(f"{len(results)} EDAM classes with missing wikipedia link")

        for r in results :
            print(f"{r['entity']} ({r['label']}) {r['seealso']}")
            
    f.close()
# Out:
# 410 EDAM classes with missing wikipedia link
# http://edamontology.org/data_0863 (Sequence alignment) http://en.wikipedia.org/wiki/Sequence_alignment
# http://edamontology.org/data_0925 (Sequence assembly) http://en.wikipedia.org/wiki/Sequence_assembly
# http://edamontology.org/data_3932 (Q-value) https://en.wikipedia.org/wiki/Q-value_(statistics)%20
# http://edamontology.org/data_3949 (Profile HMM) https://en.wikipedia.org/wiki/HMMER#Profile_HMMs
# http://edamontology.org/format_1196 (SMILES) http://en.wikipedia.org/wiki/Simplified_molecular_input_line_entry_specification
# http://edamontology.org/format_1740 (iHOP format) https://en.wikipedia.org/wiki/Information_Hyperlinked_over_Proteins
# http://edamontology.org/format_1915 (Format) http://en.wikipedia.org/wiki/File_format
# http://edamontology.org/format_1915 (Format) http://en.wikipedia.org/wiki/List_of_file_formats
# http://edamontology.org/format_1961 (Stockholm format) http://en.wikipedia.org/wiki/Stockholm_format
# http://edamontology.org/format_2376 (RDF format) https://en.wikipedia.org/wiki/Resource_Description_Framework
# http://edamontology.org/format_3016 (VCF) https://en.wikipedia.org/wiki/Variant_Call_Format
# http://edamontology.org/format_3464 (JSON) https://en.wikipedia.org/wiki/JSON
# http://edamontology.org/format_3556 (MHTML) https://en.wikipedia.org/wiki/MHTML
# http://edamontology.org/format_3748 (Linked data format) https://en.wikipedia.org/wiki/Linked_data
# http://edamontology.org/format_3749 (JSON-LD) https://en.wikipedia.org/wiki/JSON-LD
# http://edamontology.org/format_3750 (YAML) https://en.wikipedia.org/wiki/YAML
# http://edamontology.org/format_3751 (DSV) https://en.wikipedia.org/wiki/Delimiter-separated_values
# http://edamontology.org/format_3777 (MCPD) https://en.wikipedia.org/wiki/Multi-Crop_Passport_Descriptor
# http://edamontology.org/format_3788 (SQL) https://en.wikipedia.org/wiki/SQL
# http://edamontology.org/format_3789 (XQuery) https://en.wikipedia.org/wiki/XQuery
# http://edamontology.org/format_3790 (SPARQL) https://en.wikipedia.org/wiki/SPARQL
# http://edamontology.org/format_3859 (JCAMP-DX) https://en.wikipedia.org/wiki/Mass_spectrometry_data_format#cite_note-3
# http://edamontology.org/format_3973 (Docker image) https://en.wikipedia.org/wiki/Docker_(software)
# http://edamontology.org/format_3981 (TAR format) https://en.wikipedia.org/wiki/Tar_(computing)
# http://edamontology.org/format_3986 (WMV) https://en.wikipedia.org/wiki/Windows_Media_Video
# http://edamontology.org/format_3987 (ZIP format) https://en.wikipedia.org/wiki/Zip_(file_format)
# http://edamontology.org/format_3989 (GZIP format) https://en.wikipedia.org/wiki/Gzip
# http://edamontology.org/format_3990 (AVI) https://en.wikipedia.org/wiki/Audio_Video_Interleave
# http://edamontology.org/format_3997 (MPEG-4) https://en.wikipedia.org/wiki/Moving_Picture_Experts_Group
# http://edamontology.org/format_4023 (cml) https://en.wikipedia.org/wiki/Chemical_Markup_Language
# http://edamontology.org/format_4024 (cif) https://en.wikipedia.org/wiki/Crystallographic_Information_File
# http://edamontology.org/operation_0004 (Operation) http://en.wikipedia.org/wiki/Function_(computer_science)
# http://edamontology.org/operation_0004 (Operation) http://en.wikipedia.org/wiki/Function_(mathematics)
# http://edamontology.org/operation_0004 (Operation) http://en.wikipedia.org/wiki/Subroutine
# http://edamontology.org/operation_0282 (Genetic mapping) https://en.wikipedia.org/wiki/Gene_mapping#Gene_mapping
# http://edamontology.org/operation_0291 (Sequence clustering) https://en.wikipedia.org/wiki/Sequence_clustering
# http://edamontology.org/operation_0292 (Sequence alignment) https://en.wikipedia.org/wiki/Sequence_alignment
# http://edamontology.org/operation_0295 (Structure alignment) https://en.wikipedia.org/wiki/Structural_alignment
# http://edamontology.org/operation_0302 (Protein threading) https://en.wikipedia.org/wiki/Threading_(protein_sequence)
# http://edamontology.org/operation_0306 (Text mining) https://en.wikipedia.org/wiki/Text_mining
# http://edamontology.org/operation_0308 (PCR primer design) https://en.wikipedia.org/wiki/Primer_(molecular_biology)#PCR_primer_design
# http://edamontology.org/operation_0310 (Sequence assembly) https://en.wikipedia.org/wiki/Sequence_assembly
# http://edamontology.org/operation_0314 (Gene expression profiling) https://en.wikipedia.org/wiki/Gene_expression_profiling
# http://edamontology.org/operation_0321 (Protein structure validation) https://en.wikipedia.org/wiki/Structure_validation
# http://edamontology.org/operation_0323 (Phylogenetic inference) https://en.wikipedia.org/wiki/Computational_phylogenetics
# http://edamontology.org/operation_0327 (Phylogenetic footprinting) https://en.wikipedia.org/wiki/Phylogenetic_footprinting
# http://edamontology.org/operation_0337 (Visualisation) https://en.wikipedia.org/wiki/Biological_data_visualization
# http://edamontology.org/operation_0363 (Reverse complement) https://en.wikipedia.org/wiki/Complementarity_(molecular_biology)
# http://edamontology.org/operation_0365 (Restriction digest) https://en.wikipedia.org/wiki/Restriction_digest
# http://edamontology.org/operation_0396 (Ramachandran plot calculation) https://en.wikipedia.org/wiki/Ramachandran_plot
# http://edamontology.org/operation_0400 (Protein pKa calculation) https://en.wikipedia.org/wiki/Protein_pKa_calculations
# http://edamontology.org/operation_0402 (Protein titration curve plotting) https://en.wikipedia.org/wiki/Titration_curve
# http://edamontology.org/operation_0474 (Protein structure prediction) https://en.wikipedia.org/wiki/Protein_structure_prediction
# http://edamontology.org/operation_0475 (Nucleic acid structure prediction) https://en.wikipedia.org/wiki/Nucleic_acid_structure_prediction
# http://edamontology.org/operation_0476 (Ab initio structure prediction) https://en.wikipedia.org/wiki/De_novo_protein_structure_prediction
# http://edamontology.org/operation_0477 (Protein modelling) https://en.wikipedia.org/wiki/Homology_modeling
# http://edamontology.org/operation_0478 (Molecular docking) https://en.wikipedia.org/wiki/Macromolecular_docking
# http://edamontology.org/operation_0478 (Molecular docking) https://en.wikipedia.org/wiki/Docking_(molecular)
# http://edamontology.org/operation_0481 (Loop modelling) https://en.wikipedia.org/wiki/Loop_modeling
# http://edamontology.org/operation_0482 (Protein-ligand docking) https://en.wikipedia.org/wiki/Virtual_screening
# http://edamontology.org/operation_0490 (Dot plot plotting) https://en.wikipedia.org/wiki/Dot_plot_(bioinformatics)
# http://edamontology.org/operation_0491 (Pairwise sequence alignment) https://en.wikipedia.org/wiki/Sequence_alignment#Pairwise_alignment
# http://edamontology.org/operation_0492 (Multiple sequence alignment) https://en.wikipedia.org/wiki/Multiple_sequence_alignment
# http://edamontology.org/operation_0495 (Local alignment) https://en.wikipedia.org/wiki/Sequence_alignment#Global_and_local_alignments
# http://edamontology.org/operation_0496 (Global alignment) https://en.wikipedia.org/wiki/Sequence_alignment#Global_and_local_alignments
# http://edamontology.org/operation_0523 (Mapping assembly) https://en.wikipedia.org/wiki/Sequence_assembly#De-novo_vs._mapping_assembly
# http://edamontology.org/operation_0524 (De-novo assembly) https://en.wikipedia.org/wiki/Sequence_assembly#De-novo_vs._mapping_assembly
# http://edamontology.org/operation_0525 (Genome assembly) https://en.wikipedia.org/wiki/Sequence_assembly#Genome_assemblers
# http://edamontology.org/operation_0526 (EST assembly) https://en.wikipedia.org/wiki/Sequence_assembly#EST_assemblers
# http://edamontology.org/operation_0531 (Heat map generation) https://en.wikipedia.org/wiki/Heat_map
# http://edamontology.org/operation_1777 (Protein function prediction) https://en.wikipedia.org/wiki/Protein_function_prediction
# http://edamontology.org/operation_1844 (Protein geometry validation) https://en.wikipedia.org/wiki/Ramachandran_plot
# http://edamontology.org/operation_2403 (Sequence analysis) https://en.wikipedia.org/wiki/Sequence_analysis
# http://edamontology.org/operation_2436 (Gene-set enrichment analysis) https://en.wikipedia.org/wiki/Gene_Ontology_Term_Enrichment
# http://edamontology.org/operation_2436 (Gene-set enrichment analysis) https://en.wikipedia.org/wiki/Gene_set_enrichment_analysis
# http://edamontology.org/operation_2454 (Gene prediction) https://en.wikipedia.org/wiki/Gene_prediction
# http://edamontology.org/operation_2476 (Molecular dynamics) https://en.wikipedia.org/wiki/Molecular_dynamics
# http://edamontology.org/operation_2485 (Helical wheel drawing) https://en.wikipedia.org/wiki/Helical_wheel
# http://edamontology.org/operation_2486 (Topology diagram drawing) https://en.wikipedia.org/wiki/Protein_topology
# http://edamontology.org/operation_2487 (Protein structure comparison) https://en.wikipedia.org/wiki/Protein_structure_comparison
# http://edamontology.org/operation_2489 (Subcellular localisation prediction) https://en.wikipedia.org/wiki/Subcellular_localization
# http://edamontology.org/operation_2495 (Expression analysis) https://en.wikipedia.org/w/index.php?title=Gene_expression_analysis
# http://edamontology.org/operation_2495 (Expression analysis) https://en.wikipedia.org/wiki/Gene_expression_profiling
# http://edamontology.org/operation_2520 (DNA mapping) https://en.wikipedia.org/wiki/Gene_mapping
# http://edamontology.org/operation_2575 (Binding site prediction) https://en.wikipedia.org/wiki/Binding_site
# http://edamontology.org/operation_2928 (Alignment) https://en.wikipedia.org/wiki/Alignment#Biology
# http://edamontology.org/operation_2938 (Dendrogram visualisation) https://en.wikipedia.org/wiki/Dendrogram
# http://edamontology.org/operation_2942 (Treemap visualisation) https://en.wikipedia.org/wiki/Treemapping
# http://edamontology.org/operation_2943 (Box-Whisker plot plotting) https://en.wikipedia.org/wiki/Box_plot
# http://edamontology.org/operation_2944 (Physical mapping) https://en.wikipedia.org/wiki/Gene_mapping#Physical_mapping
# http://edamontology.org/operation_3095 (Nucleic acid design) https://en.wikipedia.org/wiki/Nucleic_acid_design
# http://edamontology.org/operation_3200 (DNA barcoding) https://en.wikipedia.org/wiki/DNA_barcoding
# http://edamontology.org/operation_3214 (Spectral analysis) https://en.wikipedia.org/wiki/Spectral_analysis
# http://edamontology.org/operation_3279 (Document clustering) https://en.wikipedia.org/wiki/Document_clustering
# http://edamontology.org/operation_3280 (Named-entity and concept recognition) https://en.wikipedia.org/wiki/Concept_mining
# http://edamontology.org/operation_3280 (Named-entity and concept recognition) https://en.wikipedia.org/wiki/Named-entity_recognition
# http://edamontology.org/operation_3443 (Image analysis) https://en.wikipedia.org/wiki/Image_analysis
# http://edamontology.org/operation_3446 (Cell migration analysis) https://en.wikipedia.org/wiki/Cell_migration
# http://edamontology.org/operation_3457 (Single particle analysis) https://en.wikipedia.org/wiki/Single_particle_analysis
# http://edamontology.org/operation_3557 (Imputation) https://en.wikipedia.org/wiki/Imputation_(statistics)
# http://edamontology.org/operation_3658 (Statistical inference) https://en.wikipedia.org/wiki/Statistical_inference
# http://edamontology.org/operation_3659 (Regression analysis) https://en.wikipedia.org/wiki/Regression_analysis
# http://edamontology.org/operation_3660 (Metabolic network modelling) https://en.wikipedia.org/wiki/Metabolic_network_modelling
# http://edamontology.org/operation_3662 (Ab-initio gene prediction) https://en.wikipedia.org/wiki/Gene_prediction#Ab_initio_methods
# http://edamontology.org/operation_3663 (Homology-based gene prediction) https://en.wikipedia.org/wiki/Gene_prediction#Empirical_methods
# http://edamontology.org/operation_3664 (Statistical modelling) https://en.wikipedia.org/wiki/Statistical_model
# http://edamontology.org/operation_3778 (Text annotation) https://en.wikipedia.org/wiki/Text_annotation
# http://edamontology.org/operation_3797 (Rarefaction) https://en.wikipedia.org/wiki/Rarefaction_(ecology)
# http://edamontology.org/operation_3798 (Read binning) https://en.wikipedia.org/wiki/Binning_(metagenomics)
# http://edamontology.org/operation_3840 (Multilocus sequence typing) https://en.wikipedia.org/wiki/Multilocus_sequence_typing
# http://edamontology.org/operation_3894 (DNA profiling) https://en.wikipedia.org/wiki/DNA_profiling
# http://edamontology.org/operation_3896 (Active site prediction) https://en.wikipedia.org/wiki/Active_site
# http://edamontology.org/operation_3897 (Ligand-binding site prediction) https://en.wikipedia.org/wiki/Ligand_(biochemistry)
# http://edamontology.org/operation_3898 (Metal-binding site prediction) https://en.wikipedia.org/wiki/Metalloprotein
# http://edamontology.org/operation_3904 (Protein disorder prediction) https://en.wikipedia.org/wiki/Intrinsically_disordered_proteins
# http://edamontology.org/operation_3907 (Information extraction) https://en.wikipedia.org/wiki/Information_extraction
# http://edamontology.org/operation_3920 (DNA testing) https://en.wikipedia.org/wiki/Genetic_testing
# http://edamontology.org/operation_3927 (Network analysis) https://en.wikipedia.org/wiki/Network_theory#Biological_network_analysis
# http://edamontology.org/operation_3928 (Pathway analysis) https://en.wikipedia.org/wiki/Pathway_analysis
# http://edamontology.org/operation_3935 (Dimensionality reduction) https://en.wikipedia.org/wiki/Dimensionality_reduction
# http://edamontology.org/operation_3936 (Feature selection) https://en.wikipedia.org/wiki/Feature_selection
# http://edamontology.org/operation_3960 (Principal component analysis) https://en.wikipedia.org/wiki/Principal_component_analysis
# http://edamontology.org/operation_4008 (Protein design) https://en.wikipedia.org/wiki/Protein_design
# http://edamontology.org/topic_0077 (Nucleic acids) https://en.wikipedia.org/wiki/Nucleic_acid
# http://edamontology.org/topic_0078 (Proteins) https://en.wikipedia.org/wiki/Protein
# http://edamontology.org/topic_0080 (Sequence analysis) https://en.wikipedia.org/wiki/Sequence_analysis
# http://edamontology.org/topic_0081 (Structure analysis) https://en.wikipedia.org/wiki/Structural_bioinformatics
# http://edamontology.org/topic_0082 (Structure prediction) https://en.wikipedia.org/wiki/Nucleic_acid_structure_prediction
# http://edamontology.org/topic_0082 (Structure prediction) https://en.wikipedia.org/wiki/Protein_structure_prediction
# http://edamontology.org/topic_0084 (Phylogeny) https://en.wikipedia.org/wiki/Phylogenetic_tree
# http://edamontology.org/topic_0085 (Functional genomics) https://en.wikipedia.org/wiki/Functional_genomics
# http://edamontology.org/topic_0089 (Ontology and terminology) https://en.wikipedia.org/wiki/Ontology_(information_science)
# http://edamontology.org/topic_0091 (Bioinformatics) https://en.wikipedia.org/wiki/Bioinformatics
# http://edamontology.org/topic_0092 (Data visualisation) https://en.wikipedia.org/wiki/Data_visualization
# http://edamontology.org/topic_0097 (Nucleic acid structure analysis) https://en.wikipedia.org/wiki/Nucleic_acid_structure
# http://edamontology.org/topic_0099 (RNA) https://en.wikipedia.org/wiki/RNA
# http://edamontology.org/topic_0102 (Mapping) https://en.wikipedia.org/wiki/Gene_mapping
# http://edamontology.org/topic_0108 (Protein expression) https://en.wikipedia.org/wiki/Protein_expression
# http://edamontology.org/topic_0114 (Gene structure) https://en.wikipedia.org/wiki/Gene_structure
# http://edamontology.org/topic_0121 (Proteomics) https://en.wikipedia.org/wiki/Proteomics
# http://edamontology.org/topic_0122 (Structural genomics) https://en.wikipedia.org/wiki/Structural_genomics
# http://edamontology.org/topic_0128 (Protein interactions) https://en.wikipedia.org/wiki/Protein%E2%80%93protein_interaction
# http://edamontology.org/topic_0130 (Protein folding, stability and design) https://en.wikipedia.org/wiki/Protein_design
# http://edamontology.org/topic_0130 (Protein folding, stability and design) https://en.wikipedia.org/wiki/Protein_folding
# http://edamontology.org/topic_0140 (Protein targeting and localisation) https://en.wikipedia.org/wiki/Protein_targeting
# http://edamontology.org/topic_0152 (Carbohydrates) https://en.wikipedia.org/wiki/Carbohydrate
# http://edamontology.org/topic_0153 (Lipids) https://en.wikipedia.org/wiki/Lipid
# http://edamontology.org/topic_0154 (Small molecules) https://en.wikipedia.org/wiki/Metabolite
# http://edamontology.org/topic_0154 (Small molecules) https://en.wikipedia.org/wiki/Small_molecule
# http://edamontology.org/topic_0166 (Protein structural motifs and surfaces) https://en.wikipedia.org/wiki/Protein_structure#Domains,_motifs,_and_folds_in_protein_structure
# http://edamontology.org/topic_0176 (Molecular dynamics) https://en.wikipedia.org/wiki/Molecular_dynamics
# http://edamontology.org/topic_0194 (Phylogenomics) https://en.wikipedia.org/wiki/Phylogenomics
# http://edamontology.org/topic_0196 (Sequence assembly) https://en.wikipedia.org/wiki/Sequence_assembly
# http://edamontology.org/topic_0199 (Genetic variation) https://en.wikipedia.org/wiki/Genetic_variation
# http://edamontology.org/topic_0202 (Pharmacology) https://en.wikipedia.org/wiki/Pharmacology
# http://edamontology.org/topic_0203 (Gene expression) https://en.wikipedia.org/wiki/Gene_expression
# http://edamontology.org/topic_0204 (Gene regulation) https://en.wikipedia.org/wiki/Regulation_of_gene_expression
# http://edamontology.org/topic_0208 (Pharmacogenomics) https://en.wikipedia.org/wiki/Pharmacogenomics
# http://edamontology.org/topic_0209 (Medicinal chemistry) https://en.wikipedia.org/wiki/Medicinal_chemistry
# http://edamontology.org/topic_0218 (Natural language processing) https://en.wikipedia.org/wiki/Biomedical_text_mining
# http://edamontology.org/topic_0218 (Natural language processing) https://en.wikipedia.org/wiki/Natural_language_processing
# http://edamontology.org/topic_0218 (Natural language processing) https://en.wikipedia.org/wiki/Text_mining
# http://edamontology.org/topic_0593 (NMR) https://en.wikipedia.org/wiki/Nuclear_magnetic_resonance_spectroscopy
# http://edamontology.org/topic_0601 (Protein modifications) https://en.wikipedia.org/wiki/Post-translational_modification
# http://edamontology.org/topic_0602 (Molecular interactions, pathways and networks) https://en.wikipedia.org/wiki/Interactome
# http://edamontology.org/topic_0602 (Molecular interactions, pathways and networks) https://en.wikipedia.org/wiki/Metabolic_pathway
# http://edamontology.org/topic_0605 (Informatics) https://en.wikipedia.org/wiki/Informatics
# http://edamontology.org/topic_0607 (Laboratory information management) https://en.wikipedia.org/wiki/Laboratory_information_management_system
# http://edamontology.org/topic_0610 (Ecology) https://en.wikipedia.org/wiki/Ecology
# http://edamontology.org/topic_0611 (Electron microscopy) https://en.wikipedia.org/wiki/Electron_microscope
# http://edamontology.org/topic_0621 (Model organisms) https://en.wikipedia.org/wiki/Model_organism
# http://edamontology.org/topic_0622 (Genomics) https://en.wikipedia.org/wiki/Genomics
# http://edamontology.org/topic_0623 (Gene and protein families) https://en.wikipedia.org/wiki/Gene_family
# http://edamontology.org/topic_0623 (Gene and protein families) https://en.wikipedia.org/wiki/Protein_family
# http://edamontology.org/topic_0625 (Genotype and phenotype) https://en.wikipedia.org/wiki/Genotype%E2%80%93phenotype_distinction
# http://edamontology.org/topic_0634 (Pathology) https://en.wikipedia.org/wiki/Pathology
# http://edamontology.org/topic_0637 (Taxonomy) https://en.wikipedia.org/wiki/Taxonomy_(biology)
# http://edamontology.org/topic_0654 (DNA) https://en.wikipedia.org/wiki/DNA
# http://edamontology.org/topic_0659 (Functional, regulatory and non-coding RNA) https://en.wikipedia.org/wiki/Non-coding_RNA
# http://edamontology.org/topic_0736 (Protein folds and structural domains) https://en.wikipedia.org/wiki/Protein_superfamily
# http://edamontology.org/topic_0749 (Transcription factors and regulatory sites) https://en.wikipedia.org/wiki/Transcription_factor
# http://edamontology.org/topic_0749 (Transcription factors and regulatory sites) https://en.wikipedia.org/wiki/Transcriptional_regulation
# http://edamontology.org/topic_0769 (Workflows) https://en.wikipedia.org/wiki/Workflow
# http://edamontology.org/topic_0780 (Plant biology) https://en.wikipedia.org/wiki/Botany
# http://edamontology.org/topic_0781 (Virology) https://en.wikipedia.org/wiki/Virology
# http://edamontology.org/topic_0797 (Comparative genomics) https://en.wikipedia.org/wiki/Comparative_genomics
# http://edamontology.org/topic_0798 (Mobile genetic elements) https://en.wikipedia.org/wiki/Mobile_genetic_elements
# http://edamontology.org/topic_0804 (Immunology) https://en.wikipedia.org/wiki/Immunology
# http://edamontology.org/topic_0820 (Membrane and lipoproteins) https://en.wikipedia.org/wiki/Lipoprotein
# http://edamontology.org/topic_0820 (Membrane and lipoproteins) https://en.wikipedia.org/wiki/Membrane_protein
# http://edamontology.org/topic_0821 (Enzymes) https://en.wikipedia.org/wiki/Enzyme
# http://edamontology.org/topic_1317 (Structural biology) https://en.wikipedia.org/wiki/Structural_biology
# http://edamontology.org/topic_1775 (Function analysis) https://en.wikipedia.org/wiki/Functional_genomics#At_the_protein_level
# http://edamontology.org/topic_1775 (Function analysis) https://en.wikipedia.org/wiki/Protein_function_prediction
# http://edamontology.org/topic_2229 (Cell biology) https://en.wikipedia.org/wiki/Cell_biology
# http://edamontology.org/topic_2258 (Cheminformatics) https://en.wikipedia.org/wiki/Cheminformatics
# http://edamontology.org/topic_2259 (Systems biology) http://en.wikipedia.org/wiki/Systems_biology
# http://edamontology.org/topic_2269 (Statistics and probability) https://en.wikipedia.org/wiki/Probability
# http://edamontology.org/topic_2269 (Statistics and probability) https://en.wikipedia.org/wiki/Statistics
# http://edamontology.org/topic_2269 (Statistics and probability) http://en.wikipedia.org/wiki/Biostatistics
# http://edamontology.org/topic_2275 (Molecular modelling) https://en.wikipedia.org/wiki/Molecular_modelling
# http://edamontology.org/topic_2533 (DNA mutation) https://en.wikipedia.org/wiki/Mutation
# http://edamontology.org/topic_2640 (Oncology) https://en.wikipedia.org/wiki/Oncology
# http://edamontology.org/topic_2814 (Protein structure analysis) https://en.wikipedia.org/wiki/Protein_structure
# http://edamontology.org/topic_2815 (Human biology) https://en.wikipedia.org/wiki/Human_biology
# http://edamontology.org/topic_2828 (X-ray diffraction) https://en.wikipedia.org/wiki/X-ray_diffraction
# http://edamontology.org/topic_2830 (Immunoproteins and antigens) https://en.wikipedia.org/wiki/Antigen
# http://edamontology.org/topic_2830 (Immunoproteins and antigens) https://en.wikipedia.org/wiki/Immunoproteins
# http://edamontology.org/topic_2840 (Toxicology) https://en.wikipedia.org/wiki/Toxicology
# http://edamontology.org/topic_2885 (DNA polymorphism) https://en.wikipedia.org/wiki/Single-nucleotide_polymorphism
# http://edamontology.org/topic_3047 (Molecular biology) https://en.wikipedia.org/wiki/Molecular_biology
# http://edamontology.org/topic_3050 (Biodiversity) https://en.wikipedia.org/wiki/Biodiversity
# http://edamontology.org/topic_3053 (Genetics) https://en.wikipedia.org/wiki/Genetics
# http://edamontology.org/topic_3055 (Quantitative genetics) https://en.wikipedia.org/wiki/Quantitative_genetics
# http://edamontology.org/topic_3056 (Population genetics) https://en.wikipedia.org/wiki/Population_genetics
# http://edamontology.org/topic_3063 (Medical informatics) https://en.wikipedia.org/wiki/Health_informatics
# http://edamontology.org/topic_3064 (Developmental biology) https://en.wikipedia.org/wiki/Developmental_biology
# http://edamontology.org/topic_3065 (Embryology) https://en.wikipedia.org/wiki/Embryology
# http://edamontology.org/topic_3067 (Anatomy) https://en.wikipedia.org/wiki/Anatomy
# http://edamontology.org/topic_3070 (Biology) https://en.wikipedia.org/wiki/Biology
# http://edamontology.org/topic_3071 (Data management) https://en.wikipedia.org/wiki/Data_management
# http://edamontology.org/topic_3071 (Data management) https://en.wikipedia.org/wiki/Metadata_management
# http://edamontology.org/topic_3077 (Data acquisition) https://en.wikipedia.org/wiki/Data_acquisition
# http://edamontology.org/topic_3120 (Protein variants) https://en.wikipedia.org/wiki/Mutation
# http://edamontology.org/topic_3125 (DNA binding sites) https://en.wikipedia.org/wiki/DNA_binding_site
# http://edamontology.org/topic_3127 (DNA replication and recombination) https://en.wikipedia.org/wiki/DNA_recombination
# http://edamontology.org/topic_3127 (DNA replication and recombination) https://en.wikipedia.org/wiki/DNA_replication
# http://edamontology.org/topic_3168 (Sequencing) https://en.wikipedia.org/wiki/Sequencing
# http://edamontology.org/topic_3169 (ChIP-seq) https://en.wikipedia.org/wiki/ChIP-sequencing
# http://edamontology.org/topic_3170 (RNA-Seq) https://en.wikipedia.org/wiki/RNA-Seq
# http://edamontology.org/topic_3170 (RNA-Seq) https://en.wikipedia.org/wiki/Small_RNA_sequencing
# http://edamontology.org/topic_3172 (Metabolomics) https://en.wikipedia.org/wiki/Metabolomics
# http://edamontology.org/topic_3173 (Epigenomics) https://en.wikipedia.org/wiki/Epigenomics
# http://edamontology.org/topic_3174 (Metagenomics) https://en.wikipedia.org/wiki/Metagenomics
# http://edamontology.org/topic_3175 (Structural variation) https://en.wikipedia.org/wiki/Structural_variation
# http://edamontology.org/topic_3176 (DNA packaging) https://en.wikipedia.org/wiki/Chromosome#DNA_packaging
# http://edamontology.org/topic_3179 (ChIP-on-chip) https://en.wikipedia.org/wiki/ChIP-on-chip
# http://edamontology.org/topic_3263 (Data security) https://en.wikipedia.org/wiki/Data_security
# http://edamontology.org/topic_3277 (Sample collections) https://en.wikipedia.org/wiki/Biological_specimen
# http://edamontology.org/topic_3292 (Biochemistry) https://en.wikipedia.org/wiki/Biochemistry
# http://edamontology.org/topic_3293 (Phylogenetics) https://en.wikipedia.org/wiki/Phylogenetics
# http://edamontology.org/topic_3295 (Epigenetics) https://en.wikipedia.org/wiki/Epigenetics
# http://edamontology.org/topic_3297 (Biotechnology) https://en.wikipedia.org/wiki/Biotechnology
# http://edamontology.org/topic_3298 (Phenomics) https://en.wikipedia.org/wiki/Phenomics
# http://edamontology.org/topic_3299 (Evolutionary biology) https://en.wikipedia.org/wiki/Evolutionary_biology
# http://edamontology.org/topic_3300 (Physiology) https://en.wikipedia.org/wiki/Physiology
# http://edamontology.org/topic_3301 (Microbiology) https://en.wikipedia.org/wiki/Microbiology
# http://edamontology.org/topic_3302 (Parasitology) https://en.wikipedia.org/wiki/Parasitology
# http://edamontology.org/topic_3303 (Medicine) https://en.wikipedia.org/wiki/Medicine
# http://edamontology.org/topic_3304 (Neurobiology) https://en.wikipedia.org/wiki/Neuroscience
# http://edamontology.org/topic_3305 (Public health and epidemiology) https://en.wikipedia.org/wiki/Epidemiology
# http://edamontology.org/topic_3305 (Public health and epidemiology) https://en.wikipedia.org/wiki/Public_health
# http://edamontology.org/topic_3306 (Biophysics) https://en.wikipedia.org/wiki/Biophysics
# http://edamontology.org/topic_3307 (Computational biology) https://en.wikipedia.org/wiki/Computational_biology
# http://edamontology.org/topic_3308 (Transcriptomics) https://en.wikipedia.org/wiki/Transcriptomics_technologies
# http://edamontology.org/topic_3314 (Chemistry) https://en.wikipedia.org/wiki/Chemistry
# http://edamontology.org/topic_3315 (Mathematics) https://en.wikipedia.org/wiki/Mathematics
# http://edamontology.org/topic_3316 (Computer science) https://en.wikipedia.org/wiki/Computer_science
# http://edamontology.org/topic_3318 (Physics) https://en.wikipedia.org/wiki/Physics
# http://edamontology.org/topic_3320 (RNA splicing) https://en.wikipedia.org/wiki/RNA_splicing
# http://edamontology.org/topic_3321 (Molecular genetics) https://en.wikipedia.org/wiki/Molecular_genetics
# http://edamontology.org/topic_3322 (Respiratory medicine) https://en.wikipedia.org/wiki/Pulmonology
# http://edamontology.org/topic_3324 (Infectious disease) https://en.wikipedia.org/wiki/Infectious_disease_(medical_specialty)
# http://edamontology.org/topic_3325 (Rare diseases) https://en.wikipedia.org/wiki/Rare_disease
# http://edamontology.org/topic_3332 (Computational chemistry) https://en.wikipedia.org/wiki/Computational_chemistry
# http://edamontology.org/topic_3334 (Neurology) https://en.wikipedia.org/wiki/Neurology
# http://edamontology.org/topic_3335 (Cardiology) https://en.wikipedia.org/wiki/Cardiology
# http://edamontology.org/topic_3336 (Drug discovery) https://en.wikipedia.org/wiki/Drug_discovery
# http://edamontology.org/topic_3337 (Biobank) https://en.wikipedia.org/wiki/Biobank
# http://edamontology.org/topic_3338 (Mouse clinic) https://en.wikipedia.org/wiki/Laboratory_mouse
# http://edamontology.org/topic_3339 (Microbial collection) https://en.wikipedia.org/wiki/Microbiological_culture#Culture_collections
# http://edamontology.org/topic_3340 (Cell culture collection) https://en.wikipedia.org/wiki/Microbiological_culture#Culture_collections
# http://edamontology.org/topic_3341 (Clone library) https://en.wikipedia.org/wiki/Library_(biology)
# http://edamontology.org/topic_3342 (Translational medicine) https://en.wikipedia.org/wiki/Translational_medicine
# http://edamontology.org/topic_3343 (Compound libraries and screening) https://en.wikipedia.org/wiki/Chemical_library
# http://edamontology.org/topic_3344 (Biomedical science) https://en.wikipedia.org/wiki/Biomedical_sciences
# http://edamontology.org/topic_3360 (Biomarkers) https://en.wikipedia.org/wiki/Biomarker
# http://edamontology.org/topic_3361 (Laboratory techniques) https://en.wikipedia.org/wiki/Laboratory
# http://edamontology.org/topic_3365 (Data architecture, analysis and design) https://en.wikipedia.org/wiki/Data_architecture
# http://edamontology.org/topic_3366 (Data integration and warehousing) https://en.wikipedia.org/wiki/Data_integration
# http://edamontology.org/topic_3366 (Data integration and warehousing) https://en.wikipedia.org/wiki/Data_warehouse
# http://edamontology.org/topic_3368 (Biomaterials) https://en.wikipedia.org/wiki/Biomaterial
# http://edamontology.org/topic_3369 (Chemical biology) https://en.wikipedia.org/wiki/Chemical_biology
# http://edamontology.org/topic_3370 (Analytical chemistry) https://en.wikipedia.org/wiki/Analytical_chemistry
# http://edamontology.org/topic_3371 (Synthetic chemistry) https://en.wikipedia.org/wiki/Chemical_synthesis
# http://edamontology.org/topic_3372 (Software engineering) https://en.wikipedia.org/wiki/Software_engineering
# http://edamontology.org/topic_3373 (Drug development) https://en.wikipedia.org/wiki/Drug_development
# http://edamontology.org/topic_3375 (Drug metabolism) https://en.wikipedia.org/wiki/Drug_metabolism
# http://edamontology.org/topic_3376 (Medicines research and development) https://en.wikipedia.org/wiki/Drug_development
# http://edamontology.org/topic_3376 (Medicines research and development) https://en.wikipedia.org/wiki/Drug_discovery
# http://edamontology.org/topic_3377 (Safety sciences) https://en.wikipedia.org/wiki/Patient_safety
# http://edamontology.org/topic_3378 (Pharmacovigilance) https://en.wikipedia.org/wiki/Pharmacovigilance
# http://edamontology.org/topic_3379 (Preclinical and clinical studies) https://en.wikipedia.org/wiki/Clinical_trial
# http://edamontology.org/topic_3382 (Imaging) https://en.wikipedia.org/wiki/Imaging
# http://edamontology.org/topic_3383 (Bioimaging) https://en.wikipedia.org/wiki/Biological_imaging
# http://edamontology.org/topic_3384 (Medical imaging) https://en.wikipedia.org/wiki/Medical_imaging
# http://edamontology.org/topic_3385 (Light microscopy) https://en.wikipedia.org/wiki/Microscopy#Optical_microscopy
# http://edamontology.org/topic_3386 (Laboratory animal science) https://en.wikipedia.org/wiki/Animal_testing
# http://edamontology.org/topic_3387 (Marine biology) https://en.wikipedia.org/wiki/Marine_biology
# http://edamontology.org/topic_3388 (Molecular medicine) https://en.wikipedia.org/wiki/Molecular_medicine
# http://edamontology.org/topic_3390 (Nutritional science) https://en.wikipedia.org/wiki/Nutrition
# http://edamontology.org/topic_3391 (Omics) https://en.wikipedia.org/wiki/Omics
# http://edamontology.org/topic_3394 (Regulatory affairs) https://en.wikipedia.org/wiki/Regulatory_affairs#Healthcare_RA
# http://edamontology.org/topic_3395 (Regenerative medicine) https://en.wikipedia.org/wiki/Regenerative_medicine
# http://edamontology.org/topic_3396 (Systems medicine) https://en.wikipedia.org/wiki/Systems_medicine
# http://edamontology.org/topic_3397 (Veterinary medicine) https://en.wikipedia.org/wiki/Veterinary_medicine
# http://edamontology.org/topic_3398 (Bioengineering) https://en.wikipedia.org/wiki/Biological_engineering
# http://edamontology.org/topic_3399 (Geriatric medicine) https://en.wikipedia.org/wiki/Geriatrics
# http://edamontology.org/topic_3400 (Allergy, clinical immunology and immunotherapeutics) https://en.wikipedia.org/wiki/Allergy
# http://edamontology.org/topic_3400 (Allergy, clinical immunology and immunotherapeutics) https://en.wikipedia.org/wiki/Immunotherapy
# http://edamontology.org/topic_3400 (Allergy, clinical immunology and immunotherapeutics) https://en.wikipedia.org/wiki/Immunology#Clinical_immunology
# http://edamontology.org/topic_3401 (Pain medicine) https://en.wikipedia.org/wiki/Pain_management
# http://edamontology.org/topic_3402 (Anaesthesiology) https://en.wikipedia.org/wiki/Anesthesiology
# http://edamontology.org/topic_3403 (Critical care medicine) https://en.wikipedia.org/wiki/Intensive_care_medicine
# http://edamontology.org/topic_3404 (Dermatology) https://en.wikipedia.org/wiki/Dermatology
# http://edamontology.org/topic_3405 (Dentistry) https://en.wikipedia.org/wiki/Dentistry
# http://edamontology.org/topic_3406 (Ear, nose and throat medicine) https://en.wikipedia.org/wiki/Otorhinolaryngology
# http://edamontology.org/topic_3407 (Endocrinology and metabolism) https://en.wikipedia.org/wiki/Endocrinology
# http://edamontology.org/topic_3408 (Haematology) https://en.wikipedia.org/wiki/Hematology
# http://edamontology.org/topic_3409 (Gastroenterology) https://en.wikipedia.org/wiki/Gastroenterology
# http://edamontology.org/topic_3410 (Gender medicine) https://en.wikipedia.org/wiki/Sex_differences_in_medicine
# http://edamontology.org/topic_3411 (Gynaecology and obstetrics) https://en.wikipedia.org/wiki/Gynaecology
# http://edamontology.org/topic_3411 (Gynaecology and obstetrics) https://en.wikipedia.org/wiki/Obstetrics
# http://edamontology.org/topic_3412 (Hepatic and biliary medicine) https://en.wikipedia.org/wiki/Hepatology
# http://edamontology.org/topic_3414 (Trauma medicine) https://en.wikipedia.org/wiki/Traumatology
# http://edamontology.org/topic_3415 (Medical toxicology) https://en.wikipedia.org/wiki/Medical_toxicology
# http://edamontology.org/topic_3416 (Musculoskeletal medicine) https://en.wikipedia.org/wiki/Musculoskeletal_physiology
# http://edamontology.org/topic_3416 (Musculoskeletal medicine) https://en.wikipedia.org/wiki/Orthopedic_surgery
# http://edamontology.org/topic_3416 (Musculoskeletal medicine) https://en.wikipedia.org/wiki/Rheumatology
# http://edamontology.org/topic_3417 (Opthalmology) https://en.wikipedia.org/wiki/Ophthalmology
# http://edamontology.org/topic_3418 (Paediatrics) https://en.wikipedia.org/wiki/Pediatrics
# http://edamontology.org/topic_3419 (Psychiatry) https://en.wikipedia.org/wiki/Psychiatry
# http://edamontology.org/topic_3420 (Reproductive health) https://en.wikipedia.org/wiki/Reproductive_health
# http://edamontology.org/topic_3421 (Surgery) https://en.wikipedia.org/wiki/Surgery
# http://edamontology.org/topic_3422 (Urology and nephrology) https://en.wikipedia.org/wiki/Nephrology
# http://edamontology.org/topic_3422 (Urology and nephrology) https://en.wikipedia.org/wiki/Urology
# http://edamontology.org/topic_3423 (Complementary medicine) https://en.wikipedia.org/wiki/Alternative_medicine
# http://edamontology.org/topic_3444 (MRI) https://en.wikipedia.org/wiki/Magnetic_resonance_imaging
# http://edamontology.org/topic_3448 (Neutron diffraction) https://en.wikipedia.org/wiki/Neutron_diffraction
# http://edamontology.org/topic_3452 (Tomography) https://en.wikipedia.org/wiki/Tomography
# http://edamontology.org/topic_3473 (Data mining) https://en.wikipedia.org/wiki/Data_mining
# http://edamontology.org/topic_3474 (Machine learning) https://en.wikipedia.org/wiki/Machine_learning
# http://edamontology.org/topic_3489 (Database management) https://en.wikipedia.org/wiki/Database
# http://edamontology.org/topic_3500 (Zoology) https://en.wikipedia.org/wiki/Zoology
# http://edamontology.org/topic_3512 (Gene transcripts) https://en.wikipedia.org/wiki/Primary_transcript
# http://edamontology.org/topic_3516 (Genotyping experiment) https://en.wikipedia.org/wiki/Genotyping
# http://edamontology.org/topic_3517 (GWAS study) https://en.wikipedia.org/wiki/Genome-wide_association_study
# http://edamontology.org/topic_3518 (Microarray experiment) https://en.wikipedia.org/wiki/Microarray
# http://edamontology.org/topic_3519 (PCR experiment) https://en.wikipedia.org/wiki/Polymerase_chain_reaction
# http://edamontology.org/topic_3520 (Proteomics experiment) https://en.wikipedia.org/wiki/Proteomics
# http://edamontology.org/topic_3520 (Proteomics experiment) https://en.wikipedia.org/wiki/Proteomics_Standards_Initiative
# http://edamontology.org/topic_3523 (RNAi experiment) https://en.wikipedia.org/wiki/RNA_interference
# http://edamontology.org/topic_3534 (Protein binding sites) https://en.wikipedia.org/wiki/Binding_site
# http://edamontology.org/topic_3538 (Protein disordered structure) https://en.wikipedia.org/wiki/Intrinsically_disordered_proteins
# http://edamontology.org/topic_3542 (Protein secondary structure) https://en.wikipedia.org/wiki/Protein_secondary_structure
# http://edamontology.org/topic_3569 (Applied mathematics) https://en.wikipedia.org/wiki/Applied_mathematics
# http://edamontology.org/topic_3570 (Pure mathematics) https://en.wikipedia.org/wiki/Pure_mathematics
# http://edamontology.org/topic_3571 (Data governance) https://en.wikipedia.org/wiki/Data_governance
# http://edamontology.org/topic_3572 (Data quality management) https://en.wikipedia.org/wiki/Data_quality
# http://edamontology.org/topic_3573 (Freshwater biology) https://en.wikipedia.org/wiki/Freshwater_biology
# http://edamontology.org/topic_3574 (Human genetics) https://en.wikipedia.org/wiki/Human_genetics
# http://edamontology.org/topic_3575 (Tropical medicine) https://en.wikipedia.org/wiki/Tropical_medicine
# http://edamontology.org/topic_3576 (Medical biotechnology) https://en.wikipedia.org/wiki/Biotechnology#Medicine
# http://edamontology.org/topic_3577 (Personalised medicine) https://en.wikipedia.org/wiki/Personalized_medicine
# http://edamontology.org/topic_3656 (Immunoprecipitation experiment) https://en.wikipedia.org/wiki/Immunoprecipitation
# http://edamontology.org/topic_3673 (Whole genome sequencing) https://en.wikipedia.org/wiki/Whole_genome_sequencing
# http://edamontology.org/topic_3674 (Methylated DNA immunoprecipitation) https://en.wikipedia.org/wiki/Methylated_DNA_immunoprecipitation
# http://edamontology.org/topic_3676 (Exome sequencing) https://en.wikipedia.org/wiki/Exome_sequencing
# http://edamontology.org/topic_3678 (Experimental design and studies) https://en.wikipedia.org/wiki/Design_of_experiments
# http://edamontology.org/topic_3679 (Animal study) https://en.wikipedia.org/wiki/Animal_testing
# http://edamontology.org/topic_3697 (Microbial ecology) https://en.wikipedia.org/wiki/Microbial_ecology
# http://edamontology.org/topic_3794 (RNA immunoprecipitation) https://en.wikipedia.org/wiki/Immunoprecipitation#RNA_immunoprecipitation_(RIP)
# http://edamontology.org/topic_3796 (Population genomics) https://en.wikipedia.org/wiki/Population_genomics
# http://edamontology.org/topic_3810 (Agricultural science) https://en.wikipedia.org/wiki/Agricultural_science
# http://edamontology.org/topic_3837 (Metagenomic sequencing) https://en.wikipedia.org/wiki/Metagenomics
# http://edamontology.org/topic_3855 (Environmental sciences) https://en.wikipedia.org/wiki/Environmental_science
# http://edamontology.org/topic_3895 (Synthetic biology) https://en.wikipedia.org/wiki/Synthetic_biology
# http://edamontology.org/topic_3912 (Genetic engineering) https://en.wikipedia.org/wiki/Genetic_engineering
# http://edamontology.org/topic_3922 (Proteogenomics) https://en.wikipedia.org/wiki/Proteogenomics
# http://edamontology.org/topic_3930 (Immunogenetics) https://en.wikipedia.org/wiki/Immunogenetics
# http://edamontology.org/topic_3931 (Chemometrics) https://en.wikipedia.org/wiki/Chemometrics
# http://edamontology.org/topic_3934 (Cytometry) https://en.wikipedia.org/wiki/Cytometry
# http://edamontology.org/topic_3939 (Metabolic engineering) https://en.wikipedia.org/wiki/Metabolic_engineering
# http://edamontology.org/topic_3940 (Chromosome conformation capture) https://en.wikipedia.org/wiki/Chromosome_conformation_capture
# http://edamontology.org/topic_3941 (Metatranscriptomics) https://en.wikipedia.org/wiki/Metatranscriptomics
# http://edamontology.org/topic_3943 (Paleogenomics) https://en.wikipedia.org/wiki/Paleogenomics
# http://edamontology.org/topic_3944 (Cladistics) https://en.wikipedia.org/wiki/Cladistics
# http://edamontology.org/topic_3945 (Molecular evolution) https://en.wikipedia.org/wiki/Molecular_evolution
# http://edamontology.org/topic_3948 (Immunoinformatics) https://en.wikipedia.org/wiki/Computational_immunology
# http://edamontology.org/topic_3954 (Echography) https://en.wikipedia.org/wiki/Medical_ultrasound
# http://edamontology.org/topic_3955 (Fluxomics) https://en.wikipedia.org/wiki/Fluxomics
# http://edamontology.org/topic_3957 (Protein interaction experiment) https://en.wikipedia.org/wiki/Protein%E2%80%93protein_interaction
# http://edamontology.org/topic_3958 (Copy number variation) https://en.wikipedia.org/wiki/Copy-number_variation
# http://edamontology.org/topic_3959 (Cytogenetics) https://en.wikipedia.org/wiki/Cytogenetics
# http://edamontology.org/topic_3966 (Vaccinology) https://en.wikipedia.org/wiki/Vaccine
# http://edamontology.org/topic_3967 (Immunomics) https://en.wikipedia.org/wiki/Immunomics
# http://edamontology.org/topic_3974 (Epistasis) https://en.wikipedia.org/wiki/Epistasis
# http://edamontology.org/topic_4010 (Open science) https://en.wikipedia.org/wiki/Open_science
# http://edamontology.org/topic_4011 (Data rescue) https://en.wikipedia.org/wiki/Data_rescue
# http://edamontology.org/topic_4012 (FAIR data) https://en.wikipedia.org/wiki/FAIR_data
# http://edamontology.org/topic_4012 (FAIR data) https://en.wikipedia.org/wiki/Open_data
# http://edamontology.org/topic_4013 (Antimicrobial Resistance) https://en.wikipedia.org/wiki/Antimicrobial_resistance
# http://edamontology.org/topic_4014 (Electroencephalography) https://en.wikipedia.org/wiki/Electroencephalography
# http://edamontology.org/topic_4016 (Electrocardiography) https://en.wikipedia.org/wiki/Electrocardiography
# http://edamontology.org/topic_4017 (Cryogenic electron microscopy) https://en.wikipedia.org/wiki/Cryogenic_electron_microscopy
# http://edamontology.org/topic_4019 (Biosciences) https://en.wikipedia.org/wiki/List_of_life_sciences
# http://edamontology.org/topic_4020 (Carbon cycle) https://en.wikipedia.org/wiki/Carbon_cycle
# http://edamontology.org/topic_4020 (Carbon cycle) https://en.wikipedia.org/wiki/Biogeochemical_cycle
# http://edamontology.org/topic_4021 (Multiomics) https://en.wikipedia.org/wiki/Multiomics
# http://edamontology.org/topic_4027 (Ribosome Profiling) https://en.wikipedia.org/wiki/Ribosome_profiling
