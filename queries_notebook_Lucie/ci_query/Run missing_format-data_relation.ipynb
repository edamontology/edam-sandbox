# %%
from rdflib import ConjunctiveGraph, Namespace
import json
import os


# Constants for script error reporting as per https://github.com/edamontology/edamverify.
NOERR = "NOERR"
INFO  = "INFO"
WARN  = "WARN"
ERROR = "ERROR"

#Load EDAM_dev.owl from GitHub into an RDF graph.
print("Loading graph ...", end="")
g = ConjunctiveGraph()
g.load(os.environ.get('EDAM_PATH', '../edamontology/EDAM_dev.owl'), format='xml')
#g.load('https://raw.githubusercontent.com/edamontology/edamontology/master/EDAM_dev.owl', format='xml')
# g.load('EDAM_dev.owl', format='xml')
g.bind('edam', Namespace('http://edamontology.org#'))
print("done!")
# Out:
# Loading graph ...done!

# %%
    query = "missing_format-data_relation.rq"
    with open(query,'r') as f:
        query_term = f.read()
  
        errfound = False
        report = list()
        results = g.query(query_term)
        print(len(results))
        for r in results:
            print(f"{r['entity']} , '{r['label']}', is missing mandatory format property: {r['property']}  ")
    f.close()
# Out:
# 874
# http://edamontology.org/data_0842 , 'Identifier', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_0844 , 'Molecular mass', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_0845 , 'Molecular charge', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_0847 , 'QSAR descriptor', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_0850 , 'Sequence set', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_0856 , 'Sequence feature source', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_0860 , 'Sequence signature data', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_0862 , 'Dotplot', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_0865 , 'Sequence similarity score', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_0867 , 'Sequence alignment report', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_0874 , 'Comparison matrix', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_0878 , 'Protein secondary structure alignment', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_0881 , 'RNA secondary structure alignment', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_0886 , 'Structure alignment', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_0887 , 'Structure alignment report', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_0888 , 'Structure similarity score', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_0889 , 'Structural profile', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_0890 , 'Structural (3D) profile alignment', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_0892 , 'Protein sequence-structure scoring matrix', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_0893 , 'Sequence-structure alignment', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_0897 , 'Protein property', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_0905 , 'Protein interaction raw data', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_0909 , 'Vmax', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_0910 , 'Km', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_0912 , 'Nucleic acid property', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_0914 , 'Codon usage data', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_0919 , 'Chromosome report', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_0920 , 'Genotype/phenotype report', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_0926 , 'RH scores', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_0927 , 'Genetic linkage report', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_0928 , 'Gene expression profile', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_0937 , 'Electron density map', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_0938 , 'Raw NMR data', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_0939 , 'CD spectra', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_0940 , 'Volume map', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_0942 , '2D PAGE image', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_0943 , 'Mass spectrum', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_0944 , 'Peptide mass fingerprint', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_0945 , 'Peptide identification', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_0949 , 'Workflow metadata', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_0950 , 'Mathematical model', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_0951 , 'Statistical estimate score', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_0954 , 'Database cross-mapping', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_0956 , 'Data index report', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_0957 , 'Database metadata', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_0958 , 'Tool metadata', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_0960 , 'User metadata', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_0963 , 'Cell line report', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_0966 , 'Ontology term', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_0967 , 'Ontology concept data', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_0968 , 'Keyword', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_0976 , 'Identifier (by type of data)', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_0977 , 'Tool identifier', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_0982 , 'Molecule identifier', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_0983 , 'Atom ID', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_0984 , 'Molecule name', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_0987 , 'Chromosome name', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_0988 , 'Peptide identifier', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_0989 , 'Protein identifier', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_0990 , 'Compound name', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_0991 , 'Chemical registry number', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_0993 , 'Drug identifier', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_0994 , 'Amino acid identifier', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_0995 , 'Nucleotide identifier', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_0996 , 'Monosaccharide identifier', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_0997 , 'Chemical name (ChEBI)', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_0998 , 'Chemical name (IUPAC)', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_0999 , 'Chemical name (INN)', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1000 , 'Chemical name (brand)', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1001 , 'Chemical name (synonymous)', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1002 , 'CAS number', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1003 , 'Chemical registry number (Beilstein)', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1004 , 'Chemical registry number (Gmelin)', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1005 , 'HET group name', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1006 , 'Amino acid name', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1007 , 'Nucleotide code', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1008 , 'Polypeptide chain ID', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1009 , 'Protein name', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1010 , 'Enzyme identifier', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1011 , 'EC number', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1012 , 'Enzyme name', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1013 , 'Restriction enzyme name', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1015 , 'Sequence feature ID', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1016 , 'Sequence position', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1020 , 'Sequence feature key', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1021 , 'Sequence feature qualifier', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1022 , 'Sequence feature label', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1023 , 'EMBOSS Uniform Feature Object', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1025 , 'Gene identifier', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1026 , 'Gene symbol', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1027 , 'Gene ID (NCBI)', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1031 , 'Gene ID (CGD)', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1032 , 'Gene ID (DictyBase)', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1033 , 'Ensembl gene ID', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1034 , 'Gene ID (SGD)', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1035 , 'Gene ID (GeneDB)', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1036 , 'TIGR identifier', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1037 , 'TAIR accession (gene)', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1038 , 'Protein domain ID', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1039 , 'SCOP domain identifier', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1040 , 'CATH domain ID', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1041 , 'SCOP concise classification string (sccs)', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1042 , 'SCOP sunid', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1043 , 'CATH node ID', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1044 , 'Kingdom name', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1045 , 'Species name', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1046 , 'Strain name', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1047 , 'URI', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1048 , 'Database ID', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1049 , 'Directory name', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1050 , 'File name', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1051 , 'Ontology name', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1052 , 'URL', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1053 , 'URN', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1055 , 'LSID', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1056 , 'Database name', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1058 , 'Enumerated file name', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1059 , 'File name extension', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1060 , 'File base name', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1061 , 'QSAR descriptor name', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1063 , 'Sequence identifier', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1064 , 'Sequence set ID', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1066 , 'Sequence alignment ID', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1068 , 'Phylogenetic tree ID', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1069 , 'Comparison matrix identifier', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1070 , 'Structure ID', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1071 , 'Structural (3D) profile ID', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1072 , 'Structure alignment ID', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1073 , 'Amino acid index ID', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1074 , 'Protein interaction ID', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1075 , 'Protein family identifier', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1076 , 'Codon usage table name', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1077 , 'Transcription factor identifier', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1078 , 'Experiment annotation ID', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1079 , 'Electron microscopy model ID', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1080 , 'Gene expression report ID', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1081 , 'Genotype and phenotype annotation ID', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1082 , 'Pathway or network identifier', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1083 , 'Workflow ID', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1084 , 'Data resource definition ID', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1085 , 'Biological model ID', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1086 , 'Compound identifier', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1087 , 'Ontology concept ID', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1088 , 'Article ID', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1089 , 'FlyBase ID', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1091 , 'WormBase name', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1092 , 'WormBase class', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1093 , 'Sequence accession', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1095 , 'EMBOSS Uniform Sequence Address', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1096 , 'Sequence accession (protein)', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1097 , 'Sequence accession (nucleic acid)', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1098 , 'RefSeq accession', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1100 , 'PIR identifier', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1102 , 'Gramene primary identifier', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1103 , 'EMBL/GenBank/DDBJ ID', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1104 , 'Sequence cluster ID (UniGene)', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1105 , 'dbEST accession', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1106 , 'dbSNP ID', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1112 , 'Sequence cluster ID', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1113 , 'Sequence cluster ID (COG)', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1114 , 'Sequence motif identifier', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1115 , 'Sequence profile ID', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1116 , 'ELM ID', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1117 , 'Prosite accession number', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1118 , 'HMMER hidden Markov model ID', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1119 , 'JASPAR profile ID', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1123 , 'TreeBASE study accession number', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1124 , 'TreeFam accession number', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1126 , 'Comparison matrix name', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1127 , 'PDB ID', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1128 , 'AAindex ID', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1129 , 'BIND accession number', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1130 , 'IntAct accession number', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1131 , 'Protein family name', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1132 , 'InterPro entry name', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1133 , 'InterPro accession', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1134 , 'InterPro secondary accession', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1135 , 'Gene3D ID', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1136 , 'PIRSF ID', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1137 , 'PRINTS code', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1138 , 'Pfam accession number', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1139 , 'SMART accession number', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1140 , 'Superfamily hidden Markov model number', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1141 , 'TIGRFam ID', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1142 , 'ProDom accession number', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1143 , 'TRANSFAC accession number', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1144 , 'ArrayExpress accession number', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1145 , 'PRIDE experiment accession number', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1146 , 'EMDB ID', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1147 , 'GEO accession number', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1148 , 'GermOnline ID', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1149 , 'EMAGE ID', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1150 , 'Disease ID', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1151 , 'HGVbase ID', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1153 , 'OMIM ID', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1154 , 'KEGG object identifier', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1155 , 'Pathway ID (reactome)', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1157 , 'Pathway ID (BioCyc)', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1158 , 'Pathway ID (INOH)', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1159 , 'Pathway ID (PATIKA)', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1160 , 'Pathway ID (CPDB)', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1161 , 'Pathway ID (Panther)', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1162 , 'MIRIAM identifier', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1163 , 'MIRIAM data type name', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1164 , 'MIRIAM URI', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1165 , 'MIRIAM data type primary name', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1166 , 'MIRIAM data type synonymous name', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1167 , 'Taverna workflow ID', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1170 , 'Biological model name', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1171 , 'BioModel ID', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1172 , 'PubChem CID', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1173 , 'ChemSpider ID', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1174 , 'ChEBI ID', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1175 , 'BioPax concept ID', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1176 , 'GO concept ID', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1177 , 'MeSH concept ID', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1178 , 'HGNC concept ID', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1179 , 'NCBI taxonomy ID', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1180 , 'Plant Ontology concept ID', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1181 , 'UMLS concept ID', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1182 , 'FMA concept ID', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1183 , 'EMAP concept ID', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1184 , 'ChEBI concept ID', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1185 , 'MGED concept ID', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1186 , 'myGrid concept ID', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1187 , 'PubMed ID', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1188 , 'DOI', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1189 , 'Medline UI', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1190 , 'Tool name', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1191 , 'Tool name (signature)', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1192 , 'Tool name (BLAST)', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1193 , 'Tool name (FASTA)', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1194 , 'Tool name (EMBOSS)', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1195 , 'Tool name (EMBASSY package)', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1201 , 'QSAR descriptor (constitutional)', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1202 , 'QSAR descriptor (electronic)', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1203 , 'QSAR descriptor (geometrical)', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1204 , 'QSAR descriptor (topological)', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1205 , 'QSAR descriptor (molecular)', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1233 , 'Sequence set (protein)', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1234 , 'Sequence set (nucleic acid)', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1238 , 'Proteolytic digest', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1239 , 'Restriction digest', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1240 , 'PCR primers', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1245 , 'Sequence cluster (protein)', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1246 , 'Sequence cluster (nucleic acid)', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1249 , 'Sequence length', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1254 , 'Sequence property', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1259 , 'Sequence complexity report', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1260 , 'Sequence ambiguity report', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1261 , 'Sequence composition report', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1262 , 'Peptide molecular weight hits', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1263 , 'Base position variability plot', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1265 , 'Base frequencies table', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1266 , 'Base word frequencies table', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1267 , 'Amino acid frequencies table', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1268 , 'Amino acid word frequencies table', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1270 , 'Feature table', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1276 , 'Nucleic acid features', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1277 , 'Protein features', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1278 , 'Genetic map', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1279 , 'Sequence map', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1280 , 'Physical map', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1283 , 'Cytogenetic map', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1284 , 'DNA transduction map', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1285 , 'Gene map', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1286 , 'Plasmid map', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1288 , 'Genome map', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1289 , 'Restriction map', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1352 , 'Regular expression', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1355 , 'Protein signature', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1361 , 'Position frequency matrix', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1362 , 'Position weight matrix', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1363 , 'Information content matrix', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1365 , 'Fingerprint', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1383 , 'Nucleic acid sequence alignment', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1384 , 'Protein sequence alignment', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1385 , 'Hybrid sequence alignment', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1394 , 'Alignment score or penalty', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1397 , 'Gap opening penalty', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1398 , 'Gap extension penalty', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1399 , 'Gap separation penalty', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1401 , 'Match reward score', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1402 , 'Mismatch penalty score', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1403 , 'Drop off score', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1410 , 'Terminal gap opening penalty', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1411 , 'Terminal gap extension penalty', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1412 , 'Sequence identity', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1413 , 'Sequence similarity', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1439 , 'DNA substitution model', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1444 , 'Phylogenetic character contrasts', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1448 , 'Comparison matrix (nucleotide)', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1449 , 'Comparison matrix (amino acid)', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1459 , 'Nucleic acid structure', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1460 , 'Protein structure', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1461 , 'Protein-ligand complex', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1462 , 'Carbohydrate structure', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1463 , 'Small molecule structure', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1464 , 'DNA structure', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1465 , 'RNA structure', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1466 , 'tRNA structure', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1467 , 'Protein chain', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1468 , 'Protein domain', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1470 , 'C-alpha trace', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1479 , 'Structure alignment (pair)', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1481 , 'Protein structure alignment', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1482 , 'Nucleic acid structure alignment', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1493 , 'RNA structure alignment', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1494 , 'Structural transformation matrix', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1497 , 'Root-mean-square deviation', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1498 , 'Tanimoto similarity score', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1502 , 'Amino acid index (chemical classes)', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1503 , 'Amino acid pair-wise contact potentials', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1505 , 'Amino acid index (molecular weight)', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1506 , 'Amino acid index (hydropathy)', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1507 , 'Amino acid index (White-Wimley data)', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1508 , 'Amino acid index (van der Waals radii)', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1519 , 'Peptide molecular weights', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1520 , 'Peptide hydrophobic moment', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1521 , 'Protein aliphatic index', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1522 , 'Protein sequence hydropathy plot', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1523 , 'Protein charge plot', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1524 , 'Protein solubility', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1525 , 'Protein crystallizability', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1526 , 'Protein globularity', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1527 , 'Protein titration curve', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1528 , 'Protein isoelectric point', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1529 , 'Protein pKa value', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1530 , 'Protein hydrogen exchange rate', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1531 , 'Protein extinction coefficient', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1532 , 'Protein optical density', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1534 , 'Peptide immunogenicity data', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1537 , 'Protein structure report', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1542 , 'Protein solvent accessibility', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1544 , 'Ramachandran plot', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1545 , 'Protein dipole moment', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1546 , 'Protein distance matrix', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1547 , 'Protein contact map', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1548 , 'Protein residue 3D cluster', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1549 , 'Protein hydrogen bonds', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1566 , 'Protein-ligand interaction report', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1583 , 'Nucleic acid melting profile', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1584 , 'Nucleic acid enthalpy', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1585 , 'Nucleic acid entropy', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1588 , 'DNA base pair stacking energies data', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1589 , 'DNA base pair twist angle data', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1590 , 'DNA base trimer roll angles data', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1595 , 'Base pairing probability matrix dotplot', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1596 , 'Nucleic acid folding report', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_1597 , 'Codon usage table', is missing mandatory format property: http://edamontology.org/is_format_of
# ...
# http://edamontology.org/data_2904 , 'Map accession', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_2905 , 'Lipid accession', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_2906 , 'Peptide ID', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_2907 , 'Protein accession', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_2908 , 'Organism accession', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_2909 , 'Organism name', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_2910 , 'Protein family accession', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_2911 , 'Transcription factor accession', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_2912 , 'Strain accession', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_2913 , 'Virus identifier', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_2914 , 'Sequence features metadata', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_2915 , 'Gramene identifier', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_2916 , 'DDBJ accession', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_2917 , 'ConsensusPathDB identifier', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_2955 , 'Sequence report', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_2956 , 'Protein secondary structure', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_2957 , 'Hopp and Woods plot', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_2969 , 'Sequence image', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_2970 , 'Protein hydropathy data', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_2976 , 'Protein sequence', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_2977 , 'Nucleic acid sequence', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_2978 , 'Reaction data', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_2979 , 'Peptide property', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_2985 , 'Nucleic acid thermodynamic data', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_2991 , 'Protein geometry data', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_2992 , 'Protein structure image', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_2994 , 'Phylogenetic character weights', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_3021 , 'UniProt accession', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_3022 , 'NCBI genetic code ID', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_3025 , 'Ontology concept identifier', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_3028 , 'Taxonomy', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_3029 , 'Protein ID (EMBL/GenBank/DDBJ)', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_3034 , 'Sequence feature identifier', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_3035 , 'Structure identifier', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_3036 , 'Matrix identifier', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_3103 , 'ATC code', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_3104 , 'UNII', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_3106 , 'System metadata', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_3115 , 'Microarray metadata', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_3117 , 'Microarray hybridisation data', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_3128 , 'Nucleic acid structure report', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_3134 , 'Gene transcript report', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_3148 , 'Gene family report', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_3153 , 'Protein image', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_3181 , 'Sequence assembly report', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_3238 , 'Cell type ontology ID', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_3264 , 'COSMIC ID', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_3265 , 'HGMD ID', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_3266 , 'Sequence assembly ID', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_3270 , 'Ensembl gene tree ID', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_3271 , 'Gene tree', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_3272 , 'Species tree', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_3273 , 'Sample ID', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_3274 , 'MGI accession', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_3275 , 'Phenotype name', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_3358 , 'Format identifier', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_3424 , 'Raw image', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_3425 , 'Carbohydrate property', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_3442 , 'MRI image', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_3449 , 'Cell migration track image', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_3451 , 'Rate of association', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_3479 , 'Gene order', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_3483 , 'Spectrum', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_3492 , 'Nucleic acid signature', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_3494 , 'DNA sequence', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_3495 , 'RNA sequence', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_3505 , 'Bibliography', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_3509 , 'Ontology mapping', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_3546 , 'Image metadata', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_3558 , 'Clinical trial report', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_3568 , 'Gene Expression Atlas Experiment ID', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_3667 , 'Disease identifier', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_3668 , 'Disease name', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_3669 , 'Training material', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_3670 , 'Online course', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_3671 , 'Text', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_3716 , 'Biosafety report', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_3717 , 'Isolation report', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_3718 , 'Pathogenicity report', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_3719 , 'Biosafety classification', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_3720 , 'Geographic location', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_3721 , 'Isolation source', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_3722 , 'Physiology parameter', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_3723 , 'Morphology parameter', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_3724 , 'Cultivation parameter', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_3732 , 'Sequencing metadata name', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_3733 , 'Flow cell identifier', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_3734 , 'Lane identifier', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_3735 , 'Run number', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_3736 , 'Ecological data', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_3737 , 'Alpha diversity data', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_3738 , 'Beta diversity data', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_3739 , 'Gamma diversity data', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_3743 , 'Ordination plot', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_3753 , 'Over-representation data', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_3754 , 'GO-term enrichment data', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_3756 , 'Localisation score', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_3757 , 'Unimod ID', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_3759 , 'ProteomeXchange ID', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_3768 , 'Clustered expression profiles', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_3769 , 'BRENDA ontology concept ID', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_3805 , '3D EM Map', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_3806 , '3D EM Mask', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_3807 , 'EM Movie', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_3808 , 'EM Micrograph', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_3842 , 'Molecular simulation data', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_3856 , 'RNA central ID', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_3861 , 'Electronic health record', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_3871 , 'Forcefield parameters', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_3905 , 'Histogram', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_3914 , 'Quality control report', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_3917 , 'Count matrix', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_3924 , 'DNA structure alignment', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_3932 , 'Q-value', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_3949 , 'Profile HMM', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_3952 , 'Pathway ID (WikiPathways)', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_3953 , 'Pathway overrepresentation data', is missing mandatory format property: http://edamontology.org/is_format_of
# http://edamontology.org/data_4022 , 'ORCID Identifier', is missing mandatory format property: http://edamontology.org/is_format_of
