# %%
from rdflib import ConjunctiveGraph, Namespace
import json
import os


# Constants for script error reporting as per https://github.com/edamontology/edamverify.
NOERR = "NOERR"
INFO  = "INFO"
WARN  = "WARN"
ERROR = "ERROR"

#Load EDAM_dev.owl from GitHub into an RDF graph.
print("Loading graph ...", end="")
g = ConjunctiveGraph()
g.load(os.environ.get('EDAM_PATH', '../edamontology/EDAM_dev.owl'), format='xml')
#g.load('https://raw.githubusercontent.com/edamontology/edamontology/master/EDAM_dev.owl', format='xml')
# g.load('EDAM_dev.owl', format='xml')
g.bind('edam', Namespace('http://edamontology.org#'))
print("done!")
# Out:
# Loading graph ...done!

# %%
q = """
PREFIX obo: <http://purl.obolibrary.org/obo/>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX oboInOwl: <http://www.geneontology.org/formats/oboInOwl#>
PREFIX edam:<http://edamontology.org/>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>

SELECT DISTINCT ?entity ?property ?value WHERE {


# ?entity ?property ?value .
FILTER (?property = <http://www.w3.org/2002/07/owl#annotatedTarget>)
#FILTER NOT EXISTS {    FILTER isLiteral(?value) }
#FILTER isLiteral(?value)    
}
"""

# %%
results = g.query(q)
print(f"{len(results)} ")
for r in results:
    print(f"{r['property']} {r['entity']} --- {r['value']} ")
    #print(f"{r['property']} ")
# Out:
# 30
# http://www.w3.org/2002/07/owl#annotatedTarget N266f9b3dff554b7196933ef03677beca --- OBO_REL:participates_in
# http://www.w3.org/2002/07/owl#annotatedTarget Nf15f6b329605415da9c6b7eeb61c6353 --- OBO_REL:has_participant
# http://www.w3.org/2002/07/owl#annotatedTarget Nddf94f7357484f8ab475bbfaed74252f --- true
# http://www.w3.org/2002/07/owl#annotatedTarget Nae7dd9d584774907a37f972c330f61da --- true
# http://www.w3.org/2002/07/owl#annotatedTarget N0ec2748382b34162adfeaab82b0eed8e --- File format
# http://www.w3.org/2002/07/owl#annotatedTarget N9cabf77793f64bbca1d8e6b13bc5c113 --- http://purl.org/dc/elements/1.1/identifier
# http://www.w3.org/2002/07/owl#annotatedTarget Nea76fcfec0b54b668621a2c0796b5b72 --- OBO_REL:participates_in
# http://www.w3.org/2002/07/owl#annotatedTarget N8a87177b08d74a12aaf0c950b12c63bb --- OBO_REL:quality_of
# http://www.w3.org/2002/07/owl#annotatedTarget N0e369e8c6c9a41fa954d07bda0199045 --- true
# http://www.w3.org/2002/07/owl#annotatedTarget N28ada01054444f2ba00f0794ad147057 --- Data model
# http://www.w3.org/2002/07/owl#annotatedTarget N907a9048c7e945bbbf969dd86cfa2506 --- true
# http://www.w3.org/2002/07/owl#annotatedTarget Nadd07670b0574c26b06cda3f4c281a80 --- Function
# http://www.w3.org/2002/07/owl#annotatedTarget N649c0c833aca494c90eb3eecd3919bc2 --- true
# http://www.w3.org/2002/07/owl#annotatedTarget Nd5e82d04d7d94516937933ee0eab7c2a --- OBO_REL:inheres_in
# http://www.w3.org/2002/07/owl#annotatedTarget N168a068beb3742148468ebeefc3c5ded --- OBO_REL:bearer_of
# http://www.w3.org/2002/07/owl#annotatedTarget Nd959f3e393524087b053224d8ee6287c --- Data set
# http://www.w3.org/2002/07/owl#annotatedTarget N9593aef3b62540a9a1ef6f9e9a5966fa --- Process
# http://www.w3.org/2002/07/owl#annotatedTarget N547cb08bc73d49a19847c4f54492fe8b --- Computational tool
# http://www.w3.org/2002/07/owl#annotatedTarget Nd5ef830408814fd09f31a180408ccc3a --- SO:0001248
# http://www.w3.org/2002/07/owl#annotatedTarget N0b73bd8445f64009a7e3a82ae0edb1ae --- true
# http://www.w3.org/2002/07/owl#annotatedTarget Nb1acbf2916584ce6a6a401464f3f9d27 --- UniProt|Enzyme Nomenclature
# http://www.w3.org/2002/07/owl#annotatedTarget N4d0185bee93c4b57a81f93941b22fd0f --- Datum
# http://www.w3.org/2002/07/owl#annotatedTarget Nf705c84cae904a1e84c422232382cd26 --- OBO_REL:quality_of
# http://www.w3.org/2002/07/owl#annotatedTarget N8fd10ca97e384e7b9a1a25e207915a91 --- OBO_REL:has_participant
# http://www.w3.org/2002/07/owl#annotatedTarget Nc959b2ecb1604157bbd13fa966005739 --- true
# http://www.w3.org/2002/07/owl#annotatedTarget N994ec3066152449ba5ce3baae1ecab41 --- http://edamontology.org/comment_handle
# http://www.w3.org/2002/07/owl#annotatedTarget Nd771e61558ed4d18b6a42efe540675eb --- http://www.w3.org/2000/01/rdf-schema#label
# http://www.w3.org/2002/07/owl#annotatedTarget Ndc94611c5ab44c2c87ce8bd58c127c29 --- true
# http://www.w3.org/2002/07/owl#annotatedTarget N45e9ef01284f4c579e90142dbc8647c0 --- OBO_REL:function_of
# http://www.w3.org/2002/07/owl#annotatedTarget N8b4e9a3206724bbf8e144f604e2c7b7d --- Data record

# %%
q= """
PREFIX obo: <http://purl.obolibrary.org/obo/>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX oboInOwl: <http://www.geneontology.org/formats/oboInOwl#>
PREFIX edam:<http://edamontology.org/>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
    
SELECT DISTINCT ?entity ?property ?label ?value WHERE {
    VALUES ?property {
                    <http://edamontology.org/citation>
                    <http://edamontology.org/documentation>
                    <http://edamontology.org/information_standard>
                    <http://edamontology.org/oldParent>
                    <http://edamontology.org/ontology_used>
                    <http://edamontology.org/organisation>
                    <http://www.geneontology.org/formats/oboInOwl#consider>
                    <http://www.geneontology.org/formats/oboInOwl#inSubset>
                    <http://www.geneontology.org/formats/oboInOwl#replacedBy>
                    <http://www.w3.org/2000/01/rdf-schema#seeAlso>
                    <http://www.w3.org/2000/01/rdf-schema#subClassOf>
                    <http://www.w3.org/2000/01/rdf-schema#subPropertyOf>
                    <http://www.w3.org/2002/07/owl#annotatedProperty>
                    <http://www.w3.org/2002/07/owl#inverseOf>


}

# ?entity ?property ?value .

FILTER isLiteral(?value) 
# ?entity rdfs:label ?label .

}
ORDER BY ?entity
LIMIT 300
"""

# %%
results = g.query(q)
print(f"{len(results)} ")
for r in results:
    print(f"{r['property']} -------- {r['entity']} --- {r['value']} ")
# Out:
# 218
# http://www.geneontology.org/formats/oboInOwl#inSubset -------- http://edamontology.org/citation --- concept_properties
# http://www.geneontology.org/formats/oboInOwl#inSubset -------- http://edamontology.org/created_in --- concept_properties
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/data_0006 --- "http://purl.obolibrary.org/obo/IAO_0000027"
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/data_0006 --- "http://purl.obolibrary.org/obo/IAO_0000030"
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/data_0006 --- http://purl.org/biotop/biotop.owl#DigitalEntity
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/data_0006 --- http://semanticscience.org/resource/SIO_000069
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/data_0006 --- http://semanticscience.org/resource/SIO_000088
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/data_0006 --- http://wsio.org/data_002
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/data_0006 --- http://www.ifomis.org/bfo/1.1/snap#Continuant
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/data_0006 --- http://www.onto-med.de/ontologies/gfo.owl#Perpetuant
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/data_0842 --- "http://purl.org/dc/elements/1.1/identifier"
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/data_0842 --- http://semanticscience.org/resource/SIO_000115
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/data_0842 --- http://wsio.org/data_005
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/data_0849 --- http://purl.bioontology.org/ontology/MSH/D058977
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/data_0863 --- http://purl.bioontology.org/ontology/MSH/D016415
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/data_0863 --- http://semanticscience.org/resource/SIO_010066
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/data_0871 --- http://www.evolutionaryontology.org/cdao.owl#Character
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/data_0872 --- http://purl.bioontology.org/ontology/MSH/D010802
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/data_0872 --- http://www.evolutionaryontology.org/cdao.owl#Tree
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/data_0883 --- http://purl.bioontology.org/ontology/MSH/D015394
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/data_1255 --- http://purl.bioontology.org/ontology/MSH/D058977
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/data_1354 --- http://semanticscience.org/resource/SIO_010531
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/data_1381 --- http://semanticscience.org/resource/SIO_010068
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/data_2044 --- http://purl.bioontology.org/ontology/MSH/D008969
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/data_2044 --- http://purl.org/biotop/biotop.owl#BioMolecularSequenceInformation
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/data_2048 --- http://semanticscience.org/resource/SIO_000148
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/data_2091 --- http://semanticscience.org/resource/SIO_000675
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/data_2091 --- http://semanticscience.org/resource/SIO_000731
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/data_2098 --- http://wsio.org/data_009
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/data_2099 --- "http://www.w3.org/2000/01/rdf-schema#label
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/data_2099 --- http://semanticscience.org/resource/SIO_000116
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/data_2099 --- http://usefulinc.com/ns/doap#name
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/data_2100 --- http://purl.org/dc/elements/1.1/type
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/data_2968 --- http://semanticscience.org/resource/SIO_000079
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/data_2968 --- http://semanticscience.org/resource/SIO_000081
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/data_2976 --- http://purl.org/biotop/biotop.owl#AminoAcidSequenceInformation
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/data_2977 --- http://purl.org/biotop/biotop.owl#NucleotideSequenceInformation
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/data_3424 --- http://semanticscience.org/resource/SIO_000081
# http://www.geneontology.org/formats/oboInOwl#inSubset -------- http://edamontology.org/deprecation_comment --- concept_properties
# http://www.geneontology.org/formats/oboInOwl#inSubset -------- http://edamontology.org/documentation --- concept_properties
# http://www.geneontology.org/formats/oboInOwl#inSubset -------- http://edamontology.org/example --- concept_properties
# http://www.geneontology.org/formats/oboInOwl#inSubset -------- http://edamontology.org/file_extension --- concept_properties
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/format_1207 --- http://onto.eva.mpg.de/ontologies/gfo-bio.owl#Nucleotide_sequence
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/format_1208 --- http://onto.eva.mpg.de/ontologies/gfo-bio.owl#Amino_acid_sequence
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/format_1212 --- http://onto.eva.mpg.de/ontologies/gfo-bio.owl#DNA_sequence
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/format_1213 --- http://onto.eva.mpg.de/ontologies/gfo-bio.owl#RNA_sequence
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/format_1915 --- "http://purl.obolibrary.org/obo/IAO_0000098"
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/format_1915 --- "http://purl.org/dc/elements/1.1/format"
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/format_1915 --- http://purl.org/biotop/biotop.owl#MachineLanguage
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/format_1915 --- http://purl.org/biotop/biotop.owl#Quality
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/format_1915 --- http://semanticscience.org/resource/SIO_000612
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/format_1915 --- http://semanticscience.org/resource/SIO_000618
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/format_1915 --- http://wsio.org/compression_004
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/format_1915 --- http://www.ifomis.org/bfo/1.1/snap#Continuant
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/format_1915 --- http://www.ifomis.org/bfo/1.1/snap#Quality
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/format_1915 --- http://www.loa-cnr.it/ontologies/DOLCE-Lite.owl#quality
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/format_1915 --- http://www.onto-med.de/ontologies/gfo.owl#Perpetuant
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/format_1915 --- http://www.onto-med.de/ontologies/gfo.owl#Symbol_structure
# http://edamontology.org/documentation -------- http://edamontology.org/format_1997 --- http://www.bioperl.org/wiki/PHYLIP_multiple_alignment_format
# http://edamontology.org/documentation -------- http://edamontology.org/format_1998 --- http://www.bioperl.org/wiki/PHYLIP_multiple_alignment_format
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/format_2200 --- http://filext.com/file-extension/FASTA
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/format_2330 --- http://filext.com/file-extension/TXT
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/format_2330 --- http://www.iana.org/assignments/media-types/media-types.xhtml#text
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/format_2330 --- http://www.iana.org/assignments/media-types/text/plain
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/format_2331 --- http://filext.com/file-extension/HTML
# http://edamontology.org/ontology_used -------- http://edamontology.org/format_2352 --- Any ontology allowed, none mandatory. Preferrably with URIs but URIs are not mandatory. Non-ontology terms are also allowed as the last resort in case of a lack of suitable ontology.
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/format_2571 --- http://www.onto-med.de/ontologies/gfo.owl#Symbol_sequence
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/format_3261 --- http://www.ebi.ac.uk/SWO/data/SWO_3000006
# http://edamontology.org/documentation -------- http://edamontology.org/format_3462 --- http://www.ebi.ac.uk/ena/software/cram-usage#format_specification http://samtools.github.io/hts-specs/CRAMv2.1.pdf
# http://edamontology.org/documentation -------- http://edamontology.org/format_3484 --- https://github.com/BenLangmead/bowtie/blob/master/MANUAL
# http://edamontology.org/documentation -------- http://edamontology.org/format_3485 --- http://www.molbiol.ox.ac.uk/tutorials/Seqlab_GCG.pdf
# http://edamontology.org/documentation -------- http://edamontology.org/format_3487 --- http://rothlab.ucdavis.edu/genhelp/chapter_2_using_sequences.html#_Creating_and_Editing_Single_Sequenc
# http://edamontology.org/documentation -------- http://edamontology.org/format_3491 --- https://github.com/BenLangmead/bowtie/blob/master/MANUAL
# http://edamontology.org/documentation -------- http://edamontology.org/format_3607 --- http://en.wikipedia.org/wiki/Phred_quality_score
# http://edamontology.org/documentation -------- http://edamontology.org/format_3609 --- http://en.wikipedia.org/wiki/Phred_quality_score
# http://edamontology.org/documentation -------- http://edamontology.org/format_3610 --- http://en.wikipedia.org/wiki/Phred_quality_score
# http://edamontology.org/documentation -------- http://edamontology.org/format_3611 --- http://en.wikipedia.org/wiki/Phred_quality_score
# http://edamontology.org/documentation -------- http://edamontology.org/format_3654 --- https://dx.doi.org/10.1038%2Fnbt1031
# http://edamontology.org/documentation -------- http://edamontology.org/format_3655 --- http://sashimi.sourceforge.net/schema_revision/pepXML/pepXML_v118.xsd
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/format_3747 --- http://doi.org/10.1038/msb4100024
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/format_3747 --- http://sashimi.sourceforge.net/schema_revision/protXML/protXML_v3.xsd
# http://edamontology.org/documentation -------- http://edamontology.org/format_3764 --- http://ftp.mi.fu-berlin.de/pub/OpenMS/release1.9-documentation/html/classOpenMS_1_1IdXMLFile.html
# http://edamontology.org/documentation -------- http://edamontology.org/format_3764 --- http://open-ms.sourceforge.net/schemas/
# http://edamontology.org/documentation -------- http://edamontology.org/format_3832 --- http://ftp.mi.fu-berlin.de/pub/OpenMS/release1.9-documentation/html/classOpenMS_1_1ConsensusXMLFile.html
# http://edamontology.org/documentation -------- http://edamontology.org/format_3833 --- http://ftp.mi.fu-berlin.de/pub/OpenMS/release1.9-documentation/html/classOpenMS_1_1FeatureXMLFile.html
# http://edamontology.org/documentation -------- http://edamontology.org/format_3834 --- http://www.psidev.info/mzdata-1_0_5-docs
# http://edamontology.org/documentation -------- http://edamontology.org/format_3835 --- http://cruxtoolkit.sourceforge.net/tide-search.html
# http://edamontology.org/documentation -------- http://edamontology.org/format_3836 --- ftp://ftp.ncbi.nlm.nih.gov/blast/documents/NEWXML/ProposedBLASTXMLChanges.pdf
# http://edamontology.org/documentation -------- http://edamontology.org/format_3836 --- ftp://ftp.ncbi.nlm.nih.gov/blast/documents/NEWXML/xml2.pdf
# http://edamontology.org/documentation -------- http://edamontology.org/format_3836 --- http://www.ncbi.nlm.nih.gov/data_specs/schema/NCBI_BlastOutput2.mod.xsd
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/format_3982 --- https://genome.ucsc.edu/goldenPath/help/chain.html
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/format_3983 --- https://genome.ucsc.edu/goldenPath/help/net.html
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/format_3985 --- https://github.com/galaxyproject/gxformat2
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/format_3992 --- http://wiki.bits.vib.be/index.php/CIGAR/
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/format_4000 --- https://rmarkdown.rstudio.com/articles_intro.html
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/format_4002 --- https://docs.python.org/2/library/pickle.html
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/format_4004 --- https://pdfs.semanticscholar.org/5f25/f1cc6cdf2225fe22dc6fd4fc0296d486a85c.pdf
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/format_4006 --- https://github.com/facebook/zstd/blob/master/doc/zstd_compression_format.md
# http://www.geneontology.org/formats/oboInOwl#inSubset -------- http://edamontology.org/has_format --- edam
# http://www.geneontology.org/formats/oboInOwl#inSubset -------- http://edamontology.org/has_format --- relations
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/has_format --- "http://purl.obolibrary.org/obo/OBI_0000298"
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/has_format --- http://www.loa-cnr.it/ontologies/DOLCE-Lite.owl#has-quality"
# http://www.geneontology.org/formats/oboInOwl#inSubset -------- http://edamontology.org/has_function --- edam
# http://www.geneontology.org/formats/oboInOwl#inSubset -------- http://edamontology.org/has_function --- relations
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/has_function --- "http://purl.obolibrary.org/obo/OBI_0000306"
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/has_function --- http://wsio.org/has_function
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/has_function --- http://www.loa-cnr.it/ontologies/DOLCE-Lite.owl#has-quality"
# http://www.geneontology.org/formats/oboInOwl#inSubset -------- http://edamontology.org/has_identifier --- edam
# http://www.geneontology.org/formats/oboInOwl#inSubset -------- http://edamontology.org/has_identifier --- relations
# http://www.geneontology.org/formats/oboInOwl#inSubset -------- http://edamontology.org/has_input --- edam
# http://www.geneontology.org/formats/oboInOwl#inSubset -------- http://edamontology.org/has_input --- relations
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/has_input --- "http://purl.obolibrary.org/obo/OBI_0000293"
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/has_input --- http://wsio.org/has_input
# http://www.geneontology.org/formats/oboInOwl#inSubset -------- http://edamontology.org/has_output --- edam
# http://www.geneontology.org/formats/oboInOwl#inSubset -------- http://edamontology.org/has_output --- relations
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/has_output --- "http://purl.obolibrary.org/obo/OBI_0000299"
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/has_output --- http://wsio.org/has_output
# http://www.geneontology.org/formats/oboInOwl#inSubset -------- http://edamontology.org/has_topic --- edam
# http://www.geneontology.org/formats/oboInOwl#inSubset -------- http://edamontology.org/has_topic --- relations
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/has_topic --- "http://purl.obolibrary.org/obo/IAO_0000136"
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/has_topic --- "http://purl.obolibrary.org/obo/OBI_0000298"
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/has_topic --- http://annotation-ontology.googlecode.com/svn/trunk/annotation-core.owl#hasTopic
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/has_topic --- http://www.loa-cnr.it/ontologies/DOLCE-Lite.owl#has-quality
# http://www.geneontology.org/formats/oboInOwl#inSubset -------- http://edamontology.org/information_standard --- concept_properties
# http://www.geneontology.org/formats/oboInOwl#inSubset -------- http://edamontology.org/is_deprecation_candidate --- concept_properties
# http://www.geneontology.org/formats/oboInOwl#inSubset -------- http://edamontology.org/is_format_of --- edam
# http://www.geneontology.org/formats/oboInOwl#inSubset -------- http://edamontology.org/is_format_of --- relations
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/is_format_of --- http://www.loa-cnr.it/ontologies/DOLCE-Lite.owl#inherent-in
# http://www.geneontology.org/formats/oboInOwl#inSubset -------- http://edamontology.org/is_function_of --- edam
# http://www.geneontology.org/formats/oboInOwl#inSubset -------- http://edamontology.org/is_function_of --- relations
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/is_function_of --- http://wsio.org/is_function_of
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/is_function_of --- http://www.loa-cnr.it/ontologies/DOLCE-Lite.owl#inherent-in
# http://www.geneontology.org/formats/oboInOwl#inSubset -------- http://edamontology.org/is_identifier_of --- edam
# http://www.geneontology.org/formats/oboInOwl#inSubset -------- http://edamontology.org/is_identifier_of --- relations
# http://www.geneontology.org/formats/oboInOwl#inSubset -------- http://edamontology.org/is_input_of --- edam
# http://www.geneontology.org/formats/oboInOwl#inSubset -------- http://edamontology.org/is_input_of --- relations
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/is_input_of --- "http://purl.obolibrary.org/obo/OBI_0000295"
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/is_input_of --- http://wsio.org/is_input_of
# http://www.geneontology.org/formats/oboInOwl#inSubset -------- http://edamontology.org/is_output_of --- edam
# http://www.geneontology.org/formats/oboInOwl#inSubset -------- http://edamontology.org/is_output_of --- relations
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/is_output_of --- "http://purl.obolibrary.org/obo/OBI_0000312"
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/is_output_of --- http://wsio.org/is_output_of
# http://www.geneontology.org/formats/oboInOwl#inSubset -------- http://edamontology.org/is_refactor_candidate --- concept_properties
# http://www.geneontology.org/formats/oboInOwl#inSubset -------- http://edamontology.org/is_topic_of --- edam
# http://www.geneontology.org/formats/oboInOwl#inSubset -------- http://edamontology.org/is_topic_of --- relations
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/is_topic_of --- http://www.loa-cnr.it/ontologies/DOLCE-Lite.owl#inherent-in
# http://www.geneontology.org/formats/oboInOwl#inSubset -------- http://edamontology.org/isdebtag --- concept_properties
# http://www.geneontology.org/formats/oboInOwl#inSubset -------- http://edamontology.org/media_type --- concept_properties
# http://www.geneontology.org/formats/oboInOwl#inSubset -------- http://edamontology.org/notRecommendedForAnnotation --- concept_properties
# http://www.geneontology.org/formats/oboInOwl#inSubset -------- http://edamontology.org/obsolete_since --- concept_properties
# http://www.geneontology.org/formats/oboInOwl#inSubset -------- http://edamontology.org/oldParent --- concept_properties
# http://www.geneontology.org/formats/oboInOwl#inSubset -------- http://edamontology.org/oldRelated --- concept_properties
# http://www.geneontology.org/formats/oboInOwl#inSubset -------- http://edamontology.org/ontology_used --- concept_properties
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/operation_0004 --- http://onto.eva.mpg.de/ontologies/gfo-bio.owl#Method
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/operation_0004 --- http://purl.org/biotop/biotop.owl#Function
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/operation_0004 --- http://semanticscience.org/resource/SIO_000017
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/operation_0004 --- http://semanticscience.org/resource/SIO_000649
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/operation_0004 --- http://wsio.org/operation_001
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/operation_0004 --- http://www.ebi.ac.uk/swo/SWO_0000003
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/operation_0004 --- http://www.ifomis.org/bfo/1.1/snap#Continuant
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/operation_0004 --- http://www.ifomis.org/bfo/1.1/snap#Function
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/operation_0004 --- http://www.ifomis.org/bfo/1.1/snap#Quality
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/operation_0004 --- http://www.ifomis.org/bfo/1.1/span#Process
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/operation_0004 --- http://www.loa-cnr.it/ontologies/DOLCE-Lite.owl#process
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/operation_0004 --- http://www.loa-cnr.it/ontologies/DOLCE-Lite.owl#quality
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/operation_0004 --- http://www.onto-med.de/ontologies/gfo.owl#Function
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/operation_0004 --- http://www.onto-med.de/ontologies/gfo.owl#Perpetuant
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/operation_0004 --- http://www.onto-med.de/ontologies/gfo.owl#Process
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/operation_0558 --- http://www.evolutionaryontology.org/cdao.owl#CDAOAnnotation
# http://www.geneontology.org/formats/oboInOwl#inSubset -------- http://edamontology.org/organisation --- concept_properties
# http://www.geneontology.org/formats/oboInOwl#inSubset -------- http://edamontology.org/refactor_comment --- concept_properties
# http://www.geneontology.org/formats/oboInOwl#inSubset -------- http://edamontology.org/regex --- concept_properties
# http://www.geneontology.org/formats/oboInOwl#inSubset -------- http://edamontology.org/related_term --- concept_properties
# http://www.geneontology.org/formats/oboInOwl#inSubset -------- http://edamontology.org/repository --- concept_properties
# http://www.geneontology.org/formats/oboInOwl#inSubset -------- http://edamontology.org/thematic_editor --- concept_properties
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/topic_0003 --- http://bioontology.org/ontologies/ResearchArea.owl#Area_of_Research
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/topic_0003 --- http://onto.eva.mpg.de/ontologies/gfo-bio.owl#Method
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/topic_0003 --- http://purl.org/biotop/biotop.owl#Quality
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/topic_0003 --- http://www.ifomis.org/bfo/1.1/snap#Continuant
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/topic_0003 --- http://www.ifomis.org/bfo/1.1/snap#Quality
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/topic_0003 --- http://www.loa-cnr.it/ontologies/DOLCE-Lite.owl#quality
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/topic_0003 --- http://www.onto-med.de/ontologies/gfo.owl#Category
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/topic_0003 --- http://www.onto-med.de/ontologies/gfo.owl#Perpetuant
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/topic_0077 --- http://purl.bioontology.org/ontology/MSH/D017422
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/topic_0077 --- http://purl.bioontology.org/ontology/MSH/D017423
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/topic_0078 --- http://purl.bioontology.org/ontology/MSH/D020539
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/topic_0080 --- http://purl.bioontology.org/ontology/MSH/D017421
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/topic_0081 --- http://purl.bioontology.org/ontology/MSH/D015394
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/topic_0084 --- http://purl.bioontology.org/ontology/MSH/D010802
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/topic_0089 --- http://purl.bioontology.org/ontology/MSH/D002965
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/topic_0091 --- http://purl.bioontology.org/ontology/MSH/D016247
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/topic_0121 --- http://purl.bioontology.org/ontology/MSH/D040901
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/topic_0199 --- http://purl.bioontology.org/ontology/MSH/D014644
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/topic_0200 --- http://purl.bioontology.org/ontology/MSH/D046228
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/topic_0203 --- http://purl.bioontology.org/ontology/MSH/D015870
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/topic_0610 --- http://purl.bioontology.org/ontology/MSH/D004777
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/topic_0622 --- http://purl.bioontology.org/ontology/MSH/D023281
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/topic_0632 --- http://purl.bioontology.org/ontology/MSH/D015335
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/topic_0804 --- http://purl.bioontology.org/ontology/MSH/D007120
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/topic_0804 --- http://purl.bioontology.org/ontology/MSH/D007125
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/topic_2259 --- http://purl.bioontology.org/ontology/MSH/D049490
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/topic_2269 --- http://purl.bioontology.org/ontology/MSH/D056808
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/topic_2829 --- http://purl.bioontology.org/ontology/MSH/D002965
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/topic_3050 --- http://purl.bioontology.org/ontology/MSH/D044822
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/topic_3053 --- http://purl.bioontology.org/ontology/MSH/D005823
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/topic_3068 --- http://purl.bioontology.org/ontology/MSH/D011642
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/topic_3071 --- http://purl.bioontology.org/ontology/MSH/D000079803
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/topic_3072 --- http://purl.bioontology.org/ontology/MSH/D058977
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/topic_3168 --- http://purl.bioontology.org/ontology/MSH/D059014
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/topic_3172 --- http://purl.bioontology.org/ontology/MSH/D055432
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/topic_3173 --- http://purl.bioontology.org/ontology/MSH/D057890
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/topic_3174 --- http://purl.bioontology.org/ontology/MSH/D056186
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/topic_3176 --- http://purl.bioontology.org/ontology/MSH/D042003
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/topic_3293 --- http://purl.bioontology.org/ontology/MSH/D010802
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/topic_3295 --- http://purl.bioontology.org/ontology/MSH/D019175
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/topic_3412 --- Hepatobiliary medicine
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/topic_3571 --- http://purl.bioontology.org/ontology/MSH/D030541
# http://www.w3.org/2000/01/rdf-schema#seeAlso -------- http://edamontology.org/topic_3974 --- http://purl.bioontology.org/ontology/MSH/D057890
